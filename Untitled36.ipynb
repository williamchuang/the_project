# %%
print(reqId)
print(clientId)
# Out:
# 573
# 15327

# %%
reqId = 555
initiation = 0

import xlwt
from xlutils.copy import copy
import xlrd
import os.path
from datetime import datetime 
from datetime import timedelta
import time
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
from IBWrapper import IBWrapper, contract
from ib.ext.EClientSocket import EClientSocket
from ib.ext.ScannerSubscription import ScannerSubscription
accountName = "U9038813"
host = ""
port = 7497

# %%
class Excel(object):

    def __init__(self):
        print("write to excel file")

    def group(self,lst, size):
        return ([lst[i:i+size] for i  in range(0, len(lst), size)])

    def write_to_excel_file(self, filename, row, column, content):
        if not os.path.exists(filename):
            workbook = xlwt.Workbook() # Create an new Excel file and add a worksheet.
            worksheet = workbook.add_sheet('001') #add worksheet
            workbook.save(filename)
        rb = xlrd.open_workbook(filename,formatting_info=True)
        r_sheet = rb.sheet_by_index(0) 
        r = r_sheet.nrows
        wb = copy(rb) 
        sheet = wb.get_sheet(0)
        sheet.write(row, column, content)
        wb.save(filename)

now=datetime.now()
now_plus_1 = now + timedelta(minutes = 1)
k=now_plus_1.strftime("%Y-%m-%d %H:%M:%S")
flag=0
print(datetime.now())
E = Excel()
data_endtime_BID = datetime.now().strftime("%Y%m%d %H:%M:%S")#-timedelta(seconds = 6000)
data_endtime_ASK = datetime.now().strftime("%Y%m%d %H:%M:%S")

print("data_endtime_BID "+str(data_endtime_BID)) 
print("data_endtime_ASK "+str(data_endtime_ASK))
# Out:
# 2018-07-27 14:25:03.088895
# write to excel file
# data_endtime_BID 20180727 14:25:03
# data_endtime_ASK 20180727 14:25:03

# %%
Counter = 3
clientId=15305

data_endtime_BID_1 = 0
data_endtime_BID_2 = 0
data_endtime_BID_3 = 0

data_endtime_ASK_1 = 0
data_endtime_ASK_2 = 0
data_endtime_ASK_3 = 0


while Counter>0:
    try:
        
        if Counter ==3:
            time.sleep(12)
            callback = IBWrapper()             # Instantiate IBWrapper. callback 
            tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
            tws.eConnect(host, port, clientId) # Connect to TWS
            create = contract()                # Instantiate contract class
            contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
            callback.initiate_variables()
            tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_BID,
                          "10000 S", 
                          #"30 secs",
                          "5 secs", 
                          "BID", 
                          0, 
                          1)
            time.sleep(13)
            #print(callback.historical_Data)
            data_endtime_BID_1=callback.historical_Data[0][1]
            data_endtime_ASK_1=data_endtime_BID_1
            print(callback.historical_Data[0][1])
            print("data_endtime_ASK_1 "+str(data_endtime_ASK_1))
            tws.eDisconnect()
        elif Counter ==2:
            time.sleep(12)
            callback = IBWrapper()             # Instantiate IBWrapper. callback 
            tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
            tws.eConnect(host, port, clientId) # Connect to TWS
            create = contract()                # Instantiate contract class
            contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
            callback.initiate_variables()
            tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_BID_1,
                          "10000 S", 
                          #"30 secs",
                          "5 secs", 
                          "BID", 
                          0, 
                          1)
            time.sleep(13)
            data_endtime_BID_2=callback.historical_Data[0][1]
            data_endtime_ASK_2=data_endtime_BID_2
            print("data_endtime_BID_2 "+str(data_endtime_BID_2)) 
            print("data_endtime_ASK_2 "+str(data_endtime_ASK_2))
            tws.eDisconnect()
        elif Counter ==1:
            time.sleep(12)
            callback = IBWrapper()             # Instantiate IBWrapper. callback 
            tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
            tws.eConnect(host, port, clientId) # Connect to TWS
            create = contract()                # Instantiate contract class
            contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
            callback.initiate_variables()
            tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_BID_2,
                          "10000 S", 
                          #"30 secs",
                          "5 secs", 
                          "BID", 
                          0, 
                          1)
            time.sleep(13)
            data_endtime_BID_3=callback.historical_Data[0][1]
            data_endtime_ASK_3=data_endtime_BID_3
            print("data_endtime_BID_3 "+str(data_endtime_BID_3)) 
            print("data_endtime_ASK_3 "+str(data_endtime_ASK_3))
            tws.eDisconnect()
        Counter=Counter-1
        clientId = clientId+1
        reqId = reqId + 1
        continue
    except (TimeoutError, IndexError):
        pass
# Out:
# Server Version: 76
# TWS Time at connection:20180727 14:25:45 EST
# create_contract
# [-1, 2104, 'Market data farm connection is OK:hfarm']
# [-1, 2104, 'Market data farm connection is OK:jfarm']
# [-1, 2104, 'Market data farm connection is OK:eufarm']
# [-1, 2104, 'Market data farm connection is OK:usfuture']
# [-1, 2104, 'Market data farm connection is OK:cashfarm']
# [-1, 2104, 'Market data farm connection is OK:usfarm.us']
# [-1, 2104, 'Market data farm connection is OK:usfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ilhmds']
# [-1, 2106, 'HMDS data farm connection is OK:euhmds']
# [-1, 2106, 'HMDS data farm connection is OK:fundfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ushmds']
# 20180727  11:38:20
# data_endtime_ASK_1 20180727  11:38:20
# Server Version: 76
# TWS Time at connection:20180727 14:26:10 EST
# create_contract
# [-1, 2104, 'Market data farm connection is OK:hfarm']
# [-1, 2104, 'Market data farm connection is OK:jfarm']
# ...

# %%
Counter = 4
I=0
i=0
while Counter>0:
    try:
         
        if Counter ==4:
            time.sleep(12)
            callback = IBWrapper()             # Instantiate IBWrapper. callback 
            tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
            tws.eConnect(host, port, clientId) # Connect to TWS
            create = contract()                # Instantiate contract class
            contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
            callback.initiate_variables()
            tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_BID_3,
                          "10000 S", 
                          #"30 secs",
                          "5 secs", 
                          "BID", 
                          0, 
                          1)
            time.sleep(12)
            #print(callback.historical_Data)
            
            filename = "BID_book1.xls"
            if not os.path.exists(filename):
                workbook = xlwt.Workbook() # Create an new Excel file and add a worksheet.
                worksheet = workbook.add_sheet('001') #add worksheet
                workbook.save(filename)
            rb = xlrd.open_workbook("BID_book1.xls",formatting_info=True)
            r_sheet = rb.sheet_by_index(0) 
            r = r_sheet.nrows
            wb = copy(rb) 
            sheet = wb.get_sheet(0)
            while i<len(callback.historical_Data):
                sheet.write(i, 0, callback.historical_Data[i][1])
                sheet.write(i, 1, callback.historical_Data[i][2])
                sheet.write(i, 2, callback.historical_Data[i][3])
                sheet.write(i, 3, callback.historical_Data[i][4])
                sheet.write(i, 4, callback.historical_Data[i][5])
                i=i+1
            wb.save("BID_book1.xls")
            tws.eDisconnect()
            clientId = clientId+1
            time.sleep(12)
            callback = IBWrapper()             # Instantiate IBWrapper. callback 
            tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
            tws.eConnect(host, port, clientId) # Connect to TWS
            create = contract()                # Instantiate contract class
            contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
            callback.initiate_variables()
            time.sleep(2)
            tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_ASK_3,
                          "10000 S", 
                          #"30 secs",
                          "5 secs", 
                          "ASK", 
                          0, 
                          1)
            time.sleep(12)
            filename = "ASK_book1.xls"
            if not os.path.exists(filename):
                workbook = xlwt.Workbook() # Create an new Excel file and add a worksheet.
                worksheet = workbook.add_sheet('001') #add worksheet
                workbook.save(filename)
            rb = xlrd.open_workbook("ASK_book1.xls",formatting_info=True)
            r_sheet = rb.sheet_by_index(0) 
            r = r_sheet.nrows
            wb = copy(rb) 
            sheet = wb.get_sheet(0)
            while I<len(callback.historical_Data):
                sheet.write(I, 0, callback.historical_Data[I][1])
                sheet.write(I, 1, callback.historical_Data[I][2])
                sheet.write(I, 2, callback.historical_Data[I][3])
                sheet.write(I, 3, callback.historical_Data[I][4])
                sheet.write(I, 4, callback.historical_Data[I][5])
                I=I+1
            wb.save("ASK_book1.xls")
            tws.eDisconnect()
        elif Counter ==3:
            time.sleep(12)
            callback = IBWrapper()             # Instantiate IBWrapper. callback 
            tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
            tws.eConnect(host, port, clientId) # Connect to TWS
            create = contract()                # Instantiate contract class
            contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
            callback.initiate_variables()
            tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_BID_2,
                          "10000 S", 
                          #"30 secs",
                          "5 secs", 
                          "BID", 
                          0, 
                          1)
            time.sleep(12)
            print(callback.historical_Data[0][1])
            i=i-1
            rb = xlrd.open_workbook("BID_book1.xls",formatting_info=True)
            r_sheet = rb.sheet_by_index(0) 
            r = r_sheet.nrows
            wb = copy(rb) 
            sheet = wb.get_sheet(0)
            j=0
            while j<len(callback.historical_Data):
                sheet.write(i, 0, callback.historical_Data[j][1])
                sheet.write(i, 1, callback.historical_Data[j][2])
                sheet.write(i, 2, callback.historical_Data[j][3])
                sheet.write(i, 3, callback.historical_Data[j][4])
                sheet.write(i, 4, callback.historical_Data[j][5])
                i=i+1
                j=j+1
            wb.save("BID_book1.xls")
            tws.eDisconnect()
            clientId = clientId+1
            time.sleep(12)
            callback = IBWrapper()             # Instantiate IBWrapper. callback 
            tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
            tws.eConnect(host, port, clientId) # Connect to TWS
            create = contract()                # Instantiate contract class
            contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
            callback.initiate_variables()
            tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_ASK_2,
                          "10000 S", 
                          #"30 secs",
                          "5 secs", 
                          "ASK", 
                          0, 
                          1)
            time.sleep(12)
            I=I-1
            rb = xlrd.open_workbook("ASK_book1.xls",formatting_info=True)
            r_sheet = rb.sheet_by_index(0) 
            r = r_sheet.nrows
            wb = copy(rb) 
            sheet = wb.get_sheet(0)
            J=0
            while J<len(callback.historical_Data):
                sheet.write(I, 0, callback.historical_Data[J][1])
                sheet.write(I, 1, callback.historical_Data[J][2])
                sheet.write(I, 2, callback.historical_Data[J][3])
                sheet.write(I, 3, callback.historical_Data[J][4])
                sheet.write(I, 4, callback.historical_Data[J][5])
                I=I+1
                J=J+1
            wb.save("ASK_book1.xls")
            tws.eDisconnect()
        elif Counter ==2:
            time.sleep(12)
            callback = IBWrapper()             # Instantiate IBWrapper. callback 
            tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
            tws.eConnect(host, port, clientId) # Connect to TWS
            create = contract()                # Instantiate contract class
            contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
            callback.initiate_variables()
            tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_BID_1,
                          "10000 S", 
                          #"30 secs",
                          "5 secs", 
                          "BID", 
                          0, 
                          1)
            time.sleep(12)
            i=i-1
            rb = xlrd.open_workbook("BID_book1.xls",formatting_info=True)
            r_sheet = rb.sheet_by_index(0) 
            r = r_sheet.nrows
            wb = copy(rb) 
            sheet = wb.get_sheet(0)
            j=0
            while j<len(callback.historical_Data):
                sheet.write(i, 0, callback.historical_Data[j][1])
                sheet.write(i, 1, callback.historical_Data[j][2])
                sheet.write(i, 2, callback.historical_Data[j][3])
                sheet.write(i, 3, callback.historical_Data[j][4])
                sheet.write(i, 4, callback.historical_Data[j][5])
                i=i+1
                j=j+1
            wb.save("BID_book1.xls")
            tws.eDisconnect()
            clientId = clientId+1
            time.sleep(12)
            callback = IBWrapper()             # Instantiate IBWrapper. callback 
            tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
            tws.eConnect(host, port, clientId) # Connect to TWS
            create = contract()                # Instantiate contract class
            contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
            callback.initiate_variables()
            tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_ASK_1,
                          "10000 S", 
                          #"30 secs",
                          "5 secs", 
                          "ASK", 
                          0, 
                          1)
            time.sleep(12)
            I=I-1
            rb = xlrd.open_workbook("ASK_book1.xls",formatting_info=True)
            r_sheet = rb.sheet_by_index(0) 
            r = r_sheet.nrows
            wb = copy(rb) 
            sheet = wb.get_sheet(0)
            J=0
            while J<len(callback.historical_Data):
                sheet.write(I, 0, callback.historical_Data[J][1])
                sheet.write(I, 1, callback.historical_Data[J][2])
                sheet.write(I, 2, callback.historical_Data[J][3])
                sheet.write(I, 3, callback.historical_Data[J][4])
                sheet.write(I, 4, callback.historical_Data[J][5])
                I=I+1
                J=J+1
            wb.save("ASK_book1.xls")
            tws.eDisconnect()
        elif Counter ==1:
            time.sleep(12)
            callback = IBWrapper()             # Instantiate IBWrapper. callback 
            tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
            tws.eConnect(host, port, clientId) # Connect to TWS
            create = contract()                # Instantiate contract class
            contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
            callback.initiate_variables()
            tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_BID,
                          "10000 S", 
                          #"30 secs",
                          "5 secs", 
                          "BID", 
                          0, 
                          1)
            time.sleep(12)
            i=i-1
            rb = xlrd.open_workbook("BID_book1.xls",formatting_info=True)
            r_sheet = rb.sheet_by_index(0) 
            r = r_sheet.nrows
            wb = copy(rb) 
            sheet = wb.get_sheet(0)
            j=0
            while j<len(callback.historical_Data):
                sheet.write(i, 0, callback.historical_Data[j][1])
                sheet.write(i, 1, callback.historical_Data[j][2])
                sheet.write(i, 2, callback.historical_Data[j][3])
                sheet.write(i, 3, callback.historical_Data[j][4])
                sheet.write(i, 4, callback.historical_Data[j][5])
                i=i+1
                j=j+1
            wb.save("BID_book1.xls")
            tws.eDisconnect()
            clientId = clientId+1
            time.sleep(12)
            callback = IBWrapper()             # Instantiate IBWrapper. callback 
            tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
            tws.eConnect(host, port, clientId) # Connect to TWS
            create = contract()                # Instantiate contract class
            contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
            callback.initiate_variables()
            tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_ASK,
                          "10000 S", 
                          #"30 secs",
                          "5 secs", 
                          "ASK", 
                          0, 
                          1)
            time.sleep(12)
            I=I-1
            rb = xlrd.open_workbook("ASK_book1.xls",formatting_info=True)
            r_sheet = rb.sheet_by_index(0) 
            r = r_sheet.nrows
            wb = copy(rb) 
            sheet = wb.get_sheet(0)
            J=0
            while J<len(callback.historical_Data):
                sheet.write(I, 0, callback.historical_Data[J][1])
                sheet.write(I, 1, callback.historical_Data[J][2])
                sheet.write(I, 2, callback.historical_Data[J][3])
                sheet.write(I, 3, callback.historical_Data[J][4])
                sheet.write(I, 4, callback.historical_Data[J][5])
                I=I+1
                J=J+1
            wb.save("ASK_book1.xls")
            tws.eDisconnect()
        Counter=Counter-1
        clientId = clientId+1
        reqId = reqId + 1
        continue
    except TimeoutError or IndexError:
        pass
# Out:
# Server Version: 76
# TWS Time at connection:20180727 14:28:17 EST
# create_contract
# [-1, 2104, 'Market data farm connection is OK:hfarm']
# [-1, 2104, 'Market data farm connection is OK:jfarm']
# [-1, 2104, 'Market data farm connection is OK:eufarm']
# [-1, 2104, 'Market data farm connection is OK:usfuture']
# [-1, 2104, 'Market data farm connection is OK:cashfarm']
# [-1, 2104, 'Market data farm connection is OK:usfarm.us']
# [-1, 2104, 'Market data farm connection is OK:usfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ilhmds']
# [-1, 2106, 'HMDS data farm connection is OK:euhmds']
# [-1, 2106, 'HMDS data farm connection is OK:fundfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ushmds']
# Server Version: 76
# TWS Time at connection:20180727 14:28:42 EST
# create_contract
# [-1, 2104, 'Market data farm connection is OK:hfarm']
# [-1, 2104, 'Market data farm connection is OK:jfarm']
# [-1, 2104, 'Market data farm connection is OK:eufarm']
# ...

# %%
bd = datetime.strptime(callback.historical_Data[-2][1], '%Y%m%d %H:%M:%S')
data_endtime_ASK = datetime.now().strftime("%Y%m%d %H:%M:%S")
data_endtime_BID = data_endtime_ASK

# %%
time.sleep(12)
callback = IBWrapper()             # Instantiate IBWrapper. callback 
tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
tws.eConnect(host, port, clientId) # Connect to TWS
create = contract()                # Instantiate contract class
contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
callback.initiate_variables()
tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_BID,
                          "800 S", 
                          #"30 secs",
                          "5 secs", 
                          "BID", 
                          0, 
                          1)
time.sleep(2)
print(callback.historical_Data[0][1])
Time_ = datetime.strptime(callback.historical_Data[0][1], '%Y%m%d %H:%M:%S') 
Time=Time_
filename = "BID_book1.xls"
if not os.path.exists(filename):
    workbook = xlwt.Workbook() # Create an new Excel file and add a worksheet.
    worksheet = workbook.add_sheet('001') #add worksheet
    workbook.save(filename)
rb = xlrd.open_workbook("BID_book1.xls",formatting_info=True)
r_sheet = rb.sheet_by_index(0) 
r = r_sheet.nrows
wb = copy(rb) 
sheet = wb.get_sheet(0)
J=0
i=i-1#manually type in

#bd = datetime.strptime(callback.historical_Data[-2][1], '%Y%m%d %H:%M:%S')
#sheet.write(0, 0, "callback.historical_Data[0][1]")
while J<(len(callback.historical_Data)-1):
    #print("Time"+str(Time))
    #print("bd"+str(bd))
    if Time>bd:
        #print(J)
        #print()
        #sheet.write(0, 0, str(callback.historical_Data[0][1]))
        sheet.write(i, 0, callback.historical_Data[J][1])
        sheet.write(i, 1, callback.historical_Data[J][2])
        sheet.write(i, 2, callback.historical_Data[J][3])
        sheet.write(i, 3, callback.historical_Data[J][4])
        sheet.write(i, 4, callback.historical_Data[J][5])
        i=i+1
    Time=datetime.strptime(callback.historical_Data[J][1], '%Y%m%d %H:%M:%S')  
    J=J+1
    
wb.save("BID_book1.xls")
tws.eDisconnect()
# Out:
# Server Version: 76
# TWS Time at connection:20180727 14:33:43 EST
# create_contract
# [-1, 2104, 'Market data farm connection is OK:hfarm']
# [-1, 2104, 'Market data farm connection is OK:jfarm']
# [-1, 2104, 'Market data farm connection is OK:eufarm']
# [-1, 2104, 'Market data farm connection is OK:usfuture']
# [-1, 2104, 'Market data farm connection is OK:cashfarm']
# [-1, 2104, 'Market data farm connection is OK:usfarm.us']
# [-1, 2104, 'Market data farm connection is OK:usfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ilhmds']
# [-1, 2106, 'HMDS data farm connection is OK:euhmds']
# [-1, 2106, 'HMDS data farm connection is OK:fundfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ushmds']
# 20180727  14:19:50

# %%
import gc
gc.collect()
time.sleep(2)
clientId=clientId+1
reqId = reqId + 1
callback = IBWrapper()             # Instantiate IBWrapper. callback 
tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
tws.eConnect(host, port, clientId) # Connect to TWS
create = contract()                # Instantiate contract class
contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
callback.initiate_variables()
tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_ASK,
                          "800 S", 
                          #"30 secs",
                          "5 secs", 
                          "ASK", 
                          0, 
                          1)
time.sleep(2)
print(callback.historical_Data[0][1])
Time = Time_
filename = "ASK_book1.xls"
if not os.path.exists(filename):
    workbook = xlwt.Workbook() # Create an new Excel file and add a worksheet.
    worksheet = workbook.add_sheet('001') #add worksheet
    workbook.save(filename)
rb = xlrd.open_workbook("ASK_book1.xls",formatting_info=True)
r_sheet = rb.sheet_by_index(0) 
r = r_sheet.nrows
wb = copy(rb) 
sheet = wb.get_sheet(0)
J=0
I=I-1#manually type in

#bd = datetime.strptime(callback.historical_Data[-2][1], '%Y%m%d %H:%M:%S')
#sheet.write(0, 0, "callback.historical_Data[0][1]")
while J<(len(callback.historical_Data)-1):
    #print("Time"+str(Time))
    #print("bd"+str(bd))
    if Time>bd:
        #print(J)
        #print()
        #sheet.write(0, 0, str(callback.historical_Data[0][1]))
        sheet.write(I, 0, callback.historical_Data[J][1])
        sheet.write(I, 1, callback.historical_Data[J][2])
        sheet.write(I, 2, callback.historical_Data[J][3])
        sheet.write(I, 3, callback.historical_Data[J][4])
        sheet.write(I, 4, callback.historical_Data[J][5])
        I=I+1
    Time=datetime.strptime(callback.historical_Data[J][1], '%Y%m%d %H:%M:%S')  
    J=J+1
    
wb.save("ASK_book1.xls")
tws.eDisconnect()
# Out:
# Server Version: 76
# TWS Time at connection:20180727 14:35:01 EST
# create_contract
# [-1, 2104, 'Market data farm connection is OK:hfarm']
# [-1, 2104, 'Market data farm connection is OK:jfarm']
# [-1, 2104, 'Market data farm connection is OK:eufarm']
# [-1, 2104, 'Market data farm connection is OK:usfuture']
# [-1, 2104, 'Market data farm connection is OK:cashfarm']
# [-1, 2104, 'Market data farm connection is OK:usfarm.us']
# [-1, 2104, 'Market data farm connection is OK:usfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ilhmds']
# [-1, 2106, 'HMDS data farm connection is OK:euhmds']
# [-1, 2106, 'HMDS data farm connection is OK:fundfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ushmds']
# 20180727  14:19:50

# %%
print(reqId)
print(clientId)
#reqId = 385
#clientId = 15104
# Out:
# 563
# 15317

# %%
import gc
gc.collect()
bd = Time
clientId=clientId+1
reqId = reqId + 1
data_endtime_ASK = datetime.now().strftime("%Y%m%d %H:%M:%S")
data_endtime_BID = data_endtime_ASK
time.sleep(14)
callback = IBWrapper()             # Instantiate IBWrapper. callback 
tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
tws.eConnect(host, port, clientId) # Connect to TWS
create = contract()                # Instantiate contract class
contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
callback.initiate_variables()
tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_BID,
                          "800 S", 
                          #"30 secs",
                          "5 secs", 
                          "BID", 
                          0, 
                          1)
time.sleep(2)
print(callback.historical_Data[0][1])
Time_ = datetime.strptime(callback.historical_Data[0][1], '%Y%m%d %H:%M:%S') 
Time=Time_
filename = "BID_book1.xls"
if not os.path.exists(filename):
    workbook = xlwt.Workbook() # Create an new Excel file and add a worksheet.
    worksheet = workbook.add_sheet('001') #add worksheet
    workbook.save(filename)
rb = xlrd.open_workbook("BID_book1.xls",formatting_info=True)
r_sheet = rb.sheet_by_index(0) 
r = r_sheet.nrows
wb = copy(rb) 
sheet = wb.get_sheet(0)
J=0
i=i#manually type in

#bd = datetime.strptime(callback.historical_Data[-2][1], '%Y%m%d %H:%M:%S')
#sheet.write(0, 0, "callback.historical_Data[0][1]")
while J<(len(callback.historical_Data)-1):
    #print("Time"+str(Time))
    #print("bd"+str(bd))
    if Time>bd:
        #print(J)
        #print()
        #sheet.write(0, 0, str(callback.historical_Data[0][1]))
        sheet.write(i, 0, callback.historical_Data[J][1])
        sheet.write(i, 1, callback.historical_Data[J][2])
        sheet.write(i, 2, callback.historical_Data[J][3])
        sheet.write(i, 3, callback.historical_Data[J][4])
        sheet.write(i, 4, callback.historical_Data[J][5])
        i=i+1
    Time=datetime.strptime(callback.historical_Data[J][1], '%Y%m%d %H:%M:%S')  
    J=J+1
    
wb.save("BID_book1.xls")
tws.eDisconnect()


time.sleep(2)
clientId=clientId+1
reqId = reqId + 1
callback = IBWrapper()             # Instantiate IBWrapper. callback 
tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
tws.eConnect(host, port, clientId) # Connect to TWS
create = contract()                # Instantiate contract class
contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
callback.initiate_variables()
tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_ASK,
                          "800 S", 
                          #"30 secs",
                          "5 secs", 
                          "ASK", 
                          0, 
                          1)
time.sleep(2)
print(callback.historical_Data[0][1])
Time = Time_
filename = "ASK_book1.xls"
if not os.path.exists(filename):
    workbook = xlwt.Workbook() # Create an new Excel file and add a worksheet.
    worksheet = workbook.add_sheet('001') #add worksheet
    workbook.save(filename)
rb = xlrd.open_workbook("ASK_book1.xls",formatting_info=True)
r_sheet = rb.sheet_by_index(0) 
r = r_sheet.nrows
wb = copy(rb) 
sheet = wb.get_sheet(0)
J=0
I=I#manually type in

#bd = datetime.strptime(callback.historical_Data[-2][1], '%Y%m%d %H:%M:%S')
#sheet.write(0, 0, "callback.historical_Data[0][1]")
while J<(len(callback.historical_Data)-1):
    #print("Time"+str(Time))
    #print("bd"+str(bd))
    if Time>bd:
        #print(J)
        #print()
        #sheet.write(0, 0, str(callback.historical_Data[0][1]))
        sheet.write(I, 0, callback.historical_Data[J][1])
        sheet.write(I, 1, callback.historical_Data[J][2])
        sheet.write(I, 2, callback.historical_Data[J][3])
        sheet.write(I, 3, callback.historical_Data[J][4])
        sheet.write(I, 4, callback.historical_Data[J][5])
        I=I+1
    Time=datetime.strptime(callback.historical_Data[J][1], '%Y%m%d %H:%M:%S')  
    J=J+1
    
wb.save("ASK_book1.xls")
tws.eDisconnect()
# Out:
# Server Version: 76
# TWS Time at connection:20180727 14:35:54 EST
# create_contract
# [-1, 2104, 'Market data farm connection is OK:hfarm']
# [-1, 2104, 'Market data farm connection is OK:jfarm']
# [-1, 2104, 'Market data farm connection is OK:eufarm']
# [-1, 2104, 'Market data farm connection is OK:usfuture']
# [-1, 2104, 'Market data farm connection is OK:cashfarm']
# [-1, 2104, 'Market data farm connection is OK:usfarm.us']
# [-1, 2104, 'Market data farm connection is OK:usfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ilhmds']
# [-1, 2106, 'HMDS data farm connection is OK:euhmds']
# [-1, 2106, 'HMDS data farm connection is OK:fundfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ushmds']
# 20180727  14:22:20
# Server Version: 76
# TWS Time at connection:20180727 14:35:59 EST
# create_contract
# [-1, 2104, 'Market data farm connection is OK:hfarm']
# [-1, 2104, 'Market data farm connection is OK:jfarm']
# [-1, 2104, 'Market data farm connection is OK:eufarm']
# ...

# %%
import gc
gc.collect()
bd = Time
reqId = reqId+1
clientId = clientId+1

data_endtime_ASK = datetime.now().strftime("%Y%m%d %H:%M:%S")
data_endtime_BID = data_endtime_ASK
time.sleep(14)
callback = IBWrapper()             # Instantiate IBWrapper. callback 
tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
tws.eConnect(host, port, clientId) # Connect to TWS
create = contract()                # Instantiate contract class
contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
callback.initiate_variables()
tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_BID,
                          "800 S", 
                          #"30 secs",
                          "5 secs", 
                          "BID", 
                          0, 
                          1)
time.sleep(2)
print(callback.historical_Data[0][1])
Time_ = datetime.strptime(callback.historical_Data[0][1], '%Y%m%d %H:%M:%S') 
Time=Time_
filename = "BID_book1.xls"
if not os.path.exists(filename):
    workbook = xlwt.Workbook() # Create an new Excel file and add a worksheet.
    worksheet = workbook.add_sheet('001') #add worksheet
    workbook.save(filename)
rb = xlrd.open_workbook("BID_book1.xls",formatting_info=True)
r_sheet = rb.sheet_by_index(0) 
r = r_sheet.nrows
wb = copy(rb) 
sheet = wb.get_sheet(0)
J=0
i=i#manually type in

#bd = datetime.strptime(callback.historical_Data[-2][1], '%Y%m%d %H:%M:%S')
#sheet.write(0, 0, "callback.historical_Data[0][1]")
while J<(len(callback.historical_Data)-1):
    #print("Time"+str(Time))
    #print("bd"+str(bd))
    if Time>bd:
        #print(J)
        #print()
        #sheet.write(0, 0, str(callback.historical_Data[0][1]))
        sheet.write(i, 0, callback.historical_Data[J][1])
        sheet.write(i, 1, callback.historical_Data[J][2])
        sheet.write(i, 2, callback.historical_Data[J][3])
        sheet.write(i, 3, callback.historical_Data[J][4])
        sheet.write(i, 4, callback.historical_Data[J][5])
        i=i+1
    Time=datetime.strptime(callback.historical_Data[J][1], '%Y%m%d %H:%M:%S')  
    J=J+1
    
wb.save("BID_book1.xls")
tws.eDisconnect()


time.sleep(2)
clientId=clientId+1
reqId = reqId + 1
callback = IBWrapper()             # Instantiate IBWrapper. callback 
tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
tws.eConnect(host, port, clientId) # Connect to TWS
create = contract()                # Instantiate contract class
contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
callback.initiate_variables()
tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_ASK,
                          "800 S", 
                          #"30 secs",
                          "5 secs", 
                          "ASK", 
                          0, 
                          1)
time.sleep(2)
print(callback.historical_Data[0][1])
Time = Time_
filename = "ASK_book1.xls"
if not os.path.exists(filename):
    workbook = xlwt.Workbook() # Create an new Excel file and add a worksheet.
    worksheet = workbook.add_sheet('001') #add worksheet
    workbook.save(filename)
rb = xlrd.open_workbook("ASK_book1.xls",formatting_info=True)
r_sheet = rb.sheet_by_index(0) 
r = r_sheet.nrows
wb = copy(rb) 
sheet = wb.get_sheet(0)
J=0
I=I#manually type in

#bd = datetime.strptime(callback.historical_Data[-2][1], '%Y%m%d %H:%M:%S')
#sheet.write(0, 0, "callback.historical_Data[0][1]")
while J<(len(callback.historical_Data)-1):
    #print("Time"+str(Time))
    #print("bd"+str(bd))
    if Time>bd:
        #print(J)
        #print()
        #sheet.write(0, 0, str(callback.historical_Data[0][1]))
        sheet.write(I, 0, callback.historical_Data[J][1])
        sheet.write(I, 1, callback.historical_Data[J][2])
        sheet.write(I, 2, callback.historical_Data[J][3])
        sheet.write(I, 3, callback.historical_Data[J][4])
        sheet.write(I, 4, callback.historical_Data[J][5])
        I=I+1
    Time=datetime.strptime(callback.historical_Data[J][1], '%Y%m%d %H:%M:%S')  
    J=J+1
    
wb.save("ASK_book1.xls")
tws.eDisconnect()
# Out:
# Server Version: 76
# TWS Time at connection:20180727 14:38:43 EST
# create_contract
# [-1, 2104, 'Market data farm connection is OK:hfarm']
# [-1, 2104, 'Market data farm connection is OK:jfarm']
# [-1, 2104, 'Market data farm connection is OK:eufarm']
# [-1, 2104, 'Market data farm connection is OK:usfuture']
# [-1, 2104, 'Market data farm connection is OK:cashfarm']
# [-1, 2104, 'Market data farm connection is OK:usfarm.us']
# [-1, 2104, 'Market data farm connection is OK:usfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ilhmds']
# [-1, 2106, 'HMDS data farm connection is OK:euhmds']
# [-1, 2106, 'HMDS data farm connection is OK:fundfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ushmds']
# 20180727  14:25:10
# Server Version: 76
# TWS Time at connection:20180727 14:38:48 EST
# create_contract
# [-1, 2104, 'Market data farm connection is OK:hfarm']
# [-1, 2104, 'Market data farm connection is OK:jfarm']
# [-1, 2104, 'Market data farm connection is OK:eufarm']
# ...

# %%
import gc
gc.collect()
bd = Time
reqId = reqId+1
clientId = clientId+1

data_endtime_ASK = datetime.now().strftime("%Y%m%d %H:%M:%S")
data_endtime_BID = data_endtime_ASK
time.sleep(14)
callback = IBWrapper()             # Instantiate IBWrapper. callback 
tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
tws.eConnect(host, port, clientId) # Connect to TWS
create = contract()                # Instantiate contract class
contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
callback.initiate_variables()
tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_BID,
                          "800 S", 
                          #"30 secs",
                          "5 secs", 
                          "BID", 
                          0, 
                          1)
time.sleep(2)
print(callback.historical_Data[0][1])
Time_ = datetime.strptime(callback.historical_Data[0][1], '%Y%m%d %H:%M:%S') 
Time=Time_
filename = "BID_book1.xls"
if not os.path.exists(filename):
    workbook = xlwt.Workbook() # Create an new Excel file and add a worksheet.
    worksheet = workbook.add_sheet('001') #add worksheet
    workbook.save(filename)
rb = xlrd.open_workbook("BID_book1.xls",formatting_info=True)
r_sheet = rb.sheet_by_index(0) 
r = r_sheet.nrows
wb = copy(rb) 
sheet = wb.get_sheet(0)
J=0
i=i#manually type in

#bd = datetime.strptime(callback.historical_Data[-2][1], '%Y%m%d %H:%M:%S')
#sheet.write(0, 0, "callback.historical_Data[0][1]")
while J<(len(callback.historical_Data)-1):
    #print("Time"+str(Time))
    #print("bd"+str(bd))
    if Time>bd:
        #print(J)
        #print()
        #sheet.write(0, 0, str(callback.historical_Data[0][1]))
        sheet.write(i, 0, callback.historical_Data[J][1])
        sheet.write(i, 1, callback.historical_Data[J][2])
        sheet.write(i, 2, callback.historical_Data[J][3])
        sheet.write(i, 3, callback.historical_Data[J][4])
        sheet.write(i, 4, callback.historical_Data[J][5])
        i=i+1
    Time=datetime.strptime(callback.historical_Data[J][1], '%Y%m%d %H:%M:%S')  
    J=J+1
    
wb.save("BID_book1.xls")
tws.eDisconnect()


time.sleep(2)
clientId=clientId+1
reqId = reqId + 1
callback = IBWrapper()             # Instantiate IBWrapper. callback 
tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
tws.eConnect(host, port, clientId) # Connect to TWS
create = contract()                # Instantiate contract class
contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
callback.initiate_variables()
tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_ASK,
                          "800 S", 
                          #"30 secs",
                          "5 secs", 
                          "ASK", 
                          0, 
                          1)
time.sleep(2)
print(callback.historical_Data[0][1])
Time = Time_
filename = "ASK_book1.xls"
if not os.path.exists(filename):
    workbook = xlwt.Workbook() # Create an new Excel file and add a worksheet.
    worksheet = workbook.add_sheet('001') #add worksheet
    workbook.save(filename)
rb = xlrd.open_workbook("ASK_book1.xls",formatting_info=True)
r_sheet = rb.sheet_by_index(0) 
r = r_sheet.nrows
wb = copy(rb) 
sheet = wb.get_sheet(0)
J=0
I=I#manually type in

#bd = datetime.strptime(callback.historical_Data[-2][1], '%Y%m%d %H:%M:%S')
#sheet.write(0, 0, "callback.historical_Data[0][1]")
while J<(len(callback.historical_Data)-1):
    #print("Time"+str(Time))
    #print("bd"+str(bd))
    if Time>bd:
        #print(J)
        #print()
        #sheet.write(0, 0, str(callback.historical_Data[0][1]))
        sheet.write(I, 0, callback.historical_Data[J][1])
        sheet.write(I, 1, callback.historical_Data[J][2])
        sheet.write(I, 2, callback.historical_Data[J][3])
        sheet.write(I, 3, callback.historical_Data[J][4])
        sheet.write(I, 4, callback.historical_Data[J][5])
        I=I+1
    Time=datetime.strptime(callback.historical_Data[J][1], '%Y%m%d %H:%M:%S')  
    J=J+1
    
wb.save("ASK_book1.xls")
tws.eDisconnect()
# Out:
# Server Version: 76
# TWS Time at connection:20180727 14:39:18 EST
# create_contract
# [-1, 2104, 'Market data farm connection is OK:hfarm']
# [-1, 2104, 'Market data farm connection is OK:jfarm']
# [-1, 2104, 'Market data farm connection is OK:eufarm']
# [-1, 2104, 'Market data farm connection is OK:usfuture']
# [-1, 2104, 'Market data farm connection is OK:cashfarm']
# [-1, 2104, 'Market data farm connection is OK:usfarm.us']
# [-1, 2104, 'Market data farm connection is OK:usfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ilhmds']
# [-1, 2106, 'HMDS data farm connection is OK:euhmds']
# [-1, 2106, 'HMDS data farm connection is OK:fundfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ushmds']
# 20180727  14:25:45
# Server Version: 76
# TWS Time at connection:20180727 14:39:23 EST
# create_contract
# [-1, 2104, 'Market data farm connection is OK:hfarm']
# [-1, 2104, 'Market data farm connection is OK:jfarm']
# [-1, 2104, 'Market data farm connection is OK:eufarm']
# ...

# %%
import gc
gc.collect()
bd = Time
reqId = reqId+1
clientId = clientId+1

data_endtime_ASK = datetime.now().strftime("%Y%m%d %H:%M:%S")
data_endtime_BID = data_endtime_ASK
time.sleep(14)
callback = IBWrapper()             # Instantiate IBWrapper. callback 
tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
tws.eConnect(host, port, clientId) # Connect to TWS
create = contract()                # Instantiate contract class
contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
callback.initiate_variables()
tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_BID,
                          "800 S", 
                          #"30 secs",
                          "5 secs", 
                          "BID", 
                          0, 
                          1)
time.sleep(2)
print(callback.historical_Data[0][1])
Time_ = datetime.strptime(callback.historical_Data[0][1], '%Y%m%d %H:%M:%S') 
Time=Time_
filename = "BID_book1.xls"
if not os.path.exists(filename):
    workbook = xlwt.Workbook() # Create an new Excel file and add a worksheet.
    worksheet = workbook.add_sheet('001') #add worksheet
    workbook.save(filename)
rb = xlrd.open_workbook("BID_book1.xls",formatting_info=True)
r_sheet = rb.sheet_by_index(0) 
r = r_sheet.nrows
wb = copy(rb) 
sheet = wb.get_sheet(0)
J=0
i=i#manually type in

#bd = datetime.strptime(callback.historical_Data[-2][1], '%Y%m%d %H:%M:%S')
#sheet.write(0, 0, "callback.historical_Data[0][1]")
while J<(len(callback.historical_Data)-1):
    #print("Time"+str(Time))
    #print("bd"+str(bd))
    if Time>bd:
        #print(J)
        #print()
        #sheet.write(0, 0, str(callback.historical_Data[0][1]))
        sheet.write(i, 0, callback.historical_Data[J][1])
        sheet.write(i, 1, callback.historical_Data[J][2])
        sheet.write(i, 2, callback.historical_Data[J][3])
        sheet.write(i, 3, callback.historical_Data[J][4])
        sheet.write(i, 4, callback.historical_Data[J][5])
        i=i+1
    Time=datetime.strptime(callback.historical_Data[J][1], '%Y%m%d %H:%M:%S')  
    J=J+1
    
wb.save("BID_book1.xls")
tws.eDisconnect()

time.sleep(2)
clientId=clientId+1
reqId = reqId + 1
callback = IBWrapper()             # Instantiate IBWrapper. callback 
tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
tws.eConnect(host, port, clientId) # Connect to TWS
create = contract()                # Instantiate contract class
contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
callback.initiate_variables()
tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_ASK,
                          "800 S", 
                          #"30 secs",
                          "5 secs", 
                          "ASK", 
                          0, 
                          1)
time.sleep(2)
print(callback.historical_Data[0][1])
Time = Time_
filename = "ASK_book1.xls"
if not os.path.exists(filename):
    workbook = xlwt.Workbook() # Create an new Excel file and add a worksheet.
    worksheet = workbook.add_sheet('001') #add worksheet
    workbook.save(filename)
rb = xlrd.open_workbook("ASK_book1.xls",formatting_info=True)
r_sheet = rb.sheet_by_index(0) 
r = r_sheet.nrows
wb = copy(rb) 
sheet = wb.get_sheet(0)
J=0
I=I#manually type in

#bd = datetime.strptime(callback.historical_Data[-2][1], '%Y%m%d %H:%M:%S')
#sheet.write(0, 0, "callback.historical_Data[0][1]")
while J<(len(callback.historical_Data)-1):
    #print("Time"+str(Time))
    #print("bd"+str(bd))
    if Time>bd:
        #print(J)
        #print()
        #sheet.write(0, 0, str(callback.historical_Data[0][1]))
        sheet.write(I, 0, callback.historical_Data[J][1])
        sheet.write(I, 1, callback.historical_Data[J][2])
        sheet.write(I, 2, callback.historical_Data[J][3])
        sheet.write(I, 3, callback.historical_Data[J][4])
        sheet.write(I, 4, callback.historical_Data[J][5])
        I=I+1
    Time=datetime.strptime(callback.historical_Data[J][1], '%Y%m%d %H:%M:%S')  
    J=J+1
    
wb.save("ASK_book1.xls")
tws.eDisconnect()
# Out:
# Server Version: 76
# TWS Time at connection:20180727 14:40:13 EST
# create_contract
# [-1, 2104, 'Market data farm connection is OK:hfarm']
# [-1, 2104, 'Market data farm connection is OK:jfarm']
# [-1, 2104, 'Market data farm connection is OK:eufarm']
# [-1, 2104, 'Market data farm connection is OK:usfuture']
# [-1, 2104, 'Market data farm connection is OK:cashfarm']
# [-1, 2104, 'Market data farm connection is OK:usfarm.us']
# [-1, 2104, 'Market data farm connection is OK:usfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ilhmds']
# [-1, 2106, 'HMDS data farm connection is OK:euhmds']
# [-1, 2106, 'HMDS data farm connection is OK:fundfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ushmds']
# 20180727  14:26:40
# Server Version: 76
# TWS Time at connection:20180727 14:40:18 EST
# create_contract
# [-1, 2104, 'Market data farm connection is OK:hfarm']
# [-1, 2104, 'Market data farm connection is OK:jfarm']
# [-1, 2104, 'Market data farm connection is OK:eufarm']
# ...

# %%
import gc
gc.collect()
bd = Time
reqId = reqId+1
clientId = clientId+1

data_endtime_ASK = datetime.now().strftime("%Y%m%d %H:%M:%S")
data_endtime_BID = data_endtime_ASK
time.sleep(14)
callback = IBWrapper()             # Instantiate IBWrapper. callback 
tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
tws.eConnect(host, port, clientId) # Connect to TWS
create = contract()                # Instantiate contract class
contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
callback.initiate_variables()
tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_BID,
                          "800 S", 
                          #"30 secs",
                          "5 secs", 
                          "BID", 
                          0, 
                          1)
time.sleep(2)
print(callback.historical_Data[0][1])
Time_ = datetime.strptime(callback.historical_Data[0][1], '%Y%m%d %H:%M:%S') 
Time=Time_
filename = "BID_book1.xls"
if not os.path.exists(filename):
    workbook = xlwt.Workbook() # Create an new Excel file and add a worksheet.
    worksheet = workbook.add_sheet('001') #add worksheet
    workbook.save(filename)
rb = xlrd.open_workbook("BID_book1.xls",formatting_info=True)
r_sheet = rb.sheet_by_index(0) 
r = r_sheet.nrows
wb = copy(rb) 
sheet = wb.get_sheet(0)
J=0
i=i#manually type in

#bd = datetime.strptime(callback.historical_Data[-2][1], '%Y%m%d %H:%M:%S')
#sheet.write(0, 0, "callback.historical_Data[0][1]")
while J<(len(callback.historical_Data)-1):
    #print("Time"+str(Time))
    #print("bd"+str(bd))
    if Time>bd:
        #print(J)
        #print()
        #sheet.write(0, 0, str(callback.historical_Data[0][1]))
        sheet.write(i, 0, callback.historical_Data[J][1])
        sheet.write(i, 1, callback.historical_Data[J][2])
        sheet.write(i, 2, callback.historical_Data[J][3])
        sheet.write(i, 3, callback.historical_Data[J][4])
        sheet.write(i, 4, callback.historical_Data[J][5])
        i=i+1
    Time=datetime.strptime(callback.historical_Data[J][1], '%Y%m%d %H:%M:%S')  
    J=J+1
    
wb.save("BID_book1.xls")
tws.eDisconnect()

time.sleep(2)
clientId=clientId+1
reqId = reqId + 1
callback = IBWrapper()             # Instantiate IBWrapper. callback 
tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
tws.eConnect(host, port, clientId) # Connect to TWS
create = contract()                # Instantiate contract class
contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
callback.initiate_variables()
tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_ASK,
                          "800 S", 
                          #"30 secs",
                          "5 secs", 
                          "ASK", 
                          0, 
                          1)
time.sleep(2)
print(callback.historical_Data[0][1])
Time = Time_
filename = "ASK_book1.xls"
if not os.path.exists(filename):
    workbook = xlwt.Workbook() # Create an new Excel file and add a worksheet.
    worksheet = workbook.add_sheet('001') #add worksheet
    workbook.save(filename)
rb = xlrd.open_workbook("ASK_book1.xls",formatting_info=True)
r_sheet = rb.sheet_by_index(0) 
r = r_sheet.nrows
wb = copy(rb) 
sheet = wb.get_sheet(0)
J=0
I=I#manually type in

#bd = datetime.strptime(callback.historical_Data[-2][1], '%Y%m%d %H:%M:%S')
#sheet.write(0, 0, "callback.historical_Data[0][1]")
while J<(len(callback.historical_Data)-1):
    #print("Time"+str(Time))
    #print("bd"+str(bd))
    if Time>bd:
        #print(J)
        #print()
        #sheet.write(0, 0, str(callback.historical_Data[0][1]))
        sheet.write(I, 0, callback.historical_Data[J][1])
        sheet.write(I, 1, callback.historical_Data[J][2])
        sheet.write(I, 2, callback.historical_Data[J][3])
        sheet.write(I, 3, callback.historical_Data[J][4])
        sheet.write(I, 4, callback.historical_Data[J][5])
        I=I+1
    Time=datetime.strptime(callback.historical_Data[J][1], '%Y%m%d %H:%M:%S')  
    J=J+1
    
wb.save("ASK_book1.xls")
tws.eDisconnect()
# Out:
# Server Version: 76
# TWS Time at connection:20180727 14:44:36 EST
# create_contract
# [-1, 2104, 'Market data farm connection is OK:hfarm']
# [-1, 2104, 'Market data farm connection is OK:jfarm']
# [-1, 2104, 'Market data farm connection is OK:eufarm']
# [-1, 2104, 'Market data farm connection is OK:usfuture']
# [-1, 2104, 'Market data farm connection is OK:cashfarm']
# [-1, 2104, 'Market data farm connection is OK:usfarm.us']
# [-1, 2104, 'Market data farm connection is OK:usfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ilhmds']
# [-1, 2106, 'HMDS data farm connection is OK:euhmds']
# [-1, 2106, 'HMDS data farm connection is OK:fundfarm']
# [-1, 2106, 'HMDS data farm connection is OK:ushmds']
# 20180727  14:31:00
# Server Version: 76
# TWS Time at connection:20180727 14:44:41 EST
# create_contract
# [-1, 2104, 'Market data farm connection is OK:hfarm']
# [-1, 2104, 'Market data farm connection is OK:jfarm']
# [-1, 2104, 'Market data farm connection is OK:eufarm']
# ...

# %%
Position = 0
BID_SIZE=0
BID_PRICE=0
ASK_PRICE=0
ASK_SIZE=0
ASK_SIZE=0
LAST_PRICE=0
LAST_SIZE=0
HIGH=0
LOW=0
VOLUME=0
CLOSE_PRICE=0
OPEN_TICK=0
tick_type = {0 : 0,#"BID SIZE",
             1 : 0,#"BID PRICE",
             2 : 0,#"ASK PRICE",
             3 : 0,#"ASK SIZE",
             4 : 0,#"LAST PRICE",
             5 : 0,#"LAST SIZE",
             6 : 0,#"HIGH",
             7 : 0,#"LOW",
             8 : 0,#"VOLUME",
             9 : 0,#"CLOSE PRICE",
             10 : 0,#"BID OPTION COMPUTATION",
             11 : 0,#"ASK OPTION COMPUTATION",
             12 : 0,#"LAST OPTION COMPUTATION",
             13 : 0,#"MODEL OPTION COMPUTATION",
             14 : 0,#"OPEN_TICK",
             15 : 0,#"LOW 13 WEEK",
             16 : 0,#"HIGH 13 WEEK",
             17 : 0,#"LOW 26 WEEK",
             18 : 0,#"HIGH 26 WEEK",
             19 : 0,#"LOW 52 WEEK",
             20 : 0,#"HIGH 52 WEEK",
             21 : 0,#"AVG VOLUME",
             22 : 0,#"OPEN INTEREST",
             23 : 0,#"OPTION HISTORICAL VOL",
             24 : 0,#"OPTION IMPLIED VOL",
             27 : 0,#"OPTION CALL OPEN INTEREST",
             28 : 0,#"OPTION PUT OPEN INTEREST",
             29 : 0,#"OPTION CALL VOLUME"
            }
recent_BID_H = callback.historical_Data[J][3]
recent_ASK_H = callback.historical_Data[J][3]
recent_BID_L = callback.historical_Data[J][3]
recent_ASK_L = callback.historical_Data[J][3]
BID_O = callback.historical_Data[J][3]
ASK_O = callback.historical_Data[J][3]
BID_C = callback.historical_Data[J][3]
ASK_C = callback.historical_Data[J][3]

# %%
def g(i,I,Time,reqId,clientId):
    import xlwt
    from xlutils.copy import copy
    import xlrd
    import os.path
    from datetime import datetime 
    from datetime import timedelta
    import time
    bd = Time
    reqId = reqId+1
    clientId = clientId+1

    data_endtime_ASK = datetime.now().strftime("%Y%m%d %H:%M:%S")
    data_endtime_BID = data_endtime_ASK
    time.sleep(14)
    callback = IBWrapper()             # Instantiate IBWrapper. callback 
    tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
    tws.eConnect(host, port, clientId) # Connect to TWS
    create = contract()                # Instantiate contract class
    contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
    callback.initiate_variables()
    tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_BID,
                          "800 S", 
                          #"30 secs",
                          "5 secs", 
                          "BID", 
                          0, 
                          1)
    time.sleep(2)
    print("1"+str(callback.historical_Data[0][1]))
    Time_ = datetime.strptime(callback.historical_Data[0][1], '%Y%m%d %H:%M:%S') 
    Time=Time_
    filename = "BID_book1.xls"
    if not os.path.exists(filename):
        workbook = xlwt.Workbook() # Create an new Excel file and add a worksheet.
        worksheet = workbook.add_sheet('001') #add worksheet
        workbook.save(filename)
    rb = xlrd.open_workbook("BID_book1.xls",formatting_info=True)
    r_sheet = rb.sheet_by_index(0) 
    r = r_sheet.nrows
    wb = copy(rb) 
    sheet = wb.get_sheet(0)
    J=0
    i=i#manually type in

    #bd = datetime.strptime(callback.historical_Data[-2][1], '%Y%m%d %H:%M:%S')
    #sheet.write(0, 0, "callback.historical_Data[0][1]")
    while J<(len(callback.historical_Data)-1):
        #print("Time"+str(Time))
        #print("bd"+str(bd))
        if Time>bd:
            #print(J)
            #print()
            #sheet.write(0, 0, str(callback.historical_Data[0][1]))
            sheet.write(i, 0, callback.historical_Data[J][1])
            sheet.write(i, 1, callback.historical_Data[J][2])
            sheet.write(i, 2, callback.historical_Data[J][3])
            sheet.write(i, 3, callback.historical_Data[J][4])
            sheet.write(i, 4, callback.historical_Data[J][5])
            i=i+1
        Time=datetime.strptime(callback.historical_Data[J][1], '%Y%m%d %H:%M:%S')  
        J=J+1
    
    wb.save("BID_book1.xls")
    tws.eDisconnect()
    
    time.sleep(14)
    clientId=clientId+1
    reqId = reqId + 1
    callback = IBWrapper()             # Instantiate IBWrapper. callback 
    tws = EClientSocket(callback)      # Instantiate EClientSocket and return data to callback
    tws.eConnect(host, port, clientId) # Connect to TWS
    create = contract()                # Instantiate contract class
    contract_Details = create.create_contract("GC", "FUT", "NYMEX", "USD", "201808", "GCN8")
    callback.initiate_variables()
    tws.reqHistoricalData(reqId, 
                          contract_Details, 
                          data_endtime_ASK,
                          "800 S", 
                          #"30 secs",
                          "5 secs", 
                          "ASK", 
                          0, 
                          1)
    time.sleep(2)
    print(callback.historical_Data[0][1])
    Time = Time_
    filename = "ASK_book1.xls"
    if not os.path.exists(filename):
        workbook = xlwt.Workbook() # Create an new Excel file and add a worksheet.
        worksheet = workbook.add_sheet('001') #add worksheet
        workbook.save(filename)
    rb = xlrd.open_workbook("ASK_book1.xls",formatting_info=True)
    r_sheet = rb.sheet_by_index(0) 
    r = r_sheet.nrows
    wb = copy(rb) 
    sheet = wb.get_sheet(0)
    J=0
    I=I#manually type in

    #bd = datetime.strptime(callback.historical_Data[-2][1], '%Y%m%d %H:%M:%S')
    #sheet.write(0, 0, "callback.historical_Data[0][1]")
    while J<(len(callback.historical_Data)-1):
        #print("Time"+str(Time))
        #print("bd"+str(bd))
        if Time>bd:
            #print(J)
            #print()
            #sheet.write(0, 0, str(callback.historical_Data[0][1]))
            sheet.write(I, 0, callback.historical_Data[J][1])
            sheet.write(I, 1, callback.historical_Data[J][2])
            sheet.write(I, 2, callback.historical_Data[J][3])
            sheet.write(I, 3, callback.historical_Data[J][4])
            sheet.write(I, 4, callback.historical_Data[J][5])
            I=I+1
        Time=datetime.strptime(callback.historical_Data[J][1], '%Y%m%d %H:%M:%S')  
        J=J+1
    
    wb.save("ASK_book1.xls")
    tws.eDisconnect()
    import gc
    gc.collect()
    return i,I,Time,reqId,clientId
