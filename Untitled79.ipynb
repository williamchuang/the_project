# %%
import os
import numpy as np
import xlrd
import statistics 
import xlrd

def run():
    y1=[]
    Position=0
    mPosition=0
    mem=0
    number=0
    profit=0
    Bid_k =0
    Ask_k =0
    Bid_j =0
    Ask_j =0
    Now=""
    MD=3000
    c=0
    center=0
    start=0
    grid_up=[]
    grid_down=[]
    
    while c<416:
        fs="Clean"+str(c)+"_5MIN"+"201812GCN8.xls"
        if os.path.isfile(fs):
            print(fs)
            book = xlrd.open_workbook(fs)
            sh = book.sheet_by_index(0)
            i = 0
            while i<sh.nrows:
                Now=sh.cell_value(rowx=i, colx=0)
                Ask_j = Ask_k
                Bid_j = Bid_k
                Bid_k = float(sh.cell_value(rowx=i, colx=4))#Ask_k-0.5 
                Ask_k = Bid_k+0.5#float(sh.cell_value(rowx=i, colx=9)) #
                if start==0:
                    start=1
                    center=(Bid_k+Ask_k)/2
                    for e in range(center,center+100):
                        grid_up.append(e)
                        e+=5
                    for e in range(center-100,center):
                        grid_down.append(e)
                        e+=5    
                    
                if len(maprice)<240:
                    maprice.append((Bid_k+Ask_k)/2)
                if len(maprice)>=240:
                    maprice.pop(0)
                    maprice.append((Bid_k+Ask_k)/2)
                if len(maprice)>=240:
                    ma.append(np.mean(maprice[-240:]))
                
                if len(ma)>0:
                    dis=abs((Ask_k+Bid_k)/2-ma[-1])
                    dir_dis=(Ask_k+Bid_k)/2-ma[-1]
                if Now[0:4]=="2018":
                    y1.append(profit)
                if len(ma)>0:
                    if Now[0:4]=="2018" and Position==0:
                        if icol[-1]>0 and dir_dis<1.6:
                            mPosition=1
                            
                        if icol[-1]<0 and dir_dis>-1.6:
                            mPosition=-1
                            
                    
                    if Position>0:
                        if dir_dis>5:
                            mPosition=0
                    if Position<0:
                        if dir_dis<-5:
                            mPosition=0   
                i=i+1    
                ############################################################################## 
                if Position==0 and mPosition==1:# and Ask_k-Bid_k<1:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print(Now)
                    mem=Ask_k
                    print(Ask_k)
                    print(1)
                    number=number+1
                    Position=1
                elif Position==0 and mPosition==-1:# and Ask_k-Bid_k<1:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print(Now)
                    mem=Bid_k
                    print(Bid_k)
                    print(-1)
                    number=number+1
                    Position=-1
                elif Position==1 and mPosition==0:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print(Now)
                    profit=profit+(Bid_k-mem)
                    number=number+1
                    print(Bid_k)
                    print(mem)
                    print(Bid_k-mem)
                    print("A")
                    print(-1)
                    Position=0
                elif Position==-1 and mPosition==0:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print(Now)
                    profit=profit+(mem-Ask_k)
                    number=number+1
                    print(mem-Ask_k)
                    print("B")
                    print(Ask_k)
                    print(1)
                    Position=0
                elif Position==-1 and mPosition==1:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print(Now)
                    profit=profit+(mem-Ask_k)
                    print(mem-Ask_k)
                    
                    print("C")
                    number=number+1
                    print(1)
                    mem=Ask_k
                    print(Ask_k)
                    print(1)
                    number=number+1
                    Position=1
                elif Position==1 and mPosition==-1: 
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print(Now)
                    profit=profit+(Bid_k-mem)
                    print(Bid_k-mem)
                    print("D")
                    number=number+1
                    print(-1)
                    mem=Bid_k
                    print(Bid_k)
                    print(-1)
                    number=number+1
                    Position=-1
        c+=1
    print("profit:"+str(profit))  
    print("number"+str(number))
    tot=100*profit-(2.37*number)
    print("tot:"+str(tot))
    print("Position:"+str(Position))
    return y1
