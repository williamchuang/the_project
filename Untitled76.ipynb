# %%
import os
import numpy as np
import xlrd
import statistics 
import xlrd
def Maximum(l):
    k=-1
    for e in l:
        if e>k:
            k=e
    return k
def minimum(l):
    k=-1
    for e in l:
        if e<k:
            k=e
    return k    
def run():
    output=[]
    InitialSMA9=[]
    InitialSMA12=[]
    InitialSMA26=[]
    period_10 = 10
    period_20 = 20
    period_320 = 320
    period_240 = 240
    H_len=240#13
    H_o=[]
    H_h_len=100
    H_h=[]
    H_l_len=100
    H_l=[]
    H_c_len=100
    H_c=[]
    MA20 = []
    MA10 = []
    MA240 = []
    MA320 = []
    avei=0
    aveii=0
    Position=0
    mPosition=0
    unrealised=0
    mem=0
    number=0
    diff=0
    profit=0
    tmp = []
    Bid_k =0
    Ask_k =0
    ma10_k = 0
    ma20_k = 0
    ma240_k =0
    ma320_k =0
    bb320sig1up_k=0
    bb320sig1down_k=0
    bb320sig2up_k=0
    bb320sig2down_k=0
    Bid_j =0
    Ask_j =0
    ma10_j = 0
    ma20_j = 0
    ma240_j =0
    ma320_j =0
    bb320sig1up_j=0
    bb320sig1down_j=0
    bb320sig2up_j=0
    bb320sig2down_j=0
    std=0
    listj=[0,0,0,0,0,0]
    listk=[0,0,0,0,0,0]
    Now=""
    direction=0
    f=0
    count=0
    dlong=[]
    period_dlong=1.5*period_320
    h=0
    light=0
    period_5=3
    MA5=[]
    ma5_j = 0
    ma5_k = 0
    step1=0
    step2=0
    c=0#356#0
    h=-1000
    l_=4000
    bias=[]
    bb=[]
    membias=0
    MD=3000
    counter=0
    
    c=0
    yesterday=[]
    b4y=[]
    ema12=[]
    #Multiplier: (2 / (Time periods + 1) ) = (2 / (10 + 1) ) = 0.1818 (18.18%)
    m9=(2/(9+1))
    m12=(2/(12+1))
    m26=(2/(26+1))
    ema26=[]
    macd=[]
    sig=[]
    his=[]
    smsa=[]
    ssma=[]
    icol=[]
    r=[]
    counter=0
    l1=[]
    I=[]
    A=0
    B=0
    C=0
    D=0
    E=0
    F=0
    l2=[]
    S4=0
    mS4=0
    I=0
    hr_o=[]
    hr_oc=0
    hr_h=[]
    hr_hc=0
    hr_l=[]
    hr_lc=10000
    hr_c=[]
    hr_cc=0
    hr_counter=0
    mprice=[]
    period=20
    vvv=[]
    wwwma=[]
    www=[]
    y1=[]
    y2=[]
    y3=[]
    y0=[]
    TR=[]
    pdm1=[]
    ndm1=[]
    TR14=[]
    pdm14=[]
    ndm14=[]
    pdi14=[]
    ndi14=[]
    di14diff=[]
    di14sum=[]
    xd=[]
    xda=[]
    mdi=0
    mwww=0
    stop=0
    III=0
    MDD=0
    axda=[]
    maprice=[]
    ma=[]
    n=1
    N=1
    initial=36086
    four_hr_counter=0
    four_hr_o=[]
    four_hr_oc=0
    four_hr_h=[]
    four_hr_hc=0
    four_hr_l=[]
    four_hr_lc=10000
    four_hr_c=[]
    four_hr_cc=0
    four_maprice=[]
    four_ma=[]
    smsa=[]
    ssma=[]
    icol=[]
    r=[]
    l1=[]
    I=[]
    A=0
    B=0
    C=0
    D=0
    E=0
    F=0
    l2=[]
    S4=0
    mS4=0
    I=0
    limit=80
    while c<418:
        
        fs="Clean"+str(c)+"_5MIN"+"201812GCN8.xls"
        if os.path.isfile(fs):
            print(fs)
            book = xlrd.open_workbook(fs)
            sh = book.sheet_by_index(0)
            i = 0
            while i<sh.nrows:

                Now=sh.cell_value(rowx=i, colx=0)
                #print(Now[10:12])
                Ask_j = Ask_k
                Bid_j = Bid_k
            
                Bid_k = float(sh.cell_value(rowx=i, colx=4))#Ask_k-0.5 #float(sh.cell_value(rowx=i, colx=4))float(sh.cell_value(rowx=i, colx=4))
                Ask_k = float(sh.cell_value(rowx=i, colx=9)) #
                #print('#'+str(Now)+": "+str(Ask_k))
                tot=100*profit-(2.37*number)+initial
                if tot>4000 and len(axda)>0:
                    n=0
                    if axda[-1]>=18:
                        n=int(tot/4000)
                    elif axda[-1]>=16 and axda[-1]<18:
                        n=int(int(tot/4000)*0.9)
                    elif axda[-1]>=15 and axda[-1]<16:
                        n=int(int(tot/4000)*0.8)
                    elif axda[-1]>=14 and axda[-1]<15:
                        n=int(int(tot/4000)*0.7)
                    elif axda[-1]>=13 and axda[-1]<14:
                        n=int(int(tot/4000)*0.6)
                    elif axda[-1]>=12 and axda[-1]<13:
                        n=int(int(tot/4000)*0.5)
                    elif axda[-1]>=11 and axda[-1]<12:
                        n=int(int(tot/4000)*0.4)
                    elif axda[-1]>=10 and axda[-1]<11:
                        n=int(int(tot/4000)*0.3)
                    elif axda[-1]>=9 and axda[-1]<10:
                        n=int(int(tot/4000)*0.2)
                    if n==0:
                        n=1
                    if n>N:
                        if Position>0:
                            profit=profit+(Bid_k-mem)*N
                            mem=Bid_k
                        if Position<0:
                            profit=profit+(mem-Ask_k)*N
                            mem=Ask_k
                        number+=n-N
                        N=n
                    if n<N:
                        if Position>0:
                            profit=profit+(Bid_k-mem)*N
                            mem=Bid_k
                        if Position<0:
                            profit=profit+(mem-Ask_k)*N
                            mem=Ask_k
                        number+=N-n
                        N=n

                hr_counter+=1
                
                if len(maprice)<240:
                    maprice.append((Bid_k+Ask_k)/2)
                if len(maprice)>=240:
                    maprice.pop(0)
                    maprice.append((Bid_k+Ask_k)/2)
                if len(maprice)>=240:
                    ma.append(np.mean(maprice[-240:]))
                c_h=(float(sh.cell_value(rowx=i, colx=2))+float(sh.cell_value(rowx=i, colx=7)))/2
                c_l=(float(sh.cell_value(rowx=i, colx=3))+float(sh.cell_value(rowx=i, colx=8)))/2
                four_c_h=(float(sh.cell_value(rowx=i, colx=2))+float(sh.cell_value(rowx=i, colx=7)))/2
                four_c_l=(float(sh.cell_value(rowx=i, colx=3))+float(sh.cell_value(rowx=i, colx=8)))/2
                if four_c_h>four_hr_hc:
                    four_hr_hc=four_c_h
                if four_c_l<four_hr_lc:
                    four_hr_lc=four_c_l
                if four_hr_counter==48: 
                    four_hr_counter=0
                    four_hr_counter=0
                    four_hr_oc=four_hr_cc
                    four_hr_cc=Ask_k #(Bid_k+Ask_k)/2
                    four_hr_o.append(four_hr_oc)
                    four_hr_c.append(four_hr_cc)
                    four_hr_l.append(four_hr_lc)
                    four_hr_lc=10000
                    four_hr_h.append(four_hr_hc)
                    four_hr_hc=0
                    while len(four_hr_o)>2000:
                        four_hr_o.pop(0)
                    while len(four_hr_h)>2000:
                        four_hr_h.pop(0)
                    while len(four_hr_l)>2000:
                        four_hr_l.pop(0)
                    while len(four_hr_c)>2000:
                        four_hr_c.pop(0)
                    if len(four_maprice)<240:
                        four_maprice.append(four_hr_oc[-1])
                    if len(four_maprice)>=240:
                        four_maprice.pop(0)
                        four_maprice.append(four_hr_oc[-1])
                    if len(four_maprice)>=240:
                        four_ma.append(np.mean(four_maprice[-limit:]))
                    if len(four_hr_l)>0:
                        ss_tmp=four_hr_h[-1]-four_hr_l[-1]
                    if len(smsa)<30 and len(four_hr_l)>0:
                        smsa.append(ss_tmp)
                    if len(smsa)>=30 and len(four_hr_l)>0:
                        smsa.append(ss_tmp) 
                        ssma.append(np.mean(smsa))
                    if len(r)<30:
                        r.append(four_hr_oc[-1])
                    if len(r)==30:
                        r.pop(0)
                        r.append(four_hr_oc[-1])
                    if len(r)>3:
                        if len(icol)<30:
                            icol.append(r[-1]-r[-2])
                        if len(icol)>=30:
                            icol.append(r[-1]-r[-2])
                    if len(icol)>4 and len(ssma)>0:
                        l1.append(ssma[-1]*icol[-1]*0.5*icol[-1])
                    ##########
                    if len(l1)>40 and icol[-1]*icol[-2]<0:
                        G1=-2
                        G2=0
                        H1=0
                        H2=0
                        K1=0
                        K2=0
                        counter_j=0
                        counter_i=-2
                        while counter_j<3:
                            counter_i-=1
                            if icol[counter_i]*icol[-2]<0 and counter_j==0:
                                G2=-2
                                H1=counter_i
                                counter_j+=1
                            elif icol[counter_i]*icol[counter_i-1]<0 and counter_j==0:
                                G2=counter_i
                                H1=counter_i-1
                                counter_j+=1
                            elif icol[counter_i]*icol[counter_i-1]<0 and counter_j==1:
                                H2=counter_i
                                K1=counter_i-1
                                counter_j+=1
                            elif icol[counter_i]*icol[counter_i-1]<0 and counter_j==2:
                                K2=counter_i
                                counter_j+=1 
                        S1=0
                        for e in icol[G2:(G1+1)]:
                            S1+=e
                        S2=0
                        for e in icol[H2:(H1+1)]:
                            S2+=e
                        S3=0
                        for e in icol[K2:(K1+1)]:
                            S3+=e
                        A=(ssma[K1]*(S3)-ssma[H1]*(S3+S2))
                        B=icol[K1]-icol[H1]
                        C=(ssma[H1]*(S3+S2)-ssma[K2]*0)
                        D=icol[H1]-icol[K2]
                        E=l1[H1]-l1[K1]
                        F=l1[K2]-l1[H1]
                        k=(F-((C*E)/A))/(D-((C*B)/A))
                        q=(E/A)-((B/A)*k)
                        I=l1[G1]+k*icol[G1]+q*ssma[G1]*(S3+S2+S1)
                        S4=(1/(ssma[-1]*q))*(I-k*icol[G1]-l1[G1])
                ###########
                if hr_counter==16:
                    hr_counter=0
                    hr_oc=hr_cc
                    hr_cc=Ask_k #(Bid_k+Ask_k)/2
                    hr_o.append(hr_oc)
                    hr_c.append(hr_cc)
                    hr_l.append(hr_lc)
                    hr_lc=10000
                    hr_h.append(hr_hc)
                    hr_hc=0
                    while len(hr_o)>2000:
                        hr_o.pop(0)
                    while len(hr_h)>2000:
                        hr_h.pop(0)
                    while len(hr_l)>2000:
                        hr_l.pop(0)
                    while len(hr_c)>2000:
                        hr_c.pop(0)
                    if len(mprice)<period and len(hr_c)>1:
                        mprice.append(hr_c[-1])#(((hr_h[-1])+(hr_l[-1]))/2)
                    if len(mprice)>=period:
                        mprice.append(hr_c[-1])#(((hr_h[-1])+(hr_l[-1]))/2)
                        #mprice.pop(0)

                    if len(mprice)>=period:
                        MA20.append(np.mean(mprice[-1*period:]))
                        vvv.append(statistics.stdev(mprice[-1*period:]))
                        www.append((4*vvv[-1]/MA20[-1]))
                        output.append(www[-1])
                    if len(www)>20:
                        wwwma.append(np.mean(www[-4:-1]))                       
                        y0.append(Now)
                        y1.append(www[-1])
                        y2.append(wwwma[-1])
                    #if Now[0:4]=="2018":
                    #    print(str(Now)+": "+str(Ask_k))
                    
                    
                    if len(hr_l)>1 and len(hr_h)>1 and len(hr_c)>1:
                        val_a=hr_h[-1]-hr_l[-1]
                        val_b=abs(hr_h[-1]-hr_c[-2])
                        val_c=abs(hr_l[-1]-hr_c[-2])
                        tmp_list=[val_a,val_b,val_c]
                        tmp=Maximum(tmp_list)
                        if tmp>0:
                            TR.append(tmp)
                            #print(TR[-1])
                        if (hr_h[-1]-hr_h[-2])>(hr_l[-2]-hr_l[-1]):
                            tmp_list=[0,(hr_h[-1]-hr_h[-2])]
                            pdm1.append(Maximum(tmp_list))
                            #print(pdm1[-1])
                        if (hr_h[-1]-hr_h[-2])<(hr_l[-2]-hr_l[-1]):
                            tmp_list=[0,(hr_l[-2]-hr_l[-1])]
                            ndm1.append(Maximum(tmp_list))
                            #print(ndm1[-1])
                        
                        if len(pdm1)==14 and len(TR)>=14:
                            TR14.append(sum(i for i in (TR[-14:])))
                            pdm14.append(sum(i for i in (pdm1[-14:])))
                            ndm14.append(sum(i for i in (ndm1[-14:])))
                        if len(pdm1)>14:
                            tmp_val=TR14[-1]-(TR14[-1]/14)+TR[-1]
                            TR14.append(tmp_val)
                            tmp_val=pdm14[-1]-(pdm14[-1]/14)+pdm1[-1]
                            pdm14.append(tmp_val)
                            tmp_val=ndm14[-1]-(ndm14[-1]/14)+ndm1[-1]
                            ndm14.append(tmp_val)
                            #print(pdm14[-1])
                        while len(TR)>2000:
                            TR.pop(0)
                        while len(TR14)>2000:
                            TR14.pop(0)
                        while len(pdm1)>2000:
                            pdm1.pop(0)
                        while len(pdm14)>2000:
                            pdm14.pop(0)
                        while len(pdm1)>2000:
                            ndm1.pop(0)
                        while len(pdm14)>2000:
                            ndm14.pop(0)
                        if len(TR14)>0 and len(pdm14)>0:
                            pdi14.append(100*(pdm14[-1]/TR14[-1]))
                        if len(TR14)>0 and len(ndm14)>0:
                            ndi14.append(100*(ndm14[-1]/TR14[-1]))
                        if len(pdi14)>0:
                            di14diff.append(abs(pdi14[-1]-ndi14[-1]))
                            di14sum.append((pdi14[-1]+ndi14[-1]))
                            xd.append(100*(di14diff[-1]/di14sum[-1]))
                        if len(xd)==14:
                            xda.append(sum(i for i in (xd))/14)
                        if len(xda)>0:
                            xda.append((xd[-1]+(13*xda[-1]))/14)
                            #print(xda[-1])
                        if len(xda)>=20:
                            axda.append(np.mean(xda[-4:-1]))


                if (len(ma)>0 and len(axda)>0) and  (Now[0:6]=="201805" or Now[0:6]=="201806" or Now[0:6]=="201807" or Now[0:6]=="201808" or Now[0:6]=="201809" or Now[0:6]=="201810" or Now[0:6]=="201811"):#and len(axda)>0 and III%3==0:# and c>=1:#bb320sig1up_j < bb320sig1up_k:#Ask_k-Bid_k<0.6:# and bb320sig1up_j < bb320sig1up_k:

                    dis=abs((Ask_k+Bid_k)/2-ma[-1])
                    dir_dis=(Ask_k+Bid_k)/2-ma[-1]
                    
                    tot=100*profit-(2.37*number)+initial
                    y3.append(tot)
                    if Now[0:4]=="2018" and Position==0:
                        if icol[-1]>0 and dir_dis<1.6:
                            mPosition=1
                            mS4=S4
                        if icol[-1]<0 and dir_dis>-1.6:
                            mPosition=-1
                            mS4=S4
                    if  Now[0:4]=="2018" and Position==0 and dis>0.5:
                        if pdi14[-1]>ndi14[-1] and dir_dis<0:
                            mPosition=1
                            stop=minimum(hr_l[-40:])
                            N=n
                            
                        if pdi14[-1]<ndi14[-1] and dir_dis>0:
                            mPosition=-1
                            stop=Maximum(hr_h[-40:])
                            N=n
                            
                        
                    if Position>0:
                        if (Bid_k-mem)>abs(mS4)*0.8 or (Bid_k-mem)<-abs(mS4)*0.5:
                            mPosition=0
                    if Position<0:
                        if (mem-Ask_k)>abs(mS4)*0.8 or (mem-Ask_k)<-abs(mS4)*0.5:
                            mPosition=0 
                    if Position>0:
                        if dir_dis>5:
                            mPosition=0
                            
                        if pdi14[-1]<ndi14[-1]:
                            mPosition=0
                       
                        if (Bid_k-mem)<MDD:
                            MDD=(Bid_k-mem)

                    if Position<0:
                        if dir_dis<-5:
                            mPosition=0
                        if pdi14[-1]>ndi14[-1]:
                            mPosition=0
                        
                        if (mem-Ask_k)<MDD:
                            MDD=(mem-Ask_k)
                        
                i=i+1    
                
                ############################################################################## 
                if Position==0 and mPosition==1:# and Ask_k-Bid_k<1:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    mem=Ask_k
                    print(Ask_k)
                    print(1)
                    number=number+N
                    Position=1
                elif Position==0 and mPosition==-1:# and Ask_k-Bid_k<1:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    mem=Bid_k
                    print(Bid_k)
                    print(-1)
                    number=number+N
                    Position=-1
                elif Position==1 and mPosition==0:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    profit=profit+(Bid_k-mem)*N
                    number=number+N
                    print(Bid_k)
                    print(mem)
                    print(Bid_k-mem)
                    print("A")
                    print(-1)
                    Position=0
                elif Position==-1 and mPosition==0:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    profit=profit+(mem-Ask_k)*N
                    number=number+N
                    print(mem-Ask_k)
                    print("B")
                    print(Ask_k)
                    print(1)
                    Position=0
                elif Position==-1 and mPosition==1:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    profit=profit+(mem-Ask_k)*N
                    print(mem-Ask_k)
                    
                    print("C")
                    number=number+N
                    print(1)
                    mem=Ask_k
                    print(Ask_k)
                    print(1)
                    number=number+N
                    Position=1
                elif Position==1 and mPosition==-1: 
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    profit=profit+(Bid_k-mem)*N
                    print(Bid_k-mem)
                    print("D")
                    number=number+N
                    print(-1)
                    mem=Bid_k
                    print(Bid_k)
                    print(-1)
                    number=number+N
                    Position=-1
        c+=1
        tot=100*profit-(2.37*number)+initial
    print("profit:"+str(profit))  
    print("number"+str(number))
    tot=100*profit-(2.37*number)
    print("tot:"+str(tot))
    print("Position:"+str(Position))
    print("MDD:"+str(MDD))
    return y3
