# %%
import os
import numpy as np
import xlrd
import statistics 
import xlrd
def run(p1,p2, limit):
    InitialSMA9=[]
    InitialSMA12=[]
    InitialSMA26=[]
    period_10 = p1
    period_20 = p2
    period_320 = 320
    period_240 = 240
    H_len=240#13
    H_o=[]
    H_h_len=100
    H_h=[]
    H_l_len=100
    H_l=[]
    H_c_len=100
    H_c=[]
    MA20 = []
    MA10 = []
    MA240 = []
    MA320 = []
    avei=0
    aveii=0
    Position=0
    mPosition=0
    unrealised=0
    mem=0
    number=0
    diff=0
    profit=0
    tmp = []
    Bid_k =0
    Ask_k =0
    ma10_k = 0
    ma20_k = 0
    ma240_k =0
    ma320_k =0
    bb320sig1up_k=0
    bb320sig1down_k=0
    bb320sig2up_k=0
    bb320sig2down_k=0
    Bid_j =0
    Ask_j =0
    ma10_j = 0
    ma20_j = 0
    ma240_j =0
    ma320_j =0
    bb320sig1up_j=0
    bb320sig1down_j=0
    bb320sig2up_j=0
    bb320sig2down_j=0
    std=0
    listj=[0,0,0,0,0,0]
    listk=[0,0,0,0,0,0]
    Now=""
    direction=0
    f=0
    count=0
    dlong=[]
    period_dlong=1.5*period_320
    h=0
    light=0
    period_5=3
    MA5=[]
    ma5_j = 0
    ma5_k = 0
    step1=0
    step2=0
    c=0#356#0
    h=-1000
    l_=4000
    bias=[]
    bb=[]
    membias=0
    MD=3000
    counter=0
    threshold=limit
    c=0
    yesterday=[]
    b4y=[]
    ema12=[]
    #Multiplier: (2 / (Time periods + 1) ) = (2 / (10 + 1) ) = 0.1818 (18.18%)
    m9=(2/(9+1))
    m12=(2/(12+1))
    m26=(2/(26+1))
    ema26=[]
    macd=[]
    sig=[]
    his=[]
    smsa=[]
    ssma=[]
    icol=[]
    r=[]
    counter=0
    l1=[]
    I=[]
    A=0
    B=0
    C=0
    D=0
    E=0
    F=0
    l2=[]
    S4=0
    mS4=0
    I=0
    while c<416:
        fs="Clean"+str(c)+"1HR"+"201812GCN8.xls"
        if os.path.isfile(fs):
            print(fs)
            book = xlrd.open_workbook(fs)
            sh = book.sheet_by_index(0)
            i = 0
            while i<sh.nrows:

                Now=sh.cell_value(rowx=i, colx=0)
                #print(Now[10:12])
                Ask_j = Ask_k
                Bid_j = Bid_k
            
                Bid_k = float(sh.cell_value(rowx=i, colx=4))#Ask_k-0.5 #float(sh.cell_value(rowx=i, colx=4))float(sh.cell_value(rowx=i, colx=4))
                Ask_k = Bid_k+0.5#float(sh.cell_value(rowx=i, colx=9)) #
                
                ma10_j = ma10_k
                if len(MA10)<period_10:
                    MA10.append(((float(sh.cell_value(rowx=i, colx=3))+float(sh.cell_value(rowx=i, colx=2))+float(sh.cell_value(rowx=i, colx=7))+float(sh.cell_value(rowx=i, colx=8)))/4))
                if len(MA10)>=period_10:
                    MA10.append(((float(sh.cell_value(rowx=i, colx=3))+float(sh.cell_value(rowx=i, colx=2))+float(sh.cell_value(rowx=i, colx=7))+float(sh.cell_value(rowx=i, colx=8)))/4))
                    MA10.pop(0)
                    ma10_k = np.mean(MA10) 
                
                if len(yesterday)<(23*4):
                    yesterday.append(ma10_k)
                if len(yesterday)>=(23*4):
                    yesterday.append(ma10_k)
                    yesterday.pop(0)
                ss_tmp=((float(sh.cell_value(rowx=i, colx=2))-float(sh.cell_value(rowx=i, colx=3)))+(float(sh.cell_value(rowx=i, colx=7))-float(sh.cell_value(rowx=i, colx=8))))/2
                if len(smsa)<30:
                    smsa.append(ss_tmp)
                if len(smsa)>=30:
                    #smsa.pop(0)
                    smsa.append(ss_tmp) 
                    ssma.append(np.mean(smsa))
                #if len(ssma)>30:
                    #ssma.pop(0)                                                                            
                    #print(ssma[-1])
                if len(r)<30:
                    r.append((Ask_k+Bid_k)/2)
                if len(r)==30:
                    r.pop(0)
                    r.append((Ask_k+Bid_k)/2)
                if len(r)>3:
                    if len(icol)<30:
                        icol.append(r[-1]-r[-2])
                    if len(icol)>=30:
                        #icol.pop(0)
                        icol.append(r[-1]-r[-2])
                        #print(icol[-1])
                if len(icol)>4 and len(ssma)>0:
                    l1.append(ssma[-1]*icol[-1]*0.5*icol[-1])
                    #print(l1[-1])
                if len(l1)>40 and icol[-1]*icol[-2]<0:
                    G1=-2
                    G2=0
                    H1=0
                    H2=0
                    K1=0
                    K2=0
                    counter_j=0
                    counter_i=-2
                    while counter_j<3:
                        counter_i-=1
                        if icol[counter_i]*icol[-2]<0 and counter_j==0:
                            G2=-2
                            H1=counter_i
                            counter_j+=1
                        elif icol[counter_i]*icol[counter_i-1]<0 and counter_j==0:
                            G2=counter_i
                            H1=counter_i-1
                            counter_j+=1
                        elif icol[counter_i]*icol[counter_i-1]<0 and counter_j==1:
                            H2=counter_i
                            K1=counter_i-1
                            counter_j+=1
                        elif icol[counter_i]*icol[counter_i-1]<0 and counter_j==2:
                            K2=counter_i
                            counter_j+=1 
                        
                    S1=0
                    for e in icol[G2:(G1+1)]:
                        S1+=e
                    S2=0
                    for e in icol[H2:(H1+1)]:
                        S2+=e
                    S3=0
                    for e in icol[K2:(K1+1)]:
                        S3+=e
                    
                    
                    A=(ssma[K1]*(S3)-ssma[H1]*(S3+S2))
                    B=icol[K1]-icol[H1]
                    C=(ssma[H1]*(S3+S2)-ssma[K2]*0)
                    D=icol[H1]-icol[K2]
                    E=l1[H1]-l1[K1]
                    F=l1[K2]-l1[H1]
                    k=(F-((C*E)/A))/(D-((C*B)/A))
                    q=(E/A)-((B/A)*k)
                    I=l1[G1]+k*icol[G1]+q*ssma[G1]*(S3+S2+S1)
                    S4=(1/(ssma[-1]*q))*(I-k*icol[G1]-l1[G1])
                    print("I:"+str(I))
                    print("S4:"+str(S4))
                    
                #EMA: {Close - EMA(previous day)} x multiplier + EMA(previous day). 
                if len(InitialSMA12)<12:
                    InitialSMA12.append((Ask_k+Bid_k)/2)
                if len(InitialSMA12)==12 and len(ema12)==0:
                    ema12.append(np.mean(InitialSMA12))
                if len(ema12)>0:
                    ema12.append(ema12[-1]+m12*((Ask_k+Bid_k)/2-ema12[-1]))
                                 
                if len(InitialSMA26)<26:
                    InitialSMA26.append((Ask_k+Bid_k)/2)
                if len(InitialSMA26)==26 and len(ema26)==0:
                    ema26.append(np.mean(InitialSMA26))
                if len(ema26)>0:
                    ema26.append(ema26[-1]+m26*((Ask_k+Bid_k)/2-ema26[-1]))
                if len(ema26)>1:
                    macd.append(ema12[-1]-ema26[-1])
                if len(InitialSMA9)<9 and len(macd)>0:
                    InitialSMA9.append(macd[-1])
                if len(InitialSMA9)==9 and len(sig)==0:
                    sig.append(np.mean(InitialSMA9))
                if len(sig)>0:
                    sig.append(sig[-1]+m9*(macd[-1]-sig[-1]))
                if len(sig)>1:
                    his.append(macd[-1]-sig[-1])
                    #print(his[-1])
                ma20_j = ma20_k
                if len(MA20)<period_20:
                    MA20.append(((float(sh.cell_value(rowx=i, colx=3))+float(sh.cell_value(rowx=i, colx=2))+float(sh.cell_value(rowx=i, colx=7))+float(sh.cell_value(rowx=i, colx=8)))/4))
                if len(MA20)>=period_20:
                    MA20.append(((float(sh.cell_value(rowx=i, colx=3))+float(sh.cell_value(rowx=i, colx=2))+float(sh.cell_value(rowx=i, colx=7))+float(sh.cell_value(rowx=i, colx=8)))/4))
                    MA20.pop(0)
                    ma20_k = np.mean(MA20)
                ma320_j = ma320_k
                if len(MA320)<period_320:
                    MA320.append(ma20_k)#((float(sh.cell_value(rowx=i, colx=3))+float(sh.cell_value(rowx=i, colx=2))+float(sh.cell_value(rowx=i, colx=7))+float(sh.cell_value(rowx=i, colx=8)))/4))
                if len(MA320)>=period_320:
                    MA320.append(ma20_k)#((float(sh.cell_value(rowx=i, colx=3))+float(sh.cell_value(rowx=i, colx=2))+float(sh.cell_value(rowx=i, colx=7))+float(sh.cell_value(rowx=i, colx=8)))/4))
                    MA320.pop(0)
                    ma320_k = np.mean(MA320)
                    std=statistics.stdev(MA320)
                if len(dlong)<period_dlong:
                    dlong.append(ma20_k)
                if len(dlong)>=period_dlong:
                    dlong.append(ma20_k)
                    dlong.pop(0)
                if len(b4y)<(23*4):
                    b4y.append(ma20_k)
                if len(b4y)>=(23*4):
                    b4y.append(ma20_k)
                    b4y.pop(0)  
                bb320sig1up_j = bb320sig1up_k
                bb320sig1up_k = ma320_k+std
                bb320sig1down_j = bb320sig1down_k
                bb320sig1down_k = ma320_k-std
                bb320sig2up_j = bb320sig2up_k
                bb320sig2up_k = ma320_k+(2*std)
                bb320sig2down_j = bb320sig2down_k    
                bb320sig2down_k = ma320_k-(2*std)

                longtrend=MA320[-1]-MA320[0]
                slong=dlong[-1]-dlong[0]
                if len(his)>=4:# and c>=1:#bb320sig1up_j < bb320sig1up_k:#Ask_k-Bid_k<0.6:# and bb320sig1up_j < bb320sig1up_k:
                    #print(MA20[-1])
                    #print(yesterday[limit])
                    #print(b4y[0])
                    if Now[0:4]=="2018" and Position==0 and abs(S4)>3:# and (Now[10:15]=="19:15"):# and Now[10:12]!="09" and Now[10:12]!="08": and Now[0:4]=="2018"
                        #print("HHHHHHHH")
                        if (his[-1]-his[-2])>0 and (his[-1]>0) and (his[-2]<0): #icol[-1]>0:#
                            mPosition=1
                            mS4=S4
                        if (his[-1]-his[-2])<0 and (his[-1]<0) and (his[-2]>0): #icol[-1]<0:#
                            mPosition=-1
                            mS4=S4
                        """if Bid_k>ma10_k and Bid_k>ma20_k and ma10_k>ma20_k and ma10_j<ma20_j:# and yesterday[limit]>b4y[0]:# and ma10_j<yesterday[0]:
                            mPosition=1
                        if Ask_k<ma10_k and Ask_k<ma20_k and ma10_k<ma20_k and ma10_j>ma20_j:# and yesterday[limit]<b4y[0]:# and ma10_j<yesterday[0]:
                            mPosition=-1"""
                    #if (Now[10:15]=="04:00"):
                    #    mPosition=0
                    if Position>0:
                        #if Ask_k<ma10_k:#>ma20_k+5:
                        #    mPosition=0
                        if (Bid_k-mem)>abs(mS4)*0.7 or (Bid_k-mem)<-abs(mS4)*0.5:#or his[-1]<-2:
                            mPosition=0
                            
                    if Position<0:
                        #if Bid_k>ma10_k:#<ma20_k-5:
                        #    mPosition=0
                        if (mem-Ask_k)>abs(mS4)*0.7 or (mem-Ask_k)<-abs(mS4)*0.5: #or his[-1]>2:
                            mPosition=0
                            
                            
                i=i+1    
                #print(listj)
                #print("profit:"+str(profit))  
                ############################################################################## 
                if Position==0 and mPosition==1:# and Ask_k-Bid_k<1:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    mem=Ask_k
                    print(Ask_k)
                    print(1)
                    number=number+1
                    Position=1
                elif Position==0 and mPosition==-1:# and Ask_k-Bid_k<1:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    mem=Bid_k
                    print(Bid_k)
                    print(-1)
                    number=number+1
                    Position=-1
                elif Position==1 and mPosition==0:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    profit=profit+(Bid_k-mem)
                    number=number+1
                    print(Bid_k)
                    print(mem)
                    print(Bid_k-mem)
                    print("A")
                    print(-1)
                    Position=0
                elif Position==-1 and mPosition==0:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    profit=profit+(mem-Ask_k)
                    number=number+1
                    print(mem-Ask_k)
                    print("B")
                    print(Ask_k)
                    print(1)
                    Position=0
                elif Position==-1 and mPosition==1:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    profit=profit+(mem-Ask_k)
                    print(mem-Ask_k)
                    
                    print("C")
                    number=number+1
                    print(1)
                    mem=Ask_k
                    print(Ask_k)
                    print(1)
                    number=number+1
                    Position=1
                elif Position==1 and mPosition==-1: 
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    profit=profit+(Bid_k-mem)
                    print(Bid_k-mem)
                    print("D")
                    number=number+1
                    print(-1)
                    mem=Bid_k
                    print(Bid_k)
                    print(-1)
                    number=number+1
                    Position=-1
        c+=1
    print("profit:"+str(profit))  
    print("number"+str(number))
    tot=100*profit-(2.37*number)
    print("tot:"+str(tot))
    print("Position:"+str(Position))
    return profit
