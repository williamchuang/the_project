# %%
import os
import numpy as np
import xlrd
import statistics 
import xlrd
def Maximum(l):
    k=-1
    for e in l:
        if e>k:
            k=e
    return k
def minimum(l):
    k=-1
    for e in l:
        if e<k:
            k=e
    return k    
def run():
    output=[]
    InitialSMA9=[]
    InitialSMA12=[]
    InitialSMA26=[]
    period_10 = 10
    period_20 = 20
    period_320 = 320
    period_240 = 240
    H_len=240#13
    H_o=[]
    H_h_len=100
    H_h=[]
    H_l_len=100
    H_l=[]
    H_c_len=100
    H_c=[]
    MA20 = []
    MA10 = []
    MA240 = []
    MA320 = []
    avei=0
    aveii=0
    Position=0
    mPosition=0
    unrealised=0
    mem=0
    number=0
    diff=0
    profit=0
    tmp = []
    Bid_k =0
    Ask_k =0
    ma10_k = 0
    ma20_k = 0
    ma240_k =0
    ma320_k =0
    bb320sig1up_k=0
    bb320sig1down_k=0
    bb320sig2up_k=0
    bb320sig2down_k=0
    Bid_j =0
    Ask_j =0
    ma10_j = 0
    ma20_j = 0
    ma240_j =0
    ma320_j =0
    bb320sig1up_j=0
    bb320sig1down_j=0
    bb320sig2up_j=0
    bb320sig2down_j=0
    std=0
    listj=[0,0,0,0,0,0]
    listk=[0,0,0,0,0,0]
    Now=""
    direction=0
    f=0
    count=0
    dlong=[]
    period_dlong=1.5*period_320
    h=0
    light=0
    period_5=3
    MA5=[]
    ma5_j = 0
    ma5_k = 0
    step1=0
    step2=0
    c=0#356#0
    h=-1000
    l_=4000
    bias=[]
    bb=[]
    membias=0
    MD=3000
    counter=0
    
    c=0
    yesterday=[]
    b4y=[]
    ema12=[]
    #Multiplier: (2 / (Time periods + 1) ) = (2 / (10 + 1) ) = 0.1818 (18.18%)
    m9=(2/(9+1))
    m12=(2/(12+1))
    m26=(2/(26+1))
    ema26=[]
    macd=[]
    sig=[]
    his=[]
    smsa=[]
    ssma=[]
    icol=[]
    r=[]
    counter=0
    l1=[]
    I=[]
    A=0
    B=0
    C=0
    D=0
    E=0
    F=0
    l2=[]
    S4=0
    mS4=0
    I=0
    hr_o=[]
    hr_oc=0
    hr_h=[]
    hr_hc=0
    hr_l=[]
    hr_lc=10000
    hr_c=[]
    hr_cc=0
    hr_counter=0
    mprice=[]
    period=20
    vvv=[]
    wwwma=[]
    www=[]
    y1=[]
    y2=[]
    y3=[]
    y0=[]
    TR=[]
    pdm1=[]
    ndm1=[]
    TR14=[]
    pdm14=[]
    ndm14=[]
    pdi14=[]
    ndi14=[]
    di14diff=[]
    di14sum=[]
    xd=[]
    xda=[]
    mdi=0
    mwww=0
    stop=0
    III=0
    MDD=0
    axda=[]
    list_1=[0,0,0,0,0,0,0,0]
    list_2=[0,0,0,0,0,0,0,0]
    list_3=[0,0,0,0,0,0,0,0]
    list_4=[0,0,0,0,0,0,0,0]
    list_5=[0,0,0,0,0,0,0,0]
    list_6=[0,0,0,0,0,0,0,0]
    list_7=[0,0,0,0,0,0,0,0]
    list_8=[0,0,0,0,0,0,0,0]
    list_9=[0,0,0,0,0,0,0,0]
    list_10=[0,0,0,0,0,0,0,0]
    list_11=[0,0,0,0,0,0,0,0]
    list_12=[0,0,0,0,0,0,0,0]
    list_13=[0,0,0,0,0,0,0,0]
    list_14=[0,0,0,0,0,0,0,0]
    list_15=[0,0,0,0,0,0,0,0]
    list_16=[0,0,0,0,0,0,0,0]
    list_17=[0,0,0,0,0,0,0,0]
    list_18=[0,0,0,0,0,0,0,0]
    list_19=[0,0,0,0,0,0,0,0]
    list_20=[0,0,0,0,0,0,0,0]
    list_21=[0,0,0,0,0,0,0,0]
    list_22=[0,0,0,0,0,0,0,0]
    list_23=[0,0,0,0,0,0,0,0]
    list_24=[0,0,0,0,0,0,0,0]
    midprice=[]
    histogram_1=[]

    while c<418:
        fs="Clean"+str(c)+"_5MIN"+"201812GCN8.xls"
        if os.path.isfile(fs):
            print(fs)
            book = xlrd.open_workbook(fs)
            sh = book.sheet_by_index(0)
            i = 0
            while i<sh.nrows:

                Now=sh.cell_value(rowx=i, colx=0)
                #print(Now[10:12])
                Ask_j = Ask_k
                Bid_j = Bid_k
            
                Bid_k = float(sh.cell_value(rowx=i, colx=4))#Ask_k-0.5 #float(sh.cell_value(rowx=i, colx=4))float(sh.cell_value(rowx=i, colx=4))
                Ask_k = float(sh.cell_value(rowx=i, colx=9)) #
                #print('#'+str(Now)+": "+str(Ask_k))
                midprice.append((Bid_k+Ask_k)/2)
                hr_counter+=1
                c_h=(float(sh.cell_value(rowx=i, colx=2))+float(sh.cell_value(rowx=i, colx=7)))/2
                c_l=(float(sh.cell_value(rowx=i, colx=3))+float(sh.cell_value(rowx=i, colx=8)))/2
                if c_h>hr_hc:
                    hr_hc=c_h
                if c_l<hr_lc:
                    hr_lc=c_l
                if hr_counter==16:
                    hr_counter=0
                    hr_oc=hr_cc
                    hr_cc=Ask_k #(Bid_k+Ask_k)/2
                    hr_o.append(hr_oc)
                    hr_c.append(hr_cc)
                    hr_l.append(hr_lc)
                    hr_lc=10000
                    hr_h.append(hr_hc)
                    hr_hc=0
                    while len(hr_o)>2000:
                        hr_o.pop(0)
                    while len(hr_h)>2000:
                        hr_h.pop(0)
                    while len(hr_l)>2000:
                        hr_l.pop(0)
                    while len(hr_c)>2000:
                        hr_c.pop(0)
                    if len(mprice)<period and len(hr_c)>1:
                        mprice.append(hr_c[-1])#(((hr_h[-1])+(hr_l[-1]))/2)
                    if len(mprice)>=period:
                        mprice.append(hr_c[-1])#(((hr_h[-1])+(hr_l[-1]))/2)
                        #mprice.pop(0)

                    if len(mprice)>=period:
                        MA20.append(np.mean(mprice[-1*period:]))
                        vvv.append(statistics.stdev(mprice[-1*period:]))
                        www.append((4*vvv[-1]/MA20[-1]))
                        output.append(www[-1])
                    if len(www)>20:
                        wwwma.append(np.mean(www[-4:-1]))                       
                        y0.append(Now)
                        y1.append(www[-1])
                        y2.append(wwwma[-1])
                    #if Now[0:4]=="2018":
                    #    print(str(Now)+": "+str(Ask_k))
                    
                    
                    
                      
                 
                
                
                
                if len(midprice)==100:# and III%3==0:# and c>=1:#bb320sig1up_j < bb320sig1up_k:#Ask_k-Bid_k<0.6:# and bb320sig1up_j < bb320sig1up_k:
                    #III=0
                    #print(MA20[-1])
                    #print(yesterday[limit])
                    #print(b4y[0])
                    if midprice[-1]>=MA20[-1]+3*vvv[-1]:
                        list_24=[1,0,0,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+3*vvv[-1] and midprice[-1]>=MA20[-1]+2*vvv[-1]:
                        list_24=[0,1,0,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+2*vvv[-1] and midprice[-1]>=MA20[-1]+1*vvv[-1]:
                        list_24=[0,0,1,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+1*vvv[-1] and midprice[-1]>=MA20[-1]+0*vvv[-1]:
                        list_24=[0,0,0,1,0,0,0,0]
                    if midprice[-1]<MA20[-1]+0*vvv[-1] and midprice[-1]>=MA20[-1]-1*vvv[-1]:
                        list_24=[0,0,0,0,1,0,0,0]
                    if midprice[-1]<MA20[-1]-vvv[-1] and midprice[-1]>=MA20[-1]-2*vvv[-1]:
                        list_24=[0,0,0,0,0,1,0,0]
                    if midprice[-1]<MA20[-1]-2*vvv[-1] and midprice[-1]>=MA20[-1]-3*vvv[-1]:
                        list_24=[0,0,0,0,0,0,1,0]
                    if midprice[-1]<MA20[-1]-3*vvv[-1]:
                        list_24=[0,0,0,0,0,0,0,1]
                    ###
                    if midprice[-1]>=MA20[-1]+3*vvv[-1]:
                        list_23=[1,0,0,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+3*vvv[-1] and midprice[-1]>=MA20[-1]+2*vvv[-1]:
                        list_23=[0,1,0,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+2*vvv[-1] and midprice[-1]>=MA20[-1]+1*vvv[-1]:
                        list_23=[0,0,1,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+1*vvv[-1] and midprice[-1]>=MA20[-1]+0*vvv[-1]:
                        list_23=[0,0,0,1,0,0,0,0]
                    if midprice[-1]<MA20[-1]+0*vvv[-1] and midprice[-1]>=MA20[-1]-1*vvv[-1]:
                        list_23=[0,0,0,0,1,0,0,0]
                    if midprice[-1]<MA20[-1]-vvv[-1] and midprice[-1]>=MA20[-1]-2*vvv[-1]:
                        list_23=[0,0,0,0,0,1,0,0]
                    if midprice[-1]<MA20[-1]-2*vvv[-1] and midprice[-1]>=MA20[-1]-3*vvv[-1]:
                        list_23=[0,0,0,0,0,0,1,0]
                    if midprice[-1]<MA20[-1]-3*vvv[-1]:
                        list_23=[0,0,0,0,0,0,0,1]
                    ###
                    if midprice[-1]>=MA20[-1]+3*vvv[-1]:
                        list_22=[1,0,0,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+3*vvv[-1] and midprice[-1]>=MA20[-1]+2*vvv[-1]:
                        list_22=[0,1,0,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+2*vvv[-1] and midprice[-1]>=MA20[-1]+1*vvv[-1]:
                        list_22=[0,0,1,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+1*vvv[-1] and midprice[-1]>=MA20[-1]+0*vvv[-1]:
                        list_22=[0,0,0,1,0,0,0,0]
                    if midprice[-1]<MA20[-1]+0*vvv[-1] and midprice[-1]>=MA20[-1]-1*vvv[-1]:
                        list_22=[0,0,0,0,1,0,0,0]
                    if midprice[-1]<MA20[-1]-vvv[-1] and midprice[-1]>=MA20[-1]-2*vvv[-1]:
                        list_22=[0,0,0,0,0,1,0,0]
                    if midprice[-1]<MA20[-1]-2*vvv[-1] and midprice[-1]>=MA20[-1]-3*vvv[-1]:
                        list_22=[0,0,0,0,0,0,1,0]
                    if midprice[-1]<MA20[-1]-3*vvv[-1]:
                        list_22=[0,0,0,0,0,0,0,1]
                    ###
                    if midprice[-1]>=MA20[-1]+3*vvv[-1]:
                        list_21=[1,0,0,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+3*vvv[-1] and midprice[-1]>=MA20[-1]+2*vvv[-1]:
                        list_21=[0,1,0,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+2*vvv[-1] and midprice[-1]>=MA20[-1]+1*vvv[-1]:
                        list_21=[0,0,1,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+1*vvv[-1] and midprice[-1]>=MA20[-1]+0*vvv[-1]:
                        list_21=[0,0,0,1,0,0,0,0]
                    if midprice[-1]<MA20[-1]+0*vvv[-1] and midprice[-1]>=MA20[-1]-1*vvv[-1]:
                        list_21=[0,0,0,0,1,0,0,0]
                    if midprice[-1]<MA20[-1]-vvv[-1] and midprice[-1]>=MA20[-1]-2*vvv[-1]:
                        list_21=[0,0,0,0,0,1,0,0]
                    if midprice[-1]<MA20[-1]-2*vvv[-1] and midprice[-1]>=MA20[-1]-3*vvv[-1]:
                        list_21=[0,0,0,0,0,0,1,0]
                    if midprice[-1]<MA20[-1]-3*vvv[-1]:
                        list_21=[0,0,0,0,0,0,0,1]
                    ###
                    if midprice[-1]>=MA20[-1]+3*vvv[-1]:
                        list_20=[1,0,0,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+3*vvv[-1] and midprice[-1]>=MA20[-1]+2*vvv[-1]:
                        list_20=[0,1,0,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+2*vvv[-1] and midprice[-1]>=MA20[-1]+1*vvv[-1]:
                        list_20=[0,0,1,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+1*vvv[-1] and midprice[-1]>=MA20[-1]+0*vvv[-1]:
                        list_20=[0,0,0,1,0,0,0,0]
                    if midprice[-1]<MA20[-1]+0*vvv[-1] and midprice[-1]>=MA20[-1]-1*vvv[-1]:
                        list_20=[0,0,0,0,1,0,0,0]
                    if midprice[-1]<MA20[-1]-vvv[-1] and midprice[-1]>=MA20[-1]-2*vvv[-1]:
                        list_20=[0,0,0,0,0,1,0,0]
                    if midprice[-1]<MA20[-1]-2*vvv[-1] and midprice[-1]>=MA20[-1]-3*vvv[-1]:
                        list_20=[0,0,0,0,0,0,1,0]
                    if midprice[-1]<MA20[-1]-3*vvv[-1]:
                        list_20=[0,0,0,0,0,0,0,1]
                    ###
                    if midprice[-1]>=MA20[-1]+3*vvv[-1]:
                        list_19=[1,0,0,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+3*vvv[-1] and midprice[-1]>=MA20[-1]+2*vvv[-1]:
                        list_24=[0,1,0,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+2*vvv[-1] and midprice[-1]>=MA20[-1]+1*vvv[-1]:
                        list_24=[0,0,1,0,0,0,0,0]
                    if midprice[-1]<MA20[-1]+1*vvv[-1] and midprice[-1]>=MA20[-1]+0*vvv[-1]:
                        list_24=[0,0,0,1,0,0,0,0]
                    if midprice[-1]<MA20[-1]+0*vvv[-1] and midprice[-1]>=MA20[-1]-1*vvv[-1]:
                        list_24=[0,0,0,0,1,0,0,0]
                    if midprice[-1]<MA20[-1]-vvv[-1] and midprice[-1]>=MA20[-1]-2*vvv[-1]:
                        list_24=[0,0,0,0,0,1,0,0]
                    if midprice[-1]<MA20[-1]-2*vvv[-1] and midprice[-1]>=MA20[-1]-3*vvv[-1]:
                        list_24=[0,0,0,0,0,0,1,0]
                    if midprice[-1]<MA20[-1]-3*vvv[-1]:
                        list_24=[0,0,0,0,0,0,0,1]
                if len(midprice)>100:            
                    if Now[0:4]=="2018":
                        y3.append(profit)
                        
                    if Now[0:4]=="2018" and Position==0:# and xda[-1]>axda[-1]:# and www[-1]>wwwma[-1]:# and (Now[10:15]=="19:15"):# and Now[10:12]!="09" and Now[10:12]!="08": and Now[0:4]=="2018"
                        #print("HHHHHHHH")
                        
                        
                    
                            
                #III+=1            
                i=i+1    
                #print(listj)
                #print("profit:"+str(profit))
                
                ############################################################################## 
                if Position==0 and mPosition==1:# and Ask_k-Bid_k<1:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    mem=Ask_k
                    print(Ask_k)
                    print(1)
                    number=number+1
                    Position=1
                elif Position==0 and mPosition==-1:# and Ask_k-Bid_k<1:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    mem=Bid_k
                    print(Bid_k)
                    print(-1)
                    number=number+1
                    Position=-1
                elif Position==1 and mPosition==0:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    profit=profit+(Bid_k-mem)
                    number=number+1
                    print(Bid_k)
                    print(mem)
                    print(Bid_k-mem)
                    print("A")
                    print(-1)
                    Position=0
                elif Position==-1 and mPosition==0:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    profit=profit+(mem-Ask_k)
                    number=number+1
                    print(mem-Ask_k)
                    print("B")
                    print(Ask_k)
                    print(1)
                    Position=0
                elif Position==-1 and mPosition==1:
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    profit=profit+(mem-Ask_k)
                    print(mem-Ask_k)
                    
                    print("C")
                    number=number+1
                    print(1)
                    mem=Ask_k
                    print(Ask_k)
                    print(1)
                    number=number+1
                    Position=1
                elif Position==1 and mPosition==-1: 
                    print("-----------")
                    print("Ask_k:"+str(Ask_k))
                    print("Bid_k:"+str(Bid_k))
                    print("ma20_k:"+str(ma20_k))
                    print("ma320_k:"+str(ma320_k))
                    print("bb320sig1up_k:"+str(bb320sig1up_k))
                    print("bb320sig1down_k:"+str(bb320sig1down_k))
                    print("bb320sig2up_k:"+str(bb320sig2up_k))
                    print("bb320sig2down_k:"+str(bb320sig2down_k))
                    print(Now)
                    profit=profit+(Bid_k-mem)
                    print(Bid_k-mem)
                    print("D")
                    number=number+1
                    print(-1)
                    mem=Bid_k
                    print(Bid_k)
                    print(-1)
                    number=number+1
                    Position=-1
        c+=1
        
    print("profit:"+str(profit))  
    print("number"+str(number))
    tot=100*profit-(2.37*number)
    print("tot:"+str(tot))
    print("Position:"+str(Position))
    print("MDD:"+str(MDD))
    return y3

# %%
int(0.01)
# Out:
# 0
