# %%
#profit:78.10000000000173
#mem:1297.4499999999998
#(H_k+L_k)/2:1295.7
#T:2957
#t:3200
#78.10000000000173
import statistics
import math
position=0
step=0
fee=0
t=242
step_list=[]
profit=0
mem=0
max_potential=0

while t<3200:
    #import gspread
    #from oauth2client.service_account import ServiceAccountCredentials
    # use creds to create a client to interact with the Google Drive API
    #scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']
    #creds = ServiceAccountCredentials.from_json_keyfile_name('Spreadsheet-5f9f3b27a502.json', scope)
    #gc= gspread.authorize(creds)
    #sh = gc.open('A new spreadsheet')
    #worksheet = sh.get_worksheet(0)
    import xlrd
    workbook = xlrd.open_workbook('cleaned_data.xls')
    s = workbook.sheet_by_index(0)
    
    
    #H_i=callback.historical_Data[(t-2)][3]
    H_i=s.cell((t-1),2).value
    #print(H_i) #1359.3
    #L_i=callback.historical_Data[(t-2)][4]
    L_i=s.cell((t-1),3).value
    #print(L_i) #1357.8
    #C_i=callback.historical_Data[(t-2)][5]
    C_i=s.cell((t-2),4).value
    #print(C_i)
    #O_i=callback.historical_Data[(t-2)][2]
    O_i=s.cell((t-2),1).value
    
    #H_j=callback.historical_Data[(t-1)][3]
    H_j=s.cell((t-1),2).value
    #print(H_j)
    #L_j=callback.historical_Data[(t-1)][4]
    L_j=s.cell((t-1),3).value
    #print(L_j)
    #C_j=callback.historical_Data[(t-1)][5]
    C_j=s.cell((t-1),4).value
    #print(C_j)
    #O_j=callback.historical_Data[(t-1)][2]
    O_j=s.cell((t-1),1).value
    
    #H_k=callback.historical_Data[t][3]
    H_k=s.cell(t,2).value
    #print(H_k) #1359.4
    #L_k=callback.historical_Data[t][4]
    L_k=s.cell(t,3).value
    #print(L_k) #1357.6
    #C_k=callback.historical_Data[t][5]
    C_k=s.cell(t,4).value
    #print(C_k) #1358.2
    O_k=s.cell(t,1).value
    
    
    #print("t"+str(t))
    #v=worksheet.acell('K'+str(s)).value
    v=s.cell((t-1),10).value
    
    #print(v)
    bbHj=float(v)-1.5
    #print(bollingerband_H_k) #1363.14
    w=s.cell((t-1),12).value
    #print(w)
    bbLj=float(w)+1.5
    
    #print(bollingerband_L_k) #1349.19
    
    q=s.cell((t-2),18).value
    #print(q)
    macd_his_i=float(q)
    e=s.cell((t-1),18).value
    macd_his_j=float(e)
    #print(e)
                     
    bbw_i=float(s.cell((t-2),19).value)
    #print(bbw_i)
    bbw_j=float(s.cell((t-1),19).value)
    #print(bbw_j)
    
    #check step
    if H_j<bbHj and L_j>bbLj:
        step=1
    elif H_j>bbHj and L_j>bbLj:
        step=2
    elif H_j<bbHj and L_j<bbLj:
        step =3
    else:
        step =0
    #print(step)
    
    sd=(bbw_j)/4
    sumforma=0
    n=10   #60:-19 40:-10 20:78
    m=20
    for x in range(t-n, t): #print from t-240 to t-1
        h_s=s.cell(x,2).value
        l_s=s.cell(x,3).value
        hl2=(h_s+l_s)/2
        sumforma=sumforma+hl2
    sma=sumforma/n
    
    lj=[]
    for x in range(t-m, t): #print from t-240 to t-1
        h_s=s.cell(x,2).value
        l_s=s.cell(x,3).value
        hl2=(h_s+l_s)/2
        lj.append(hl2)
    sdm_j=statistics.stdev(lj)
    
    li=[]
    for x in range(t-m-1, t-1): #print from t-240 to t-1
        h_s=s.cell(x,2).value
        l_s=s.cell(x,3).value
        hl2=(h_s+l_s)/2
        li.append(hl2)
    sdm_i=statistics.stdev(li)
    
    C_p=float(s.cell(t-n,4).value)
    
    T=0
    
    if t>243:
        T=t-242
        if position>0:
            if macd_his_i>macd_his_j:  #18/48
                position=position-1
                fee=fee+1
                if (H_k+L_k)/2-mem<=0:
                    profit = profit-(mem-((H_k+L_k)/2))
                elif (H_k+L_k)/2-mem>0:
                    profit = profit+(((H_k+L_k)/2)-mem)
                mem=(H_k+L_k)/2
            elif (H_k+L_k)/2-mem>1.2: #3/48
                if (H_k+L_k)/2-mem>max_potential:
                    max_potential=(H_k+L_k)/2-mem
                elif (H_k+L_k)/2-mem<max_potential*0.7:
                    position=position-1
                    fee=fee+1
                    max_potential=0
                    if (H_k+L_k)/2-mem<=0:
                        profit = profit-(mem-((H_k+L_k)/2))
                    elif (H_k+L_k)/2-mem>0:
                        profit = profit+(((H_k+L_k)/2)-mem)
                    mem=(H_k+L_k)/2 
            elif L_j<sma+1.5 or C_p>C_k: #23.8/48 or C_p>C_k: 1.8/23.8 L_j<sma+1.5:22
                position=position-1
                fee=fee+1
                if (H_k+L_k)/2-mem<=0:
                    profit = profit-(mem-((H_k+L_k)/2))
                elif (H_k+L_k)/2-mem>0:
                    profit = profit+(((H_k+L_k)/2)-mem)
                mem=(H_k+L_k)/2 
        if position<0:
            if macd_his_i<macd_his_j: #18/48
                position=position+1
                fee=fee+1
                if (H_k+L_k)/2-mem<=0:
                    profit = profit+(mem-((H_k+L_k)/2))
                elif (H_k+L_k)/2-mem>0:
                    profit = profit-(((H_k+L_k)/2)-mem)
                mem=(H_k+L_k)/2
            elif mem-(H_k+L_k)/2>1.2:  #3/48
                if mem-(H_k+L_k)/2>max_potential:
                    max_potential=mem-(H_k+L_k)/2
                elif mem-(H_k+L_k)/2<max_potential*0.7:
                    position=position+1
                    max_potential=0
                    if (H_k+L_k)/2-mem<=0:
                        profit = profit+(mem-((H_k+L_k)/2))
                    elif (H_k+L_k)/2-mem>0:
                        profit = profit-(((H_k+L_k)/2)-mem)
                    mem=(H_k+L_k)/2
            elif H_j>sma-1.5 or C_p<C_k:  #23.8/48 
                position=position+1
                fee=fee+1
                if (H_k+L_k)/2-mem<=0:
                    profit = profit+(mem-((H_k+L_k)/2))
                elif (H_k+L_k)/2-mem>0:
                    profit = profit-(((H_k+L_k)/2)-mem)
                mem=(H_k+L_k)/2
        if position==0 and sdm_i<sdm_j:
            if C_p>C_k:  #36/48
                position=position-1
                fee=fee+1
                mem=(H_k+L_k)/2
            elif C_p<C_k: #36/48
                position=position+1
                fee=fee+1
                mem=(H_k+L_k)/2
            elif (H_j+L_j)/2<sma: #redundant
                position=position-1
                fee=fee+1
                mem=(H_k+L_k)/2
            elif (H_j+L_j)/2>sma: #redundant
                position=position+1
                fee=fee+1
                mem=(H_k+L_k)/2
    
    if position!=0:
        print("position:"+str(position))
    print("profit:"+str(profit))
    print("mem:"+str(mem))
    print("(H_k+L_k)/2:"+str((H_k+L_k)/2))
    step_list.append(step)
    #print(step_list)
    min=1500
    max=0
    
    
    t = t+1
    print("T:"+str(T))
    print("t:"+str(t))
    #if t%88==0:
        #min=1500
        #max=0
    if (H_k+L_k)/2>max:
        max=(H_k+L_k)/2
    if (H_k+L_k)/2<min:
        min=(H_k+L_k)/2
    #print("---------------------------------------------------------------------------------------------------------")
    #if t%13==0:
        #time.sleep(100)
    print("fee:"+str(fee))
print("profit:"+str(profit))         
print(fee)
# Out:
# profit:0
# mem:0
# (H_k+L_k)/2:1356.95
# T:0
# t:243
# fee:0
# profit:0
# mem:0
# (H_k+L_k)/2:1357.55
# T:0
# t:244
# fee:0
# profit:0
# mem:0
# (H_k+L_k)/2:1357.5
# T:2
# t:245
# fee:0
# profit:0
# mem:0
# (H_k+L_k)/2:1356.3
# T:3
# t:246
# fee:0
# profit:0
# mem:0
# (H_k+L_k)/2:1356.4
# T:4
# t:247
# fee:0
# profit:0
# mem:0
# (H_k+L_k)/2:1356.25
# T:5
# t:248
# fee:0
# profit:0
# mem:0
# (H_k+L_k)/2:1356.55
# T:6
# t:249
# fee:0
# profit:0
# mem:0
# (H_k+L_k)/2:1356.75
# T:7
# t:250
# fee:0
# profit:0
# mem:0
# (H_k+L_k)/2:1357.05
# T:8
# t:251
# fee:0
# profit:0
# mem:0
# (H_k+L_k)/2:1355.85
# T:9
# t:252
# fee:0
# position:-1
# profit:0
# mem:1354.9
# (H_k+L_k)/2:1354.9
# T:10
# t:253
# fee:1
# position:-1
# profit:0
# mem:1354.9
# (H_k+L_k)/2:1353.25
# T:11
# t:254
# fee:1
# position:-1
# profit:0
# mem:1354.9
# (H_k+L_k)/2:1353.1
# T:12
# t:255
# fee:1
# position:-1
# profit:0
# mem:1354.9
# (H_k+L_k)/2:1351.2
# T:13
# t:256
# fee:1
# position:-1
# profit:0
# mem:1354.9
# (H_k+L_k)/2:1350.4499999999998
# T:14
# t:257
# fee:1
# position:-1
# profit:2.75
# mem:1352.15
# (H_k+L_k)/2:1352.15
# T:15
# t:258
# fee:2
# position:-1
# profit:1.0
# mem:1353.9
# (H_k+L_k)/2:1353.9
# T:16
# t:259
# fee:4
# position:-1
# profit:1.550000000000182
# mem:1353.35
# (H_k+L_k)/2:1353.35
# T:17
# t:260
# fee:6
# profit:0.25
# mem:1354.65
# (H_k+L_k)/2:1354.65
# T:18
# t:261
# fee:7
# profit:0.25
# mem:1354.65
# (H_k+L_k)/2:1354.6999999999998
# T:19
# t:262
# fee:7
# profit:0.25
# mem:1354.65
# (H_k+L_k)/2:1354.55
# T:20
# t:263
# fee:7
# profit:0.25
# mem:1354.65
# (H_k+L_k)/2:1354.85
# T:21
# t:264
# fee:7
# profit:0.25
# mem:1354.65
# (H_k+L_k)/2:1355.0
# T:22
# t:265
# fee:7
# profit:0.25
# mem:1354.65
# (H_k+L_k)/2:1354.35
# T:23
# t:266
# fee:7
# profit:0.25
# mem:1354.65
# (H_k+L_k)/2:1354.1
# T:24
# t:267
# fee:7
# profit:0.25
# mem:1354.65
# (H_k+L_k)/2:1353.6
# T:25
# t:268
# fee:7
# profit:0.25
# mem:1354.65
# (H_k+L_k)/2:1353.25
# T:26
# t:269
# fee:7
# profit:0.25
# mem:1354.65
# (H_k+L_k)/2:1353.45
# T:27
# t:270
# fee:7
# profit:0.25
# mem:1354.65
# (H_k+L_k)/2:1353.9499999999998
# T:28
# t:271
# fee:7
# profit:0.25
# mem:1354.65
# (H_k+L_k)/2:1353.7
# T:29
# t:272
# fee:7
# profit:0.25
# mem:1354.65
# (H_k+L_k)/2:1354.4
# T:30
# t:273
# fee:7
# profit:0.25
# mem:1354.65
# (H_k+L_k)/2:1354.3000000000002
# T:31
# t:274
# fee:7
# position:-1
# profit:0.25
# mem:1354.35
# (H_k+L_k)/2:1354.35
# T:32
# t:275
# fee:8
# position:1
# profit:-0.10000000000013642
# mem:1354.7
# (H_k+L_k)/2:1354.7
# T:33
# t:276
# fee:10
# profit:-0.5
# mem:1354.3000000000002
# (H_k+L_k)/2:1354.3000000000002
# T:34
# t:277
# fee:11
# profit:-0.5
# mem:1354.3000000000002
# (H_k+L_k)/2:1354.05
# T:35
# t:278
# fee:11
# profit:-0.5
# mem:1354.3000000000002
# (H_k+L_k)/2:1354.3
# T:36
# t:279
# fee:11
# profit:-0.5
# mem:1354.3000000000002
# (H_k+L_k)/2:1354.0500000000002
# T:37
# t:280
# fee:11
# profit:-0.5
# mem:1354.3000000000002
# (H_k+L_k)/2:1353.55
# T:38
# t:281
# fee:11
# position:-1
# profit:-0.5
# mem:1353.1
# (H_k+L_k)/2:1353.1
# T:39
# t:282
# fee:12
# position:-1
# profit:0.1999999999998181
# mem:1352.4
# (H_k+L_k)/2:1352.4
# T:40
# t:283
# fee:14
# position:-1
# profit:0.2999999999999545
# mem:1352.3
# (H_k+L_k)/2:1352.3
# T:41
# t:284
# fee:16
# position:-1
# profit:0.25
# mem:1352.35
# (H_k+L_k)/2:1352.35
# T:42
# t:285
# fee:18
# position:-1
# profit:-0.3500000000001364
# mem:1352.95
# (H_k+L_k)/2:1352.95
# T:43
# t:286
# fee:20
# position:-1
# profit:-1.050000000000182
# mem:1353.65
# (H_k+L_k)/2:1353.65
# T:44
# t:287
# fee:22
# profit:0.599999999999909
# mem:1352.0
# (H_k+L_k)/2:1352.0
# T:45
# t:288
# fee:23
# position:-1
# profit:0.599999999999909
# mem:1350.5
# (H_k+L_k)/2:1350.5
# T:46
# t:289
# fee:24
# position:-1
# profit:0.599999999999909
# mem:1350.5
# (H_k+L_k)/2:1350.65
# T:47
# t:290
# fee:24
# position:-1
# profit:0.049999999999954525
# mem:1351.05
# (H_k+L_k)/2:1351.05
# T:48
# t:291
# fee:26
# position:-1
# profit:-0.40000000000009095
# mem:1351.5
# (H_k+L_k)/2:1351.5
# T:49
# t:292
# fee:28
# position:-1
# profit:0.14999999999986358
# mem:1350.95
# (H_k+L_k)/2:1350.95
# T:50
# t:293
# fee:30
# position:-1
# profit:0.5499999999997272
# mem:1350.5500000000002
# (H_k+L_k)/2:1350.5500000000002
# T:51
# t:294
# fee:32
# position:-1
# profit:0.599999999999909
# mem:1350.5
# (H_k+L_k)/2:1350.5
# T:52
# t:295
# fee:34
# position:-1
# profit:0.25
# mem:1350.85
# (H_k+L_k)/2:1350.85
# T:53
# t:296
# fee:36
# profit:-0.15000000000009095
# mem:1351.25
# (H_k+L_k)/2:1351.25
# T:54
# t:297
# fee:37
# profit:-0.15000000000009095
# mem:1351.25
# (H_k+L_k)/2:1351.6
# T:55
# t:298
# fee:37
# profit:-0.15000000000009095
# mem:1351.25
# (H_k+L_k)/2:1350.9
# T:56
# t:299
# fee:37
# profit:-0.15000000000009095
# mem:1351.25
# (H_k+L_k)/2:1350.55
# T:57
# t:300
# fee:37
# profit:-0.15000000000009095
# mem:1351.25
# (H_k+L_k)/2:1350.5500000000002
# T:58
# t:301
# fee:37
# profit:-0.15000000000009095
# mem:1351.25
# (H_k+L_k)/2:1350.5500000000002
# T:59
# t:302
# fee:37
# profit:-0.15000000000009095
# mem:1351.25
# (H_k+L_k)/2:1350.1
# T:60
# t:303
# fee:37
# position:1
# profit:-0.15000000000009095
# mem:1350.5
# (H_k+L_k)/2:1350.5
# T:61
# t:304
# fee:38
# profit:0.34999999999990905
# mem:1351.0
# (H_k+L_k)/2:1351.0
# T:62
# t:305
# fee:39
# profit:0.34999999999990905
# mem:1351.0
# (H_k+L_k)/2:1351.05
# T:63
# t:306
# fee:39
# profit:0.34999999999990905
# mem:1351.0
# (H_k+L_k)/2:1350.6999999999998
# T:64
# t:307
# fee:39
# profit:0.34999999999990905
# mem:1351.0
# (H_k+L_k)/2:1351.35
# T:65
# t:308
# fee:39
# profit:0.34999999999990905
# mem:1351.0
# (H_k+L_k)/2:1352.05
# T:66
# t:309
# fee:39
# position:1
# profit:0.34999999999990905
# mem:1352.25
# (H_k+L_k)/2:1352.25
# T:67
# t:310
# fee:40
# position:1
# profit:0.1999999999998181
# mem:1352.1
# (H_k+L_k)/2:1352.1
# T:68
# t:311
# fee:42
# position:1
# profit:-0.650000000000091
# mem:1351.25
# (H_k+L_k)/2:1351.25
# T:69
# t:312
# fee:44
# profit:-2.150000000000091
# mem:1349.75
# (H_k+L_k)/2:1349.75
# T:70
# t:313
# fee:45
# position:-1
# profit:-2.150000000000091
# mem:1349.95
# (H_k+L_k)/2:1349.95
# T:71
# t:314
# fee:46
# position:-1
# profit:-2.0
# mem:1349.8
# (H_k+L_k)/2:1349.8
# T:72
# t:315
# fee:48
# position:-1
# profit:-2.9500000000000455
# mem:1350.75
# (H_k+L_k)/2:1350.75
# T:73
# t:316
# fee:50
# position:1
# profit:-2.9500000000000455
# mem:1350.75
# (H_k+L_k)/2:1350.75
# T:74
# t:317
# fee:52
# profit:-3.5000000000002274
# mem:1350.1999999999998
# (H_k+L_k)/2:1350.1999999999998
# T:75
# t:318
# fee:53
# profit:-3.5000000000002274
# mem:1350.1999999999998
# (H_k+L_k)/2:1349.8
# T:76
# t:319
# fee:53
# position:-1
# profit:-3.5000000000002274
# mem:1349.0
# (H_k+L_k)/2:1349.0
# T:77
# t:320
# fee:54
# position:-1
# profit:-2.700000000000273
# mem:1348.2
# (H_k+L_k)/2:1348.2
# T:78
# t:321
# fee:56
# position:-1
# profit:-2.9000000000003183
# mem:1348.4
# (H_k+L_k)/2:1348.4
# T:79
# t:322
# fee:58
# position:-1
# profit:-3.200000000000273
# mem:1348.7
# (H_k+L_k)/2:1348.7
# T:80
# t:323
# fee:60
# position:-1
# profit:-3.6000000000001364
# mem:1349.1
# (H_k+L_k)/2:1349.1
# T:81
# t:324
# fee:62
# position:-1
# profit:-4.000000000000227
# mem:1349.5
# (H_k+L_k)/2:1349.5
# T:82
# t:325
# fee:64
# position:-1
# profit:-3.4000000000003183
# mem:1348.9
# (H_k+L_k)/2:1348.9
# T:83
# t:326
# fee:66
# position:-1
# profit:-4.2000000000000455
# mem:1349.6999999999998
# (H_k+L_k)/2:1349.6999999999998
# T:84
# t:327
# fee:68
# profit:-4.900000000000318
# mem:1350.4
# (H_k+L_k)/2:1350.4
# T:85
# t:328
# fee:69
# profit:-4.900000000000318
# mem:1350.4
# (H_k+L_k)/2:1349.9
# T:86
# t:329
# fee:69
# profit:-4.900000000000318
# mem:1350.4
# (H_k+L_k)/2:1349.1
# T:87
# t:330
# fee:69
# profit:-4.900000000000318
# mem:1350.4
# (H_k+L_k)/2:1350.4499999999998
# T:88
# t:331
# fee:69
# profit:-4.900000000000318
# mem:1350.4
# (H_k+L_k)/2:1351.7
# T:89
# t:332
# fee:69
# position:1
# profit:-4.900000000000318
# mem:1350.9499999999998
# (H_k+L_k)/2:1350.9499999999998
# T:90
# t:333
# fee:70
# position:-1
# profit:-6.650000000000091
# mem:1349.2
# (H_k+L_k)/2:1349.2
# T:91
# t:334
# fee:72
# position:-1
# profit:-5.5499999999999545
# mem:1348.1
# (H_k+L_k)/2:1348.1
# T:92
# t:335
# fee:74
# position:-1
# profit:-5.5499999999999545
# mem:1348.1
# (H_k+L_k)/2:1346.4499999999998
# T:93
# t:336
# fee:74
# position:-1
# profit:-5.5499999999999545
# mem:1348.1
# (H_k+L_k)/2:1345.05
# T:94
# t:337
# fee:74
# position:-1
# profit:-5.5499999999999545
# mem:1348.1
# (H_k+L_k)/2:1345.0
# T:95
# t:338
# fee:74
# position:-1
# profit:-5.5499999999999545
# mem:1348.1
# (H_k+L_k)/2:1345.0
# T:96
# t:339
# fee:74
# position:-1
# profit:-5.5499999999999545
# mem:1348.1
# (H_k+L_k)/2:1344.35
# T:97
# t:340
# fee:74
# position:-1
# profit:-5.5499999999999545
# mem:1348.1
# (H_k+L_k)/2:1343.7
# T:98
# t:341
# fee:74
# position:-1
# profit:-5.5499999999999545
# mem:1348.1
# (H_k+L_k)/2:1344.4
# T:99
# t:342
# fee:74
# position:-1
# profit:-3.75
# mem:1346.3
# (H_k+L_k)/2:1346.3
# T:100
# t:343
# fee:76
# position:-1
# profit:-3.7999999999999545
# mem:1346.35
# (H_k+L_k)/2:1346.35
# T:101
# t:344
# fee:78
# position:-1
# profit:-3.9500000000000455
# mem:1346.5
# (H_k+L_k)/2:1346.5
# T:102
# t:345
# fee:80
# profit:-3.900000000000091
# mem:1346.45
# (H_k+L_k)/2:1346.45
# T:103
# t:346
# fee:81
# profit:-3.900000000000091
# mem:1346.45
# (H_k+L_k)/2:1346.6
# T:104
# t:347
# fee:81
# profit:-3.900000000000091
# mem:1346.45
# (H_k+L_k)/2:1346.05
# T:105
# t:348
# fee:81
# profit:-3.900000000000091
# mem:1346.45
# (H_k+L_k)/2:1345.25
# T:106
# t:349
# fee:81
# profit:-3.900000000000091
# mem:1346.45
# (H_k+L_k)/2:1345.8
# T:107
# t:350
# fee:81
# profit:-3.900000000000091
# mem:1346.45
# (H_k+L_k)/2:1345.4499999999998
# T:108
# t:351
# fee:81
# profit:-3.900000000000091
# mem:1346.45
# (H_k+L_k)/2:1344.6
# T:109
# t:352
# fee:81
# profit:-3.900000000000091
# mem:1346.45
# (H_k+L_k)/2:1345.0
# T:110
# t:353
# fee:81
# profit:-3.900000000000091
# mem:1346.45
# (H_k+L_k)/2:1345.3
# T:111
# t:354
# fee:81
# profit:-3.900000000000091
# mem:1346.45
# (H_k+L_k)/2:1345.25
# T:112
# t:355
# fee:81
# profit:-3.900000000000091
# mem:1346.45
# (H_k+L_k)/2:1344.75
# T:113
# t:356
# fee:81
# profit:-3.900000000000091
# mem:1346.45
# (H_k+L_k)/2:1344.35
# T:114
# t:357
# fee:81
# position:-1
# profit:-3.900000000000091
# mem:1344.1
# (H_k+L_k)/2:1344.1
# T:115
# t:358
# fee:82
# position:-1
# profit:-3.3500000000001364
# mem:1343.55
# (H_k+L_k)/2:1343.55
# T:116
# t:359
# fee:84
# position:-1
# profit:-3.350000000000364
# mem:1343.5500000000002
# (H_k+L_k)/2:1343.5500000000002
# T:117
# t:360
# fee:86
# position:-1
# profit:-3.550000000000182
# mem:1343.75
# (H_k+L_k)/2:1343.75
# T:118
# t:361
# fee:88
# profit:-3.800000000000182
# mem:1344.0
# (H_k+L_k)/2:1344.0
# T:119
# t:362
# fee:89
# position:-1
# profit:-3.800000000000182
# mem:1343.85
# (H_k+L_k)/2:1343.85
# T:120
# t:363
# fee:90
# position:-1
# profit:-4.100000000000364
# mem:1344.15
# (H_k+L_k)/2:1344.15
# T:121
# t:364
# fee:92
# profit:-4.200000000000273
# mem:1344.25
# (H_k+L_k)/2:1344.25
# T:122
# t:365
# fee:93
# profit:-4.200000000000273
# mem:1344.25
# (H_k+L_k)/2:1343.8000000000002
# T:123
# t:366
# fee:93
# profit:-4.200000000000273
# mem:1344.25
# (H_k+L_k)/2:1342.65
# T:124
# t:367
# fee:93
# profit:-4.200000000000273
# mem:1344.25
# (H_k+L_k)/2:1340.9499999999998
# T:125
# t:368
# fee:93
# position:-1
# profit:-4.200000000000273
# mem:1341.6
# (H_k+L_k)/2:1341.6
# T:126
# t:369
# fee:94
# position:-1
# profit:-3.350000000000364
# mem:1340.75
# (H_k+L_k)/2:1340.75
# T:127
# t:370
# fee:96
# position:-1
# profit:-4.100000000000364
# mem:1341.5
# (H_k+L_k)/2:1341.5
# T:128
# t:371
# fee:98
# position:-1
# profit:-4.650000000000546
# mem:1342.0500000000002
# (H_k+L_k)/2:1342.0500000000002
# T:129
# t:372
# fee:100
# position:-1
# profit:-4.100000000000364
# mem:1341.5
# (H_k+L_k)/2:1341.5
# T:130
# t:373
# fee:102
# position:-1
# profit:-3.5000000000004547
# mem:1340.9
# (H_k+L_k)/2:1340.9
# T:131
# t:374
# fee:104
# position:-1
# profit:-3.5000000000004547
# mem:1340.9
# (H_k+L_k)/2:1340.9
# T:132
# t:375
# fee:106
# profit:-3.9000000000005457
# mem:1341.3000000000002
# (H_k+L_k)/2:1341.3000000000002
# T:133
# t:376
# fee:107
# profit:-3.9000000000005457
# mem:1341.3000000000002
# (H_k+L_k)/2:1341.6
# T:134
# t:377
# fee:107
# profit:-3.9000000000005457
# mem:1341.3000000000002
# (H_k+L_k)/2:1341.3
# T:135
# t:378
# fee:107
# profit:-3.9000000000005457
# mem:1341.3000000000002
# (H_k+L_k)/2:1340.9499999999998
# T:136
# t:379
# fee:107
# position:-1
# profit:-3.9000000000005457
# mem:1340.8
# (H_k+L_k)/2:1340.8
# T:137
# t:380
# fee:108
# position:-1
# profit:-4.350000000000591
# mem:1341.25
# (H_k+L_k)/2:1341.25
# T:138
# t:381
# fee:110
# profit:-5.100000000000591
# mem:1342.0
# (H_k+L_k)/2:1342.0
# T:139
# t:382
# fee:111
# profit:-5.100000000000591
# mem:1342.0
# (H_k+L_k)/2:1341.9
# T:140
# t:383
# fee:111
# profit:-5.100000000000591
# mem:1342.0
# (H_k+L_k)/2:1342.25
# T:141
# t:384
# fee:111
# profit:-5.100000000000591
# mem:1342.0
# (H_k+L_k)/2:1341.9
# T:142
# t:385
# fee:111
# profit:-5.100000000000591
# mem:1342.0
# (H_k+L_k)/2:1341.6
# T:143
# t:386
# fee:111
# profit:-5.100000000000591
# mem:1342.0
# (H_k+L_k)/2:1341.35
# T:144
# t:387
# fee:111
# profit:-5.100000000000591
# mem:1342.0
# (H_k+L_k)/2:1341.55
# T:145
# t:388
# fee:111
# profit:-5.100000000000591
# mem:1342.0
# (H_k+L_k)/2:1341.4499999999998
# T:146
# t:389
# fee:111
# profit:-5.100000000000591
# mem:1342.0
# (H_k+L_k)/2:1341.6999999999998
# T:147
# t:390
# fee:111
# profit:-5.100000000000591
# mem:1342.0
# (H_k+L_k)/2:1341.95
# T:148
# t:391
# fee:111
# position:-1
# profit:-5.100000000000591
# mem:1342.05
# (H_k+L_k)/2:1342.05
# T:149
# t:392
# fee:112
# profit:-4.950000000000728
# mem:1341.9
# (H_k+L_k)/2:1341.9
# T:150
# t:393
# fee:113
# position:-1
# profit:-4.950000000000728
# mem:1341.9
# (H_k+L_k)/2:1341.9
# T:151
# t:394
# fee:114
# profit:-5.300000000000637
# mem:1342.25
# (H_k+L_k)/2:1342.25
# T:152
# t:395
# fee:115
# profit:-5.300000000000637
# mem:1342.25
# (H_k+L_k)/2:1342.3
# T:153
# t:396
# fee:115
# position:1
# profit:-5.300000000000637
# mem:1342.6
# (H_k+L_k)/2:1342.6
# T:154
# t:397
# fee:116
# position:1
# profit:-5.650000000000546
# mem:1342.25
# (H_k+L_k)/2:1342.25
# T:155
# t:398
# fee:118
# position:1
# profit:-5.9500000000005
# mem:1341.95
# (H_k+L_k)/2:1341.95
# T:156
# t:399
# fee:120
# profit:-5.9500000000005
# mem:1341.95
# (H_k+L_k)/2:1341.95
# T:157
# t:400
# fee:121
# profit:-5.9500000000005
# mem:1341.95
# (H_k+L_k)/2:1341.5
# T:158
# t:401
# fee:121
# profit:-5.9500000000005
# mem:1341.95
# (H_k+L_k)/2:1342.3
# T:159
# t:402
# fee:121
# position:-1
# profit:-5.9500000000005
# mem:1342.0
# (H_k+L_k)/2:1342.0
# T:160
# t:403
# fee:122
# position:-1
# profit:-4.650000000000546
# mem:1340.7
# (H_k+L_k)/2:1340.7
# T:161
# t:404
# fee:123
# position:-1
# profit:-3.9500000000005002
# mem:1340.0
# (H_k+L_k)/2:1340.0
# T:162
# t:405
# fee:125
# position:-1
# profit:-3.8000000000004093
# mem:1339.85
# (H_k+L_k)/2:1339.85
# T:163
# t:406
# fee:127
# position:-1
# profit:-3.3000000000004093
# mem:1339.35
# (H_k+L_k)/2:1339.35
# T:164
# t:407
# fee:129
# position:-1
# profit:-2.850000000000591
# mem:1338.9
# (H_k+L_k)/2:1338.9
# T:165
# t:408
# fee:131
# position:-1
# profit:-2.2500000000004547
# mem:1338.3
# (H_k+L_k)/2:1338.3
# T:166
# t:409
# fee:133
# position:-1
# profit:-1.4500000000005002
# mem:1337.5
# (H_k+L_k)/2:1337.5
# T:167
# t:410
# fee:135
# position:-1
# profit:-1.4500000000005002
# mem:1337.5
# (H_k+L_k)/2:1336.25
# T:168
# t:411
# fee:135
# position:-1
# profit:-1.4500000000005002
# mem:1337.5
# (H_k+L_k)/2:1335.95
# T:169
# t:412
# fee:135
# position:-1
# profit:-1.4500000000005002
# mem:1337.5
# (H_k+L_k)/2:1335.5
# T:170
# t:413
# fee:135
# position:-1
# profit:-1.4500000000005002
# mem:1337.5
# (H_k+L_k)/2:1335.75
# T:171
# t:414
# fee:135
# position:-1
# profit:0.24999999999931788
# mem:1335.8000000000002
# (H_k+L_k)/2:1335.8000000000002
# T:172
# t:415
# fee:137
# position:-1
# profit:-4.547473508864641e-13
# mem:1336.05
# (H_k+L_k)/2:1336.05
# T:173
# t:416
# fee:139
# position:-1
# profit:-0.4500000000005002
# mem:1336.5
# (H_k+L_k)/2:1336.5
# T:174
# t:417
# fee:141
# profit:-0.4500000000005002
# mem:1336.5
# (H_k+L_k)/2:1336.5
# T:175
# t:418
# fee:142
# profit:-0.4500000000005002
# mem:1336.5
# (H_k+L_k)/2:1335.9499999999998
# T:176
# t:419
# fee:142
# profit:-0.4500000000005002
# mem:1336.5
# (H_k+L_k)/2:1335.95
# T:177
# t:420
# fee:142
# profit:-0.4500000000005002
# mem:1336.5
# (H_k+L_k)/2:1335.5
# T:178
# t:421
# fee:142
# profit:-0.4500000000005002
# mem:1336.5
# (H_k+L_k)/2:1336.25
# T:179
# t:422
# fee:142
# profit:-0.4500000000005002
# mem:1336.5
# (H_k+L_k)/2:1335.3
# T:180
# t:423
# fee:142
# profit:-0.4500000000005002
# mem:1336.5
# (H_k+L_k)/2:1334.0500000000002
# T:181
# t:424
# fee:142
# profit:-0.4500000000005002
# mem:1336.5
# (H_k+L_k)/2:1332.4499999999998
# T:182
# t:425
# fee:142
# position:-1
# profit:-0.4500000000005002
# mem:1332.85
# (H_k+L_k)/2:1332.85
# T:183
# t:426
# fee:143
# profit:-0.8500000000005912
# mem:1333.25
# (H_k+L_k)/2:1333.25
# T:184
# t:427
# fee:144
# profit:-0.8500000000005912
# mem:1333.25
# (H_k+L_k)/2:1333.5500000000002
# T:185
# t:428
# fee:144
# profit:-0.8500000000005912
# mem:1333.25
# (H_k+L_k)/2:1333.35
# T:186
# t:429
# fee:144
# profit:-0.8500000000005912
# mem:1333.25
# (H_k+L_k)/2:1332.5500000000002
# T:187
# t:430
# fee:144
# position:-1
# profit:-0.8500000000005912
# mem:1331.15
# (H_k+L_k)/2:1331.15
# T:188
# t:431
# fee:145
# position:-1
# profit:-0.6000000000005912
# mem:1330.9
# (H_k+L_k)/2:1330.9
# T:189
# t:432
# fee:147
# position:-1
# profit:-1.0500000000004093
# mem:1331.35
# (H_k+L_k)/2:1331.35
# T:190
# t:433
# fee:149
# position:-1
# profit:-1.5500000000004093
# mem:1331.85
# (H_k+L_k)/2:1331.85
# T:191
# t:434
# fee:151
# position:1
# profit:-1.2500000000004547
# mem:1331.55
# (H_k+L_k)/2:1331.55
# T:192
# t:435
# fee:153
# position:-1
# profit:-0.9000000000003183
# mem:1331.9
# (H_k+L_k)/2:1331.9
# T:193
# t:436
# fee:155
# profit:-0.05000000000040927
# mem:1331.0500000000002
# (H_k+L_k)/2:1331.0500000000002
# T:194
# t:437
# fee:156
# profit:-0.05000000000040927
# mem:1331.0500000000002
# (H_k+L_k)/2:1330.6
# T:195
# t:438
# fee:156
# profit:-0.05000000000040927
# mem:1331.0500000000002
# (H_k+L_k)/2:1331.15
# T:196
# t:439
# fee:156
# profit:-0.05000000000040927
# mem:1331.0500000000002
# (H_k+L_k)/2:1331.25
# T:197
# t:440
# fee:156
# profit:-0.05000000000040927
# mem:1331.0500000000002
# (H_k+L_k)/2:1331.4
# T:198
# t:441
# fee:156
# profit:-0.05000000000040927
# mem:1331.0500000000002
# (H_k+L_k)/2:1331.2
# T:199
# t:442
# fee:156
# profit:-0.05000000000040927
# mem:1331.0500000000002
# (H_k+L_k)/2:1331.0500000000002
# T:200
# t:443
# fee:156
# profit:-0.05000000000040927
# mem:1331.0500000000002
# (H_k+L_k)/2:1330.5
# T:201
# t:444
# fee:156
# profit:-0.05000000000040927
# mem:1331.0500000000002
# (H_k+L_k)/2:1330.75
# T:202
# t:445
# fee:156
# position:-1
# profit:-0.05000000000040927
# mem:1330.9
# (H_k+L_k)/2:1330.9
# T:203
# t:446
# fee:157
# profit:-0.8000000000004093
# mem:1331.65
# (H_k+L_k)/2:1331.65
# T:204
# t:447
# fee:158
# profit:-0.8000000000004093
# mem:1331.65
# (H_k+L_k)/2:1332.1
# T:205
# t:448
# fee:158
# profit:-0.8000000000004093
# mem:1331.65
# (H_k+L_k)/2:1332.65
# T:206
# t:449
# fee:158
# profit:-0.8000000000004093
# mem:1331.65
# (H_k+L_k)/2:1332.45
# T:207
# t:450
# fee:158
# profit:-0.8000000000004093
# mem:1331.65
# (H_k+L_k)/2:1332.1999999999998
# T:208
# t:451
# fee:158
# position:-1
# profit:-0.8000000000004093
# mem:1331.4
# (H_k+L_k)/2:1331.4
# T:209
# t:452
# fee:159
# profit:-0.9500000000002728
# mem:1331.55
# (H_k+L_k)/2:1331.55
# T:210
# t:453
# fee:160
