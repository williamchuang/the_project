# %%
#profit:78.10000000000173
#mem:1297.4499999999998
#(H_k+L_k)/2:1295.7
#T:2957
#t:3200
#78.10000000000173
import statistics
import math
position=0
step=0
fee=0
t=242
step_list=[]
profit=0
mem=0
max_potential=0

while t<3200:
    #import gspread
    #from oauth2client.service_account import ServiceAccountCredentials
    # use creds to create a client to interact with the Google Drive API
    #scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']
    #creds = ServiceAccountCredentials.from_json_keyfile_name('Spreadsheet-5f9f3b27a502.json', scope)
    #gc= gspread.authorize(creds)
    #sh = gc.open('A new spreadsheet')
    #worksheet = sh.get_worksheet(0)
    import xlrd
    workbook = xlrd.open_workbook('cleaned_data.xls')
    s = workbook.sheet_by_index(0)
    
    
    #H_i=callback.historical_Data[(t-2)][3]
    H_i=s.cell((t-1),2).value
    #print(H_i) #1359.3
    #L_i=callback.historical_Data[(t-2)][4]
    L_i=s.cell((t-1),3).value
    #print(L_i) #1357.8
    #C_i=callback.historical_Data[(t-2)][5]
    C_i=s.cell((t-2),4).value
    #print(C_i)
    #O_i=callback.historical_Data[(t-2)][2]
    O_i=s.cell((t-2),1).value
    
    #H_j=callback.historical_Data[(t-1)][3]
    H_j=s.cell((t-1),2).value
    #print(H_j)
    #L_j=callback.historical_Data[(t-1)][4]
    L_j=s.cell((t-1),3).value
    #print(L_j)
    #C_j=callback.historical_Data[(t-1)][5]
    C_j=s.cell((t-1),4).value
    #print(C_j)
    #O_j=callback.historical_Data[(t-1)][2]
    O_j=s.cell((t-1),1).value
    
    #H_k=callback.historical_Data[t][3]
    H_k=s.cell(t,2).value
    #print(H_k) #1359.4
    #L_k=callback.historical_Data[t][4]
    L_k=s.cell(t,3).value
    #print(L_k) #1357.6
    #C_k=callback.historical_Data[t][5]
    C_k=s.cell(t,4).value
    #print(C_k) #1358.2
    O_k=s.cell(t,1).value
    
    
    #print("t"+str(t))
    #v=worksheet.acell('K'+str(s)).value
    v=s.cell((t-1),10).value
    
    #print(v)
    bbHj=float(v)-1.5
    #print(bollingerband_H_k) #1363.14
    w=s.cell((t-1),12).value
    #print(w)
    bbLj=float(w)+1.5
    
    #print(bollingerband_L_k) #1349.19
    
    q=s.cell((t-2),18).value
    #print(q)
    macd_his_i=float(q)
    e=s.cell((t-1),18).value
    macd_his_j=float(e)
    #print(e)
                     
    bbw_i=float(s.cell((t-2),19).value)
    #print(bbw_i)
    bbw_j=float(s.cell((t-1),19).value)
    #print(bbw_j)
    
    #check step
    if H_j<bbHj and L_j>bbLj:
        step=1
    elif H_j>bbHj and L_j>bbLj:
        step=2
    elif H_j<bbHj and L_j<bbLj:
        step =3
    else:
        step =0
    #print(step)
    
    sd=(bbw_j)/4
    sumforma=0
    n=10   #60:-19 40:-10 20:78
    m=240
    for x in range(t-n, t): #print from t-240 to t-1
        h_s=s.cell(x,2).value
        l_s=s.cell(x,3).value
        hl2=(h_s+l_s)/2
        sumforma=sumforma+hl2
    sma=sumforma/n
    
    lj=[]
    for x in range(t-m, t): #print from t-240 to t-1
        h_s=s.cell(x,2).value
        l_s=s.cell(x,3).value
        hl2=(h_s+l_s)/2
        lj.append(hl2)
    sdm_j=statistics.stdev(lj)
    
    li=[]
    for x in range(t-m-1, t-1): #print from t-240 to t-1
        h_s=s.cell(x,2).value
        l_s=s.cell(x,3).value
        hl2=(h_s+l_s)/2
        li.append(hl2)
    sdm_i=statistics.stdev(li)
    
    C_p=float(s.cell(t-n,4).value)
    
    T=0
    
    if t>243:
        T=t-242
        if position>0:
            if macd_his_i>macd_his_j:  #18/48
                position=position-1
                fee=fee+1
                if (H_k+L_k)/2-mem<=0:
                    profit = profit-(mem-((H_k+L_k)/2))
                elif (H_k+L_k)/2-mem>0:
                    profit = profit+(((H_k+L_k)/2)-mem)
                mem=(H_k+L_k)/2
            elif (H_k+L_k)/2-mem>1.2: #3/48
                if (H_k+L_k)/2-mem>max_potential:
                    max_potential=(H_k+L_k)/2-mem
                elif (H_k+L_k)/2-mem<max_potential*0.7:
                    position=position-1
                    fee=fee+1
                    max_potential=0
                    if (H_k+L_k)/2-mem<=0:
                        profit = profit-(mem-((H_k+L_k)/2))
                    elif (H_k+L_k)/2-mem>0:
                        profit = profit+(((H_k+L_k)/2)-mem)
                    mem=(H_k+L_k)/2 
            elif L_j<sma+1.5 or C_p>C_k: #23.8/48 or C_p>C_k: 1.8/23.8 L_j<sma+1.5:22
                position=position-1
                fee=fee+1
                if (H_k+L_k)/2-mem<=0:
                    profit = profit-(mem-((H_k+L_k)/2))
                elif (H_k+L_k)/2-mem>0:
                    profit = profit+(((H_k+L_k)/2)-mem)
                mem=(H_k+L_k)/2 
        if position<0:
            if macd_his_i<macd_his_j: #18/48
                position=position+1
                fee=fee+1
                if (H_k+L_k)/2-mem<=0:
                    profit = profit+(mem-((H_k+L_k)/2))
                elif (H_k+L_k)/2-mem>0:
                    profit = profit-(((H_k+L_k)/2)-mem)
                mem=(H_k+L_k)/2
            elif mem-(H_k+L_k)/2>1.2:  #3/48
                if mem-(H_k+L_k)/2>max_potential:
                    max_potential=mem-(H_k+L_k)/2
                elif mem-(H_k+L_k)/2<max_potential*0.7:
                    position=position+1
                    max_potential=0
                    if (H_k+L_k)/2-mem<=0:
                        profit = profit+(mem-((H_k+L_k)/2))
                    elif (H_k+L_k)/2-mem>0:
                        profit = profit-(((H_k+L_k)/2)-mem)
                    mem=(H_k+L_k)/2
            elif H_j>sma-1.5 or C_p<C_k:  #23.8/48 
                position=position+1
                fee=fee+1
                if (H_k+L_k)/2-mem<=0:
                    profit = profit+(mem-((H_k+L_k)/2))
                elif (H_k+L_k)/2-mem>0:
                    profit = profit-(((H_k+L_k)/2)-mem)
                mem=(H_k+L_k)/2
        if position==0 and bbw_i<bbw_j:
            if C_p>C_k:  #36/48
                position=position-1
                fee=fee+1
                mem=(H_k+L_k)/2
            elif C_p<C_k: #36/48
                position=position+1
                fee=fee+1
                mem=(H_k+L_k)/2
            elif (H_j+L_j)/2<sma: #redundant
                position=position-1
                fee=fee+1
                mem=(H_k+L_k)/2
            elif (H_j+L_j)/2>sma: #redundant
                position=position+1
                fee=fee+1
                mem=(H_k+L_k)/2
    
    if position!=0:
        print("position:"+str(position))
    print("profit:"+str(profit))
    print("mem:"+str(mem))
    print("(H_k+L_k)/2:"+str((H_k+L_k)/2))
    step_list.append(step)
    #print(step_list)
    min=1500
    max=0
    
    
    t = t+1
    print("T:"+str(T))
    print("t:"+str(t))
    #if t%88==0:
        #min=1500
        #max=0
    if (H_k+L_k)/2>max:
        max=(H_k+L_k)/2
    if (H_k+L_k)/2<min:
        min=(H_k+L_k)/2
    #print("---------------------------------------------------------------------------------------------------------")
    #if t%13==0:
        #time.sleep(100)
    print("fee:"+str(fee))
print("profit:"+str(profit))         
print(fee)
# Out:
# profit:0
# mem:0
# (H_k+L_k)/2:1356.95
# T:0
# t:243
# fee:0
# profit:0
# mem:0
# (H_k+L_k)/2:1357.55
# T:0
# t:244
# fee:0
# position:1
# profit:0
# mem:1357.5
# (H_k+L_k)/2:1357.5
# T:2
# t:245
# fee:1
# position:-1
# profit:-1.2000000000000455
# mem:1356.3
# (H_k+L_k)/2:1356.3
# T:3
# t:246
# fee:3
# profit:-1.300000000000182
# mem:1356.4
# (H_k+L_k)/2:1356.4
# T:4
# t:247
# fee:4
# profit:-1.300000000000182
# mem:1356.4
# (H_k+L_k)/2:1356.25
# T:5
# t:248
# fee:4
# profit:-1.300000000000182
# mem:1356.4
# (H_k+L_k)/2:1356.55
# T:6
# t:249
# fee:4
# profit:-1.300000000000182
# mem:1356.4
# (H_k+L_k)/2:1356.75
# T:7
# t:250
# fee:4
# profit:-1.300000000000182
# mem:1356.4
# (H_k+L_k)/2:1357.05
# T:8
# t:251
# fee:4
# position:-1
# profit:-1.300000000000182
# mem:1355.85
# (H_k+L_k)/2:1355.85
# T:9
# t:252
# fee:5
# profit:-0.3500000000003638
# mem:1354.9
# (H_k+L_k)/2:1354.9
# T:10
# t:253
# fee:6
# position:-1
# profit:-0.3500000000003638
# mem:1353.25
# (H_k+L_k)/2:1353.25
# T:11
# t:254
# fee:7
# position:-1
# profit:-0.20000000000027285
# mem:1353.1
# (H_k+L_k)/2:1353.1
# T:12
# t:255
# fee:9
# position:-1
# profit:-0.20000000000027285
# mem:1353.1
# (H_k+L_k)/2:1351.2
# T:13
# t:256
# fee:9
# position:-1
# profit:-0.20000000000027285
# mem:1353.1
# (H_k+L_k)/2:1350.4499999999998
# T:14
# t:257
# fee:9
# position:-1
# profit:-0.20000000000027285
# mem:1353.1
# (H_k+L_k)/2:1352.15
# T:15
# t:258
# fee:9
# position:-1
# profit:-1.0000000000004547
# mem:1353.9
# (H_k+L_k)/2:1353.9
# T:16
# t:259
# fee:11
# position:-1
# profit:-0.45000000000027285
# mem:1353.35
# (H_k+L_k)/2:1353.35
# T:17
# t:260
# fee:13
# position:-1
# profit:-1.7500000000004547
# mem:1354.65
# (H_k+L_k)/2:1354.65
# T:18
# t:261
# fee:15
# position:-1
# profit:-1.800000000000182
# mem:1354.6999999999998
# (H_k+L_k)/2:1354.6999999999998
# T:19
# t:262
# fee:17
# profit:-1.6500000000003183
# mem:1354.55
# (H_k+L_k)/2:1354.55
# T:20
# t:263
# fee:18
# profit:-1.6500000000003183
# mem:1354.55
# (H_k+L_k)/2:1354.85
# T:21
# t:264
# fee:18
# profit:-1.6500000000003183
# mem:1354.55
# (H_k+L_k)/2:1355.0
# T:22
# t:265
# fee:18
# profit:-1.6500000000003183
# mem:1354.55
# (H_k+L_k)/2:1354.35
# T:23
# t:266
# fee:18
# profit:-1.6500000000003183
# mem:1354.55
# (H_k+L_k)/2:1354.1
# T:24
# t:267
# fee:18
# profit:-1.6500000000003183
# mem:1354.55
# (H_k+L_k)/2:1353.6
# T:25
# t:268
# fee:18
# position:1
# profit:-1.6500000000003183
# mem:1353.25
# (H_k+L_k)/2:1353.25
# T:26
# t:269
# fee:19
# position:-1
# profit:-1.4500000000002728
# mem:1353.45
# (H_k+L_k)/2:1353.45
# T:27
# t:270
# fee:21
# position:-1
# profit:-1.9500000000000455
# mem:1353.9499999999998
# (H_k+L_k)/2:1353.9499999999998
# T:28
# t:271
# fee:23
# profit:-1.7000000000002728
# mem:1353.7
# (H_k+L_k)/2:1353.7
# T:29
# t:272
# fee:24
# profit:-1.7000000000002728
# mem:1353.7
# (H_k+L_k)/2:1354.4
# T:30
# t:273
# fee:24
# profit:-1.7000000000002728
# mem:1353.7
# (H_k+L_k)/2:1354.3000000000002
# T:31
# t:274
# fee:24
# position:-1
# profit:-1.7000000000002728
# mem:1354.35
# (H_k+L_k)/2:1354.35
# T:32
# t:275
# fee:25
# position:1
# profit:-2.0500000000004093
# mem:1354.7
# (H_k+L_k)/2:1354.7
# T:33
# t:276
# fee:27
# position:-1
# profit:-2.450000000000273
# mem:1354.3000000000002
# (H_k+L_k)/2:1354.3000000000002
# T:34
# t:277
# fee:29
# position:1
# profit:-2.2000000000000455
# mem:1354.05
# (H_k+L_k)/2:1354.05
# T:35
# t:278
# fee:31
# position:1
# profit:-1.9500000000000455
# mem:1354.3
# (H_k+L_k)/2:1354.3
# T:36
# t:279
# fee:33
# position:1
# profit:-2.199999999999818
# mem:1354.0500000000002
# (H_k+L_k)/2:1354.0500000000002
# T:37
# t:280
# fee:35
# position:-1
# profit:-2.7000000000000455
# mem:1353.55
# (H_k+L_k)/2:1353.55
# T:38
# t:281
# fee:37
# profit:-2.25
# mem:1353.1
# (H_k+L_k)/2:1353.1
# T:39
# t:282
# fee:38
# profit:-2.25
# mem:1353.1
# (H_k+L_k)/2:1352.4
# T:40
# t:283
# fee:38
# profit:-2.25
# mem:1353.1
# (H_k+L_k)/2:1352.3
# T:41
# t:284
# fee:38
# profit:-2.25
# mem:1353.1
# (H_k+L_k)/2:1352.35
# T:42
# t:285
# fee:38
# profit:-2.25
# mem:1353.1
# (H_k+L_k)/2:1352.95
# T:43
# t:286
# fee:38
# profit:-2.25
# mem:1353.1
# (H_k+L_k)/2:1353.65
# T:44
# t:287
# fee:38
# profit:-2.25
# mem:1353.1
# (H_k+L_k)/2:1352.0
# T:45
# t:288
# fee:38
# profit:-2.25
# mem:1353.1
# (H_k+L_k)/2:1350.5
# T:46
# t:289
# fee:38
# position:-1
# profit:-2.25
# mem:1350.65
# (H_k+L_k)/2:1350.65
# T:47
# t:290
# fee:39
# position:-1
# profit:-2.6499999999998636
# mem:1351.05
# (H_k+L_k)/2:1351.05
# T:48
# t:291
# fee:41
# position:-1
# profit:-3.099999999999909
# mem:1351.5
# (H_k+L_k)/2:1351.5
# T:49
# t:292
# fee:43
# profit:-2.5499999999999545
# mem:1350.95
# (H_k+L_k)/2:1350.95
# T:50
# t:293
# fee:44
# position:-1
# profit:-2.5499999999999545
# mem:1350.5500000000002
# (H_k+L_k)/2:1350.5500000000002
# T:51
# t:294
# fee:45
# position:-1
# profit:-2.4999999999997726
# mem:1350.5
# (H_k+L_k)/2:1350.5
# T:52
# t:295
# fee:47
# position:-1
# profit:-2.8499999999996817
# mem:1350.85
# (H_k+L_k)/2:1350.85
# T:53
# t:296
# fee:49
# position:-1
# profit:-3.2499999999997726
# mem:1351.25
# (H_k+L_k)/2:1351.25
# T:54
# t:297
# fee:51
# profit:-3.5999999999996817
# mem:1351.6
# (H_k+L_k)/2:1351.6
# T:55
# t:298
# fee:52
# profit:-3.5999999999996817
# mem:1351.6
# (H_k+L_k)/2:1350.9
# T:56
# t:299
# fee:52
# position:-1
# profit:-3.5999999999996817
# mem:1350.55
# (H_k+L_k)/2:1350.55
# T:57
# t:300
# fee:53
# profit:-3.599999999999909
# mem:1350.5500000000002
# (H_k+L_k)/2:1350.5500000000002
# T:58
# t:301
# fee:54
# profit:-3.599999999999909
# mem:1350.5500000000002
# (H_k+L_k)/2:1350.5500000000002
# T:59
# t:302
# fee:54
# profit:-3.599999999999909
# mem:1350.5500000000002
# (H_k+L_k)/2:1350.1
# T:60
# t:303
# fee:54
# profit:-3.599999999999909
# mem:1350.5500000000002
# (H_k+L_k)/2:1350.5
# T:61
# t:304
# fee:54
# profit:-3.599999999999909
# mem:1350.5500000000002
# (H_k+L_k)/2:1351.0
# T:62
# t:305
# fee:54
# profit:-3.599999999999909
# mem:1350.5500000000002
# (H_k+L_k)/2:1351.05
# T:63
# t:306
# fee:54
# position:-1
# profit:-3.599999999999909
# mem:1350.6999999999998
# (H_k+L_k)/2:1350.6999999999998
# T:64
# t:307
# fee:55
# profit:-4.25
# mem:1351.35
# (H_k+L_k)/2:1351.35
# T:65
# t:308
# fee:56
# profit:-4.25
# mem:1351.35
# (H_k+L_k)/2:1352.05
# T:66
# t:309
# fee:56
# profit:-4.25
# mem:1351.35
# (H_k+L_k)/2:1352.25
# T:67
# t:310
# fee:56
# position:1
# profit:-4.25
# mem:1352.1
# (H_k+L_k)/2:1352.1
# T:68
# t:311
# fee:57
# position:1
# profit:-5.099999999999909
# mem:1351.25
# (H_k+L_k)/2:1351.25
# T:69
# t:312
# fee:59
# position:-1
# profit:-6.599999999999909
# mem:1349.75
# (H_k+L_k)/2:1349.75
# T:70
# t:313
# fee:61
# position:-1
# profit:-6.7999999999999545
# mem:1349.95
# (H_k+L_k)/2:1349.95
# T:71
# t:314
# fee:63
# position:-1
# profit:-6.649999999999864
# mem:1349.8
# (H_k+L_k)/2:1349.8
# T:72
# t:315
# fee:65
# position:-1
# profit:-7.599999999999909
# mem:1350.75
# (H_k+L_k)/2:1350.75
# T:73
# t:316
# fee:67
# position:1
# profit:-7.599999999999909
# mem:1350.75
# (H_k+L_k)/2:1350.75
# T:74
# t:317
# fee:69
# position:-1
# profit:-8.150000000000091
# mem:1350.1999999999998
# (H_k+L_k)/2:1350.1999999999998
# T:75
# t:318
# fee:71
# position:-1
# profit:-7.750000000000227
# mem:1349.8
# (H_k+L_k)/2:1349.8
# T:76
# t:319
# fee:73
# position:-1
# profit:-6.950000000000273
# mem:1349.0
# (H_k+L_k)/2:1349.0
# T:77
# t:320
# fee:75
# position:-1
# profit:-6.150000000000318
# mem:1348.2
# (H_k+L_k)/2:1348.2
# T:78
# t:321
# fee:77
# position:-1
# profit:-6.350000000000364
# mem:1348.4
# (H_k+L_k)/2:1348.4
# T:79
# t:322
# fee:79
# position:-1
# profit:-6.650000000000318
# mem:1348.7
# (H_k+L_k)/2:1348.7
# T:80
# t:323
# fee:81
# position:-1
# profit:-7.050000000000182
# mem:1349.1
# (H_k+L_k)/2:1349.1
# T:81
# t:324
# fee:83
# position:-1
# profit:-7.450000000000273
# mem:1349.5
# (H_k+L_k)/2:1349.5
# T:82
# t:325
# fee:85
# position:-1
# profit:-6.850000000000364
# mem:1348.9
# (H_k+L_k)/2:1348.9
# T:83
# t:326
# fee:87
# position:-1
# profit:-7.650000000000091
# mem:1349.6999999999998
# (H_k+L_k)/2:1349.6999999999998
# T:84
# t:327
# fee:89
# position:1
# profit:-8.350000000000364
# mem:1350.4
# (H_k+L_k)/2:1350.4
# T:85
# t:328
# fee:91
# position:-1
# profit:-8.850000000000364
# mem:1349.9
# (H_k+L_k)/2:1349.9
# T:86
# t:329
# fee:93
# position:1
# profit:-8.050000000000182
# mem:1349.1
# (H_k+L_k)/2:1349.1
# T:87
# t:330
# fee:95
# position:1
# profit:-6.700000000000273
# mem:1350.4499999999998
# (H_k+L_k)/2:1350.4499999999998
# T:88
# t:331
# fee:97
# position:1
# profit:-5.4500000000000455
# mem:1351.7
# (H_k+L_k)/2:1351.7
# T:89
# t:332
# fee:99
# position:1
# profit:-6.200000000000273
# mem:1350.9499999999998
# (H_k+L_k)/2:1350.9499999999998
# T:90
# t:333
# fee:101
# position:-1
# profit:-7.9500000000000455
# mem:1349.2
# (H_k+L_k)/2:1349.2
# T:91
# t:334
# fee:103
# position:-1
# profit:-6.849999999999909
# mem:1348.1
# (H_k+L_k)/2:1348.1
# T:92
# t:335
# fee:105
# position:-1
# profit:-6.849999999999909
# mem:1348.1
# (H_k+L_k)/2:1346.4499999999998
# T:93
# t:336
# fee:105
# position:-1
# profit:-6.849999999999909
# mem:1348.1
# (H_k+L_k)/2:1345.05
# T:94
# t:337
# fee:105
# position:-1
# profit:-6.849999999999909
# mem:1348.1
# (H_k+L_k)/2:1345.0
# T:95
# t:338
# fee:105
# position:-1
# profit:-6.849999999999909
# mem:1348.1
# (H_k+L_k)/2:1345.0
# T:96
# t:339
# fee:105
# position:-1
# profit:-6.849999999999909
# mem:1348.1
# (H_k+L_k)/2:1344.35
# T:97
# t:340
# fee:105
# position:-1
# profit:-6.849999999999909
# mem:1348.1
# (H_k+L_k)/2:1343.7
# T:98
# t:341
# fee:105
# position:-1
# profit:-6.849999999999909
# mem:1348.1
# (H_k+L_k)/2:1344.4
# T:99
# t:342
# fee:105
# position:-1
# profit:-5.0499999999999545
# mem:1346.3
# (H_k+L_k)/2:1346.3
# T:100
# t:343
# fee:107
# position:-1
# profit:-5.099999999999909
# mem:1346.35
# (H_k+L_k)/2:1346.35
# T:101
# t:344
# fee:109
# position:-1
# profit:-5.25
# mem:1346.5
# (H_k+L_k)/2:1346.5
# T:102
# t:345
# fee:111
# position:1
# profit:-5.2000000000000455
# mem:1346.45
# (H_k+L_k)/2:1346.45
# T:103
# t:346
# fee:113
# position:1
# profit:-5.050000000000182
# mem:1346.6
# (H_k+L_k)/2:1346.6
# T:104
# t:347
# fee:115
# position:1
# profit:-5.600000000000136
# mem:1346.05
# (H_k+L_k)/2:1346.05
# T:105
# t:348
# fee:117
# position:1
# profit:-6.400000000000091
# mem:1345.25
# (H_k+L_k)/2:1345.25
# T:106
# t:349
# fee:119
# position:1
# profit:-5.850000000000136
# mem:1345.8
# (H_k+L_k)/2:1345.8
# T:107
# t:350
# fee:121
# position:1
# profit:-6.200000000000273
# mem:1345.4499999999998
# (H_k+L_k)/2:1345.4499999999998
# T:108
# t:351
# fee:123
# position:-1
# profit:-7.050000000000182
# mem:1344.6
# (H_k+L_k)/2:1344.6
# T:109
# t:352
# fee:125
# position:-1
# profit:-7.450000000000273
# mem:1345.0
# (H_k+L_k)/2:1345.0
# T:110
# t:353
# fee:127
# position:-1
# profit:-7.750000000000227
# mem:1345.3
# (H_k+L_k)/2:1345.3
# T:111
# t:354
# fee:129
# position:-1
# profit:-7.700000000000273
# mem:1345.25
# (H_k+L_k)/2:1345.25
# T:112
# t:355
# fee:131
# position:-1
# profit:-7.200000000000273
# mem:1344.75
# (H_k+L_k)/2:1344.75
# T:113
# t:356
# fee:133
# position:-1
# profit:-6.800000000000182
# mem:1344.35
# (H_k+L_k)/2:1344.35
# T:114
# t:357
# fee:135
# position:-1
# profit:-6.550000000000182
# mem:1344.1
# (H_k+L_k)/2:1344.1
# T:115
# t:358
# fee:137
# position:-1
# profit:-6.000000000000227
# mem:1343.55
# (H_k+L_k)/2:1343.55
# T:116
# t:359
# fee:139
# position:-1
# profit:-6.000000000000455
# mem:1343.5500000000002
# (H_k+L_k)/2:1343.5500000000002
# T:117
# t:360
# fee:141
# position:-1
# profit:-6.200000000000273
# mem:1343.75
# (H_k+L_k)/2:1343.75
# T:118
# t:361
# fee:143
# position:-1
# profit:-6.450000000000273
# mem:1344.0
# (H_k+L_k)/2:1344.0
# T:119
# t:362
# fee:145
# position:-1
# profit:-6.300000000000182
# mem:1343.85
# (H_k+L_k)/2:1343.85
# T:120
# t:363
# fee:147
# position:-1
# profit:-6.600000000000364
# mem:1344.15
# (H_k+L_k)/2:1344.15
# T:121
# t:364
# fee:149
# position:-1
# profit:-6.700000000000273
# mem:1344.25
# (H_k+L_k)/2:1344.25
# T:122
# t:365
# fee:151
# position:-1
# profit:-6.250000000000455
# mem:1343.8000000000002
# (H_k+L_k)/2:1343.8000000000002
# T:123
# t:366
# fee:153
# position:-1
# profit:-5.100000000000364
# mem:1342.65
# (H_k+L_k)/2:1342.65
# T:124
# t:367
# fee:155
# position:-1
# profit:-3.400000000000091
# mem:1340.9499999999998
# (H_k+L_k)/2:1340.9499999999998
# T:125
# t:368
# fee:156
# position:-1
# profit:-4.050000000000182
# mem:1341.6
# (H_k+L_k)/2:1341.6
# T:126
# t:369
# fee:158
# position:-1
# profit:-3.200000000000273
# mem:1340.75
# (H_k+L_k)/2:1340.75
# T:127
# t:370
# fee:160
# position:-1
# profit:-3.950000000000273
# mem:1341.5
# (H_k+L_k)/2:1341.5
# T:128
# t:371
# fee:162
# position:-1
# profit:-4.500000000000455
# mem:1342.0500000000002
# (H_k+L_k)/2:1342.0500000000002
# T:129
# t:372
# fee:164
# position:-1
# profit:-3.950000000000273
# mem:1341.5
# (H_k+L_k)/2:1341.5
# T:130
# t:373
# fee:166
# position:-1
# profit:-3.350000000000364
# mem:1340.9
# (H_k+L_k)/2:1340.9
# T:131
# t:374
# fee:168
# position:-1
# profit:-3.350000000000364
# mem:1340.9
# (H_k+L_k)/2:1340.9
# T:132
# t:375
# fee:170
# position:-1
# profit:-3.7500000000004547
# mem:1341.3000000000002
# (H_k+L_k)/2:1341.3000000000002
# T:133
# t:376
# fee:172
# position:-1
# profit:-4.050000000000182
# mem:1341.6
# (H_k+L_k)/2:1341.6
# T:134
# t:377
# fee:174
# position:-1
# profit:-3.7500000000002274
# mem:1341.3
# (H_k+L_k)/2:1341.3
# T:135
# t:378
# fee:176
# position:-1
# profit:-3.400000000000091
# mem:1340.9499999999998
# (H_k+L_k)/2:1340.9499999999998
# T:136
# t:379
# fee:178
# position:-1
# profit:-3.2500000000002274
# mem:1340.8
# (H_k+L_k)/2:1340.8
# T:137
# t:380
# fee:180
# position:-1
# profit:-3.700000000000273
# mem:1341.25
# (H_k+L_k)/2:1341.25
# T:138
# t:381
# fee:182
# position:1
# profit:-4.450000000000273
# mem:1342.0
# (H_k+L_k)/2:1342.0
# T:139
# t:382
# fee:184
# position:1
# profit:-4.550000000000182
# mem:1341.9
# (H_k+L_k)/2:1341.9
# T:140
# t:383
# fee:186
# position:1
# profit:-4.200000000000273
# mem:1342.25
# (H_k+L_k)/2:1342.25
# T:141
# t:384
# fee:188
# position:1
# profit:-4.550000000000182
# mem:1341.9
# (H_k+L_k)/2:1341.9
# T:142
# t:385
# fee:190
# position:-1
# profit:-4.850000000000364
# mem:1341.6
# (H_k+L_k)/2:1341.6
# T:143
# t:386
# fee:192
# position:1
# profit:-4.600000000000364
# mem:1341.35
# (H_k+L_k)/2:1341.35
# T:144
# t:387
# fee:194
# position:-1
# profit:-4.400000000000318
# mem:1341.55
# (H_k+L_k)/2:1341.55
# T:145
# t:388
# fee:196
# position:1
# profit:-4.300000000000182
# mem:1341.4499999999998
# (H_k+L_k)/2:1341.4499999999998
# T:146
# t:389
# fee:198
# position:1
# profit:-4.050000000000182
# mem:1341.6999999999998
# (H_k+L_k)/2:1341.6999999999998
# T:147
# t:390
# fee:200
# position:1
# profit:-3.7999999999999545
# mem:1341.95
# (H_k+L_k)/2:1341.95
# T:148
# t:391
# fee:202
# position:-1
# profit:-3.7000000000000455
# mem:1342.05
# (H_k+L_k)/2:1342.05
# T:149
# t:392
# fee:204
# position:-1
# profit:-3.550000000000182
# mem:1341.9
# (H_k+L_k)/2:1341.9
# T:150
# t:393
# fee:206
# position:-1
# profit:-3.550000000000182
# mem:1341.9
# (H_k+L_k)/2:1341.9
# T:151
# t:394
# fee:208
# position:1
# profit:-3.900000000000091
# mem:1342.25
# (H_k+L_k)/2:1342.25
# T:152
# t:395
# fee:210
# position:1
# profit:-3.8500000000001364
# mem:1342.3
# (H_k+L_k)/2:1342.3
# T:153
# t:396
# fee:212
# profit:-3.550000000000182
# mem:1342.6
# (H_k+L_k)/2:1342.6
# T:154
# t:397
# fee:213
# position:1
# profit:-3.550000000000182
# mem:1342.25
# (H_k+L_k)/2:1342.25
# T:155
# t:398
# fee:214
# position:1
# profit:-3.8500000000001364
# mem:1341.95
# (H_k+L_k)/2:1341.95
# T:156
# t:399
# fee:216
# position:-1
# profit:-3.8500000000001364
# mem:1341.95
# (H_k+L_k)/2:1341.95
# T:157
# t:400
# fee:218
# position:-1
# profit:-3.400000000000091
# mem:1341.5
# (H_k+L_k)/2:1341.5
# T:158
# t:401
# fee:220
# position:1
# profit:-4.2000000000000455
# mem:1342.3
# (H_k+L_k)/2:1342.3
# T:159
# t:402
# fee:222
# position:-1
# profit:-4.5
# mem:1342.0
# (H_k+L_k)/2:1342.0
# T:160
# t:403
# fee:224
# position:-1
# profit:-4.5
# mem:1342.0
# (H_k+L_k)/2:1340.7
# T:161
# t:404
# fee:224
# position:-1
# profit:-4.5
# mem:1342.0
# (H_k+L_k)/2:1340.0
# T:162
# t:405
# fee:224
# position:-1
# profit:-4.5
# mem:1342.0
# (H_k+L_k)/2:1339.85
# T:163
# t:406
# fee:224
# position:-1
# profit:-4.5
# mem:1342.0
# (H_k+L_k)/2:1339.35
# T:164
# t:407
# fee:224
# position:-1
# profit:-4.5
# mem:1342.0
# (H_k+L_k)/2:1338.9
# T:165
# t:408
# fee:224
# position:-1
# profit:-4.5
# mem:1342.0
# (H_k+L_k)/2:1338.3
# T:166
# t:409
# fee:224
# position:-1
# profit:-4.5
# mem:1342.0
# (H_k+L_k)/2:1337.5
# T:167
# t:410
# fee:224
# position:-1
# profit:-4.5
# mem:1342.0
# (H_k+L_k)/2:1336.25
# T:168
# t:411
# fee:224
# position:-1
# profit:-4.5
# mem:1342.0
# (H_k+L_k)/2:1335.95
# T:169
# t:412
# fee:224
# position:-1
# profit:-4.5
# mem:1342.0
# (H_k+L_k)/2:1335.5
# T:170
# t:413
# fee:224
# position:-1
# profit:-4.5
# mem:1342.0
# (H_k+L_k)/2:1335.75
# T:171
# t:414
# fee:224
# position:-1
# profit:1.699999999999818
# mem:1335.8000000000002
# (H_k+L_k)/2:1335.8000000000002
# T:172
# t:415
# fee:226
# position:-1
# profit:1.4500000000000455
# mem:1336.05
# (H_k+L_k)/2:1336.05
# T:173
# t:416
# fee:228
# position:-1
# profit:1.0
# mem:1336.5
# (H_k+L_k)/2:1336.5
# T:174
# t:417
# fee:230
# position:-1
# profit:1.0
# mem:1336.5
# (H_k+L_k)/2:1336.5
# T:175
# t:418
# fee:232
# position:-1
# profit:1.550000000000182
# mem:1335.9499999999998
# (H_k+L_k)/2:1335.9499999999998
# T:176
# t:419
# fee:234
# position:-1
# profit:1.5499999999999545
# mem:1335.95
# (H_k+L_k)/2:1335.95
# T:177
# t:420
# fee:236
# position:-1
# profit:2.0
# mem:1335.5
# (H_k+L_k)/2:1335.5
# T:178
# t:421
# fee:238
# position:1
# profit:1.25
# mem:1336.25
# (H_k+L_k)/2:1336.25
# T:179
# t:422
# fee:240
# position:-1
# profit:0.2999999999999545
# mem:1335.3
# (H_k+L_k)/2:1335.3
# T:180
# t:423
# fee:242
# position:-1
# profit:1.5499999999997272
# mem:1334.0500000000002
# (H_k+L_k)/2:1334.0500000000002
# T:181
# t:424
# fee:243
# position:-1
# profit:1.5499999999997272
# mem:1334.0500000000002
# (H_k+L_k)/2:1332.4499999999998
# T:182
# t:425
# fee:243
# position:-1
# profit:1.5499999999997272
# mem:1334.0500000000002
# (H_k+L_k)/2:1332.85
# T:183
# t:426
# fee:243
# position:-1
# profit:2.349999999999909
# mem:1333.25
# (H_k+L_k)/2:1333.25
# T:184
# t:427
# fee:245
# position:-1
# profit:2.049999999999727
# mem:1333.5500000000002
# (H_k+L_k)/2:1333.5500000000002
# T:185
# t:428
# fee:247
# position:-1
# profit:2.25
# mem:1333.35
# (H_k+L_k)/2:1333.35
# T:186
# t:429
# fee:249
# position:-1
# profit:3.049999999999727
# mem:1332.5500000000002
# (H_k+L_k)/2:1332.5500000000002
# T:187
# t:430
# fee:251
# position:-1
# profit:3.049999999999727
# mem:1332.5500000000002
# (H_k+L_k)/2:1331.15
# T:188
# t:431
# fee:251
# position:-1
# profit:3.049999999999727
# mem:1332.5500000000002
# (H_k+L_k)/2:1330.9
# T:189
# t:432
# fee:251
# position:-1
# profit:3.049999999999727
# mem:1332.5500000000002
# (H_k+L_k)/2:1331.35
# T:190
# t:433
# fee:251
# position:-1
# profit:3.75
# mem:1331.85
# (H_k+L_k)/2:1331.85
# T:191
# t:434
# fee:253
# position:1
# profit:4.0499999999999545
# mem:1331.55
# (H_k+L_k)/2:1331.55
# T:192
# t:435
# fee:255
# position:-1
# profit:4.400000000000091
# mem:1331.9
# (H_k+L_k)/2:1331.9
# T:193
# t:436
# fee:257
# position:-1
# profit:5.25
# mem:1331.0500000000002
# (H_k+L_k)/2:1331.0500000000002
# T:194
# t:437
# fee:259
# position:-1
# profit:5.700000000000273
# mem:1330.6
# (H_k+L_k)/2:1330.6
# T:195
# t:438
# fee:261
# position:-1
# profit:5.150000000000091
# mem:1331.15
# (H_k+L_k)/2:1331.15
# T:196
# t:439
# fee:263
# position:-1
# profit:5.050000000000182
# mem:1331.25
# (H_k+L_k)/2:1331.25
# T:197
# t:440
# fee:265
# position:1
# profit:4.900000000000091
# mem:1331.4
# (H_k+L_k)/2:1331.4
# T:198
# t:441
# fee:267
# position:1
# profit:4.7000000000000455
# mem:1331.2
# (H_k+L_k)/2:1331.2
# T:199
# t:442
# fee:269
# position:-1
# profit:4.550000000000182
# mem:1331.0500000000002
# (H_k+L_k)/2:1331.0500000000002
# T:200
# t:443
# fee:271
# position:-1
# profit:5.100000000000364
# mem:1330.5
# (H_k+L_k)/2:1330.5
# T:201
# t:444
# fee:273
# position:-1
# profit:4.850000000000364
# mem:1330.75
# (H_k+L_k)/2:1330.75
# T:202
# t:445
# fee:275
# position:-1
# profit:4.700000000000273
# mem:1330.9
# (H_k+L_k)/2:1330.9
# T:203
# t:446
# fee:277
# position:1
# profit:3.950000000000273
# mem:1331.65
# (H_k+L_k)/2:1331.65
# T:204
# t:447
# fee:279
# position:1
# profit:4.400000000000091
# mem:1332.1
# (H_k+L_k)/2:1332.1
# T:205
# t:448
# fee:281
# position:1
# profit:4.950000000000273
# mem:1332.65
# (H_k+L_k)/2:1332.65
# T:206
# t:449
# fee:283
# position:1
# profit:4.750000000000227
# mem:1332.45
# (H_k+L_k)/2:1332.45
# T:207
# t:450
# fee:285
# position:1
# profit:4.5
# mem:1332.1999999999998
# (H_k+L_k)/2:1332.1999999999998
# T:208
# t:451
# fee:287
# position:-1
# profit:3.700000000000273
# mem:1331.4
# (H_k+L_k)/2:1331.4
# T:209
# t:452
# fee:289
# position:1
# profit:3.5500000000004093
# mem:1331.55
# (H_k+L_k)/2:1331.55
# T:210
# t:453
# fee:291
# position:1
# profit:4.350000000000364
# mem:1332.35
# (H_k+L_k)/2:1332.35
# T:211
# t:454
# fee:293
# position:1
# profit:4.350000000000364
# mem:1332.35
# (H_k+L_k)/2:1332.35
# T:212
# t:455
# fee:295
# position:1
# profit:4.000000000000455
# mem:1332.0
# (H_k+L_k)/2:1332.0
# T:213
# t:456
# fee:297
# profit:3.9000000000005457
# mem:1331.9
# (H_k+L_k)/2:1331.9
# T:214
# t:457
# fee:298
# profit:3.9000000000005457
# mem:1331.9
# (H_k+L_k)/2:1332.25
# T:215
# t:458
# fee:298
# profit:3.9000000000005457
# mem:1331.9
# (H_k+L_k)/2:1331.8
# T:216
# t:459
# fee:298
# profit:3.9000000000005457
# mem:1331.9
# (H_k+L_k)/2:1332.5500000000002
# T:217
# t:460
# fee:298
# profit:3.9000000000005457
# mem:1331.9
# (H_k+L_k)/2:1332.5500000000002
# T:218
# t:461
# fee:298
# profit:3.9000000000005457
# mem:1331.9
# (H_k+L_k)/2:1332.3
# T:219
# t:462
# fee:298
# profit:3.9000000000005457
# mem:1331.9
# (H_k+L_k)/2:1332.25
# T:220
# t:463
# fee:298
# profit:3.9000000000005457
# mem:1331.9
# (H_k+L_k)/2:1332.15
# T:221
# t:464
# fee:298
# profit:3.9000000000005457
# mem:1331.9
# (H_k+L_k)/2:1332.35
# T:222
# t:465
# fee:298
# profit:3.9000000000005457
# mem:1331.9
# (H_k+L_k)/2:1332.25
# T:223
# t:466
# fee:298
# profit:3.9000000000005457
# mem:1331.9
# (H_k+L_k)/2:1332.6
# T:224
# t:467
# fee:298
# profit:3.9000000000005457
# mem:1331.9
# (H_k+L_k)/2:1333.15
# T:225
# t:468
# fee:298
# profit:3.9000000000005457
# mem:1331.9
# (H_k+L_k)/2:1333.35
# T:226
# t:469
# fee:298
# profit:3.9000000000005457
# mem:1331.9
# (H_k+L_k)/2:1333.85
# T:227
# t:470
# fee:298
# profit:3.9000000000005457
# mem:1331.9
# (H_k+L_k)/2:1332.35
# T:228
# t:471
# fee:298
# profit:3.9000000000005457
# mem:1331.9
# (H_k+L_k)/2:1330.7
# T:229
# t:472
# fee:298
# position:-1
# profit:3.9000000000005457
# mem:1331.85
# (H_k+L_k)/2:1331.85
# T:230
# t:473
# fee:299
# position:1
# profit:2.5000000000004547
# mem:1333.25
# (H_k+L_k)/2:1333.25
# T:231
# t:474
# fee:301
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1334.25
# T:232
# t:475
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1334.9
# T:233
# t:476
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1335.0500000000002
# T:234
# t:477
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1334.65
# T:235
# t:478
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1334.85
# T:236
# t:479
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1334.4
# T:237
# t:480
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1334.45
# T:238
# t:481
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1334.5500000000002
# T:239
# t:482
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1334.1
# T:240
# t:483
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1333.9499999999998
# T:241
# t:484
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1334.1
# T:242
# t:485
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1334.15
# T:243
# t:486
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1334.6
# T:244
# t:487
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1335.0
# T:245
# t:488
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1335.1
# T:246
# t:489
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1334.85
# T:247
# t:490
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1334.4
# T:248
# t:491
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1335.4499999999998
# T:249
# t:492
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1334.9
# T:250
# t:493
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1333.5500000000002
# T:251
# t:494
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1332.95
# T:252
# t:495
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1333.85
# T:253
# t:496
# fee:302
# profit:3.5000000000004547
# mem:1334.25
# (H_k+L_k)/2:1332.9
# T:254
# t:497
# fee:302
# position:-1
# profit:3.5000000000004547
# mem:1332.9499999999998
# (H_k+L_k)/2:1332.9499999999998
# T:255
# t:498
# fee:303
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1333.2
# T:256
# t:499
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1333.0
# T:257
# t:500
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1333.8000000000002
# T:258
# t:501
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1334.6
# T:259
# t:502
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1335.2
# T:260
# t:503
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1335.1
# T:261
# t:504
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1334.5
# T:262
# t:505
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1334.65
# T:263
# t:506
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1335.0500000000002
# T:264
# t:507
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1335.0
# T:265
# t:508
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1334.6
# T:266
# t:509
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1334.1
# T:267
# t:510
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1333.35
# T:268
# t:511
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1333.65
# T:269
# t:512
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1333.85
# T:270
# t:513
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1333.9
# T:271
# t:514
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1334.1999999999998
# T:272
# t:515
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1333.1
# T:273
# t:516
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1332.15
# T:274
# t:517
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1332.1999999999998
# T:275
# t:518
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1333.3000000000002
# T:276
# t:519
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1334.25
# T:277
# t:520
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1334.25
# T:278
# t:521
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1335.5500000000002
# T:279
# t:522
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1336.7
# T:280
# t:523
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1337.65
# T:281
# t:524
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1337.05
# T:282
# t:525
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1336.15
# T:283
# t:526
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1335.9
# T:284
# t:527
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1336.85
# T:285
# t:528
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1336.5500000000002
# T:286
# t:529
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1336.15
# T:287
# t:530
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1336.6999999999998
# T:288
# t:531
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1338.05
# T:289
# t:532
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1339.55
# T:290
# t:533
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1339.25
# T:291
# t:534
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1338.8
# T:292
# t:535
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1338.4
# T:293
# t:536
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1338.95
# T:294
# t:537
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1339.35
# T:295
# t:538
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1339.85
# T:296
# t:539
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1339.75
# T:297
# t:540
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1340.1
# T:298
# t:541
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1339.85
# T:299
# t:542
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1339.55
# T:300
# t:543
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1339.4
# T:301
# t:544
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1339.65
# T:302
# t:545
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1339.65
# T:303
# t:546
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1338.9
# T:304
# t:547
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1339.2
# T:305
# t:548
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1339.0
# T:306
# t:549
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1338.4499999999998
# T:307
# t:550
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1338.0500000000002
# T:308
# t:551
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1338.25
# T:309
# t:552
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1338.5
# T:310
# t:553
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1338.5
# T:311
# t:554
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1338.75
# T:312
# t:555
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1339.1999999999998
# T:313
# t:556
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1339.55
# T:314
# t:557
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1339.25
# T:315
# t:558
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1338.8000000000002
# T:316
# t:559
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1338.3000000000002
# T:317
# t:560
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1337.6
# T:318
# t:561
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1337.95
# T:319
# t:562
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1337.9
# T:320
# t:563
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1336.85
# T:321
# t:564
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1336.45
# T:322
# t:565
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1336.85
# T:323
# t:566
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1336.75
# T:324
# t:567
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1336.6
# T:325
# t:568
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1336.45
# T:326
# t:569
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1336.4
# T:327
# t:570
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1336.6
# T:328
# t:571
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1336.6
# T:329
# t:572
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1336.6
# T:330
# t:573
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1336.15
# T:331
# t:574
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1335.75
# T:332
# t:575
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1335.95
# T:333
# t:576
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1335.15
# T:334
# t:577
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1334.9
# T:335
# t:578
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1334.75
# T:336
# t:579
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1333.95
# T:337
# t:580
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1334.3
# T:338
# t:581
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1334.5500000000002
# T:339
# t:582
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1333.4499999999998
# T:340
# t:583
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1332.7
# T:341
# t:584
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1332.75
# T:342
# t:585
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1332.75
# T:343
# t:586
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1331.5500000000002
# T:344
# t:587
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1331.4499999999998
# T:345
# t:588
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1331.75
# T:346
# t:589
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1331.5
# T:347
# t:590
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1331.3000000000002
# T:348
# t:591
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1331.35
# T:349
# t:592
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1332.15
# T:350
# t:593
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1332.65
# T:351
# t:594
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1332.7
# T:352
# t:595
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1332.85
# T:353
# t:596
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1332.85
# T:354
# t:597
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1332.2
# T:355
# t:598
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1331.85
# T:356
# t:599
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1331.65
# T:357
# t:600
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1331.9
# T:358
# t:601
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1331.8
# T:359
# t:602
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1331.85
# T:360
# t:603
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1331.25
# T:361
# t:604
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1330.0
# T:362
# t:605
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1328.4
# T:363
# t:606
# fee:304
# profit:3.2500000000002274
# mem:1333.2
# (H_k+L_k)/2:1328.25
# T:364
# t:607
# fee:304
# position:-1
# profit:3.2500000000002274
# mem:1327.8000000000002
# (H_k+L_k)/2:1327.8000000000002
# T:365
# t:608
# fee:305
# position:-1
# profit:3.2500000000002274
# mem:1327.8000000000002
# (H_k+L_k)/2:1326.95
# T:366
# t:609
# fee:305
# position:-1
# profit:3.2500000000002274
# mem:1327.8000000000002
# (H_k+L_k)/2:1328.25
# T:367
# t:610
# fee:305
# position:-1
# profit:2.9500000000005002
# mem:1328.1
# (H_k+L_k)/2:1328.1
# T:368
# t:611
# fee:307
# position:-1
# profit:3.0500000000004093
# mem:1328.0
# (H_k+L_k)/2:1328.0
# T:369
# t:612
# fee:309
# position:-1
# profit:2.2000000000005002
# mem:1328.85
# (H_k+L_k)/2:1328.85
# T:370
# t:613
# fee:311
# position:-1
# profit:1.5500000000004093
# mem:1329.5
# (H_k+L_k)/2:1329.5
# T:371
# t:614
# fee:313
# position:-1
# profit:2.3000000000004093
# mem:1328.75
# (H_k+L_k)/2:1328.75
# T:372
# t:615
# fee:315
# position:-1
# profit:3.100000000000364
# mem:1327.95
# (H_k+L_k)/2:1327.95
# T:373
# t:616
# fee:317
# position:-1
# profit:3.7500000000004547
# mem:1327.3
# (H_k+L_k)/2:1327.3
# T:374
# t:617
# fee:319
# position:1
# profit:3.2000000000005002
# mem:1327.85
# (H_k+L_k)/2:1327.85
# T:375
# t:618
# fee:321
# position:1
# profit:2.9500000000005002
# mem:1327.6
# (H_k+L_k)/2:1327.6
# T:376
# t:619
# fee:323
# position:1
# profit:3.7000000000005002
# mem:1328.35
# (H_k+L_k)/2:1328.35
# T:377
# t:620
# fee:325
# position:1
# profit:3.650000000000773
# mem:1328.3000000000002
# (H_k+L_k)/2:1328.3000000000002
# T:378
# t:621
# fee:327
# position:1
# profit:3.850000000000591
# mem:1328.5
# (H_k+L_k)/2:1328.5
# T:379
# t:622
# fee:329
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1328.75
# T:380
# t:623
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.5
# T:381
# t:624
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.6999999999998
# T:382
# t:625
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.6
# T:383
# t:626
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.25
# T:384
# t:627
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.0
# T:385
# t:628
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.9
# T:386
# t:629
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.75
# T:387
# t:630
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.25
# T:388
# t:631
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.15
# T:389
# t:632
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.25
# T:390
# t:633
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.4
# T:391
# t:634
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.4
# T:392
# t:635
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1330.0
# T:393
# t:636
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1330.85
# T:394
# t:637
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1330.5
# T:395
# t:638
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1330.55
# T:396
# t:639
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1330.7
# T:397
# t:640
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1330.1
# T:398
# t:641
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1330.3
# T:399
# t:642
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.8000000000002
# T:400
# t:643
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.35
# T:401
# t:644
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.4499999999998
# T:402
# t:645
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.6
# T:403
# t:646
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.9499999999998
# T:404
# t:647
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1330.15
# T:405
# t:648
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1329.9
# T:406
# t:649
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1330.1
# T:407
# t:650
# fee:330
# profit:4.100000000000591
# mem:1328.75
# (H_k+L_k)/2:1330.3000000000002
# T:408
# t:651
# fee:330
# position:1
# profit:4.100000000000591
# mem:1330.5
# (H_k+L_k)/2:1330.5
# T:409
# t:652
# fee:331
# position:1
# profit:4.350000000000591
# mem:1330.75
# (H_k+L_k)/2:1330.75
# T:410
# t:653
# fee:333
# position:1
# profit:4.4500000000005
# mem:1330.85
# (H_k+L_k)/2:1330.85
# T:411
# t:654
# fee:335
# position:1
# profit:4.300000000000637
# mem:1330.7
# (H_k+L_k)/2:1330.7
# T:412
# t:655
# fee:337
# position:1
# profit:3.8000000000006366
# mem:1330.2
# (H_k+L_k)/2:1330.2
# T:413
# t:656
# fee:339
# position:1
# profit:4.050000000000637
# mem:1330.45
# (H_k+L_k)/2:1330.45
# T:414
# t:657
# fee:341
# profit:4.600000000000591
# mem:1331.0
# (H_k+L_k)/2:1331.0
# T:415
# t:658
# fee:342
# profit:4.600000000000591
# mem:1331.0
# (H_k+L_k)/2:1331.4499999999998
# T:416
# t:659
# fee:342
# profit:4.600000000000591
# mem:1331.0
# (H_k+L_k)/2:1331.75
# T:417
# t:660
# fee:342
# profit:4.600000000000591
# mem:1331.0
# (H_k+L_k)/2:1331.3
# T:418
# t:661
# fee:342
# profit:4.600000000000591
# mem:1331.0
# (H_k+L_k)/2:1330.9
# T:419
# t:662
# fee:342
# profit:4.600000000000591
# mem:1331.0
# (H_k+L_k)/2:1330.85
# T:420
# t:663
# fee:342
# position:1
# profit:4.600000000000591
# mem:1330.95
# (H_k+L_k)/2:1330.95
# T:421
# t:664
# fee:343
# position:1
# profit:4.7000000000005
# mem:1331.05
# (H_k+L_k)/2:1331.05
# T:422
# t:665
# fee:345
# position:1
# profit:4.850000000000591
# mem:1331.2
# (H_k+L_k)/2:1331.2
# T:423
# t:666
# fee:347
# position:-1
# profit:4.4500000000005
# mem:1330.8
# (H_k+L_k)/2:1330.8
# T:424
# t:667
# fee:349
# position:-1
# profit:4.4500000000005
# mem:1330.8
# (H_k+L_k)/2:1330.8
# T:425
# t:668
# fee:351
# position:-1
# profit:4.4500000000005
# mem:1330.8
# (H_k+L_k)/2:1330.8
# T:426
# t:669
# fee:353
# position:-1
# profit:4.400000000000546
# mem:1330.85
# (H_k+L_k)/2:1330.85
# T:427
# t:670
# fee:355
# position:1
# profit:4.350000000000364
# mem:1330.9
# (H_k+L_k)/2:1330.9
# T:428
# t:671
# fee:357
# position:1
# profit:4.500000000000227
# mem:1331.05
# (H_k+L_k)/2:1331.05
# T:429
# t:672
# fee:359
# profit:4.450000000000273
# mem:1331.0
# (H_k+L_k)/2:1331.0
# T:430
# t:673
# fee:360
# position:1
# profit:4.450000000000273
# mem:1331.5
# (H_k+L_k)/2:1331.5
# T:431
# t:674
# fee:361
# position:1
# profit:4.750000000000455
# mem:1331.8000000000002
# (H_k+L_k)/2:1331.8000000000002
# T:432
# t:675
# fee:363
# profit:4.250000000000227
# mem:1331.3
# (H_k+L_k)/2:1331.3
# T:433
# t:676
# fee:364
# position:1
# profit:4.250000000000227
# mem:1331.45
# (H_k+L_k)/2:1331.45
# T:434
# t:677
# fee:365
# profit:5.25
# mem:1332.4499999999998
# (H_k+L_k)/2:1332.4499999999998
# T:435
# t:678
# fee:366
# profit:5.25
# mem:1332.4499999999998
# (H_k+L_k)/2:1333.05
# T:436
# t:679
# fee:366
# profit:5.25
# mem:1332.4499999999998
# (H_k+L_k)/2:1332.9499999999998
# T:437
# t:680
# fee:366
# profit:5.25
# mem:1332.4499999999998
# (H_k+L_k)/2:1332.4
# T:438
# t:681
# fee:366
# profit:5.25
# mem:1332.4499999999998
# (H_k+L_k)/2:1331.35
# T:439
# t:682
# fee:366
# profit:5.25
# mem:1332.4499999999998
# (H_k+L_k)/2:1330.4499999999998
# T:440
# t:683
# fee:366
# position:-1
# profit:5.25
# mem:1330.65
# (H_k+L_k)/2:1330.65
# T:441
# t:684
# fee:367
# profit:5.150000000000091
# mem:1330.75
# (H_k+L_k)/2:1330.75
# T:442
# t:685
# fee:368
# profit:5.150000000000091
# mem:1330.75
# (H_k+L_k)/2:1330.1
# T:443
# t:686
# fee:368
# position:-1
# profit:5.150000000000091
# mem:1329.2
# (H_k+L_k)/2:1329.2
# T:444
# t:687
# fee:369
# position:-1
# profit:5.150000000000091
# mem:1329.2
# (H_k+L_k)/2:1329.55
# T:445
# t:688
# fee:369
# position:-1
# profit:4.4500000000000455
# mem:1329.9
# (H_k+L_k)/2:1329.9
# T:446
# t:689
# fee:371
# position:-1
# profit:3.7000000000000455
# mem:1330.65
# (H_k+L_k)/2:1330.65
# T:447
# t:690
# fee:373
# position:-1
# profit:4.400000000000091
# mem:1329.95
# (H_k+L_k)/2:1329.95
# T:448
# t:691
# fee:375
# position:-1
# profit:4.550000000000182
# mem:1329.8
# (H_k+L_k)/2:1329.8
# T:449
# t:692
# fee:377
# position:1
# profit:4.000000000000227
# mem:1330.35
# (H_k+L_k)/2:1330.35
# T:450
# t:693
# fee:379
# position:1
# profit:4.000000000000227
# mem:1330.35
# (H_k+L_k)/2:1331.65
# T:451
# t:694
# fee:379
# position:1
# profit:4.000000000000227
# mem:1330.35
# (H_k+L_k)/2:1332.5
# T:452
# t:695
# fee:379
# position:1
# profit:4.000000000000227
# mem:1330.35
# (H_k+L_k)/2:1332.5
# T:453
# t:696
# fee:379
# position:1
# profit:4.000000000000227
# mem:1330.35
# (H_k+L_k)/2:1332.5500000000002
# T:454
# t:697
# fee:379
# profit:5.300000000000409
# mem:1331.65
# (H_k+L_k)/2:1331.65
# T:455
# t:698
# fee:380
# position:1
# profit:5.300000000000409
# mem:1331.2
# (H_k+L_k)/2:1331.2
# T:456
# t:699
# fee:381
# position:-1
# profit:4.450000000000273
# mem:1330.35
# (H_k+L_k)/2:1330.35
# T:457
# t:700
# fee:383
# position:1
# profit:4.450000000000273
# mem:1330.35
# (H_k+L_k)/2:1330.35
# T:458
# t:701
# fee:385
# position:1
# profit:5.600000000000364
# mem:1331.5
# (H_k+L_k)/2:1331.5
# T:459
# t:702
# fee:387
# position:-1
# profit:5.000000000000455
# mem:1330.9
# (H_k+L_k)/2:1330.9
# T:460
# t:703
# fee:389
# position:-1
# profit:4.800000000000637
# mem:1331.1
# (H_k+L_k)/2:1331.1
# T:461
# t:704
# fee:391
# position:-1
# profit:5.000000000000455
# mem:1330.9
# (H_k+L_k)/2:1330.9
# T:462
# t:705
# fee:393
# position:-1
# profit:5.750000000000455
# mem:1330.15
# (H_k+L_k)/2:1330.15
# T:463
# t:706
# fee:395
# position:-1
# profit:5.750000000000455
# mem:1330.15
# (H_k+L_k)/2:1328.5
# T:464
# t:707
# fee:395
# position:-1
# profit:5.750000000000455
# mem:1330.15
# (H_k+L_k)/2:1325.7
# T:465
# t:708
# fee:395
# position:-1
# profit:5.750000000000455
# mem:1330.15
# (H_k+L_k)/2:1325.55
# T:466
# t:709
# fee:395
# position:-1
# profit:5.750000000000455
# mem:1330.15
# (H_k+L_k)/2:1325.2
# T:467
# t:710
# fee:395
# position:-1
# profit:5.750000000000455
# mem:1330.15
# (H_k+L_k)/2:1324.9499999999998
# T:468
# t:711
# fee:395
# position:-1
# profit:5.750000000000455
# mem:1330.15
# (H_k+L_k)/2:1324.4
# T:469
# t:712
# fee:395
# position:-1
# profit:5.750000000000455
# mem:1330.15
# (H_k+L_k)/2:1323.5500000000002
# T:470
# t:713
# fee:395
# position:-1
# profit:5.750000000000455
# mem:1330.15
# (H_k+L_k)/2:1323.25
# T:471
# t:714
# fee:395
# position:-1
# profit:12.100000000000591
# mem:1323.8
# (H_k+L_k)/2:1323.8
# T:472
# t:715
# fee:397
# position:-1
# profit:11.600000000000591
# mem:1324.3
# (H_k+L_k)/2:1324.3
# T:473
# t:716
# fee:399
# position:-1
# profit:11.150000000000546
# mem:1324.75
# (H_k+L_k)/2:1324.75
# T:474
# t:717
# fee:401
# position:-1
# profit:11.300000000000637
# mem:1324.6
# (H_k+L_k)/2:1324.6
# T:475
# t:718
# fee:403
# position:-1
# profit:11.350000000000591
# mem:1324.55
# (H_k+L_k)/2:1324.55
# T:476
# t:719
# fee:405
# position:-1
# profit:11.600000000000364
# mem:1324.3000000000002
# (H_k+L_k)/2:1324.3000000000002
# T:477
# t:720
# fee:407
# position:1
# profit:11.300000000000637
# mem:1324.6
# (H_k+L_k)/2:1324.6
# T:478
# t:721
# fee:409
# position:1
# profit:11.550000000000637
# mem:1324.85
# (H_k+L_k)/2:1324.85
# T:479
# t:722
# fee:411
# position:1
# profit:11.100000000000819
# mem:1324.4
# (H_k+L_k)/2:1324.4
# T:480
# t:723
# fee:413
# position:1
# profit:10.600000000000819
# mem:1323.9
# (H_k+L_k)/2:1323.9
# T:481
# t:724
# fee:415
# position:-1
# profit:10.650000000000546
# mem:1323.9499999999998
# (H_k+L_k)/2:1323.9499999999998
# T:482
# t:725
# fee:417
# position:-1
# profit:10.250000000000455
# mem:1324.35
# (H_k+L_k)/2:1324.35
# T:483
# t:726
# fee:419
# position:-1
# profit:10.250000000000455
# mem:1324.35
# (H_k+L_k)/2:1324.35
# T:484
# t:727
# fee:421
# position:-1
# profit:10.400000000000318
# mem:1324.2
# (H_k+L_k)/2:1324.2
# T:485
# t:728
# fee:423
# position:1
# profit:10.050000000000182
# mem:1324.5500000000002
# (H_k+L_k)/2:1324.5500000000002
# T:486
# t:729
# fee:425
# position:1
# profit:10.5
# mem:1325.0
# (H_k+L_k)/2:1325.0
# T:487
# t:730
# fee:427
# position:-1
# profit:10.199999999999818
# mem:1324.6999999999998
# (H_k+L_k)/2:1324.6999999999998
# T:488
# t:731
# fee:429
# position:1
# profit:10.249999999999545
# mem:1324.65
# (H_k+L_k)/2:1324.65
# T:489
# t:732
# fee:431
# position:1
# profit:9.999999999999545
# mem:1324.4
# (H_k+L_k)/2:1324.4
# T:490
# t:733
# fee:433
# position:1
# profit:9.849999999999454
# mem:1324.25
# (H_k+L_k)/2:1324.25
# T:491
# t:734
# fee:435
# position:1
# profit:10.199999999999363
# mem:1324.6
# (H_k+L_k)/2:1324.6
# T:492
# t:735
# fee:437
# position:1
# profit:10.499999999999545
# mem:1324.9
# (H_k+L_k)/2:1324.9
# T:493
# t:736
# fee:439
# position:1
# profit:10.449999999999363
# mem:1324.85
# (H_k+L_k)/2:1324.85
# T:494
# t:737
# fee:441
# position:1
# profit:10.149999999999409
# mem:1324.55
# (H_k+L_k)/2:1324.55
# T:495
# t:738
# fee:443
# position:-1
# profit:10.099999999999454
# mem:1324.5
# (H_k+L_k)/2:1324.5
# T:496
# t:739
# fee:445
# position:-1
# profit:9.899999999999409
# mem:1324.7
# (H_k+L_k)/2:1324.7
# T:497
# t:740
# fee:447
# position:1
# profit:9.849999999999454
# mem:1324.75
# (H_k+L_k)/2:1324.75
# T:498
# t:741
# fee:449
# position:1
# profit:10.199999999999363
# mem:1325.1
# (H_k+L_k)/2:1325.1
# T:499
# t:742
# fee:451
# position:1
# profit:9.899999999999636
# mem:1324.8000000000002
# (H_k+L_k)/2:1324.8000000000002
# T:500
# t:743
# fee:453
# position:1
# profit:9.5499999999995
# mem:1324.45
# (H_k+L_k)/2:1324.45
# T:501
# t:744
# fee:455
# position:-1
# profit:9.049999999999272
# mem:1323.9499999999998
# (H_k+L_k)/2:1323.9499999999998
# T:502
# t:745
# fee:457
# position:-1
# profit:9.099999999999
# mem:1323.9
# (H_k+L_k)/2:1323.9
# T:503
# t:746
# fee:459
# position:-1
# profit:9.24999999999909
# mem:1323.75
# (H_k+L_k)/2:1323.75
# T:504
# t:747
# fee:461
# position:-1
# profit:10.099999999999
# mem:1322.9
# (H_k+L_k)/2:1322.9
# T:505
# t:748
# fee:463
# position:-1
# profit:9.799999999999045
# mem:1323.2
# (H_k+L_k)/2:1323.2
# T:506
# t:749
# fee:465
# position:1
# profit:8.799999999999272
# mem:1324.1999999999998
# (H_k+L_k)/2:1324.1999999999998
# T:507
# t:750
# fee:467
# position:-1
# profit:9.299999999999272
# mem:1324.6999999999998
# (H_k+L_k)/2:1324.6999999999998
# T:508
# t:751
# fee:469
# position:-1
# profit:9.599999999999
# mem:1324.4
# (H_k+L_k)/2:1324.4
# T:509
# t:752
# fee:471
# position:-1
# profit:9.849999999999
# mem:1324.15
# (H_k+L_k)/2:1324.15
# T:510
# t:753
# fee:473
# position:-1
# profit:10.199999999999136
# mem:1323.8
# (H_k+L_k)/2:1323.8
# T:511
# t:754
# fee:475
# position:-1
# profit:10.399999999999181
# mem:1323.6
# (H_k+L_k)/2:1323.6
# T:512
# t:755
# fee:477
# position:-1
# profit:10.349999999999
# mem:1323.65
# (H_k+L_k)/2:1323.65
# T:513
# t:756
# fee:479
# position:1
# profit:10.24999999999909
# mem:1323.75
# (H_k+L_k)/2:1323.75
# T:514
# t:757
# fee:481
# position:1
# profit:10.699999999999136
# mem:1324.2
# (H_k+L_k)/2:1324.2
# T:515
# t:758
# fee:483
# position:1
# profit:10.699999999999136
# mem:1324.2
# (H_k+L_k)/2:1324.2
# T:516
# t:759
# fee:485
# position:-1
# profit:10.74999999999909
# mem:1324.25
# (H_k+L_k)/2:1324.25
# T:517
# t:760
# fee:487
# position:1
# profit:10.399999999999181
# mem:1324.6
# (H_k+L_k)/2:1324.6
# T:518
# t:761
# fee:489
# position:1
# profit:10.449999999999363
# mem:1324.65
# (H_k+L_k)/2:1324.65
# T:519
# t:762
# fee:491
# position:1
# profit:9.99999999999909
# mem:1324.1999999999998
# (H_k+L_k)/2:1324.1999999999998
# T:520
# t:763
# fee:493
# position:1
# profit:9.649999999999181
# mem:1323.85
# (H_k+L_k)/2:1323.85
# T:521
# t:764
# fee:495
# position:1
# profit:9.699999999999363
# mem:1323.9
# (H_k+L_k)/2:1323.9
# T:522
# t:765
# fee:497
# position:1
# profit:10.299999999999272
# mem:1324.5
# (H_k+L_k)/2:1324.5
# T:523
# t:766
# fee:499
# position:-1
# profit:9.749999999999318
# mem:1323.95
# (H_k+L_k)/2:1323.95
# T:524
# t:767
# fee:501
# position:-1
# profit:10.349999999999454
# mem:1323.35
# (H_k+L_k)/2:1323.35
# T:525
# t:768
# fee:503
# position:-1
# profit:10.399999999999181
# mem:1323.3000000000002
# (H_k+L_k)/2:1323.3000000000002
# T:526
# t:769
# fee:505
# position:-1
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1323.45
# T:527
# t:770
# fee:507
# position:-1
# profit:10.149999999999409
# mem:1323.55
# (H_k+L_k)/2:1323.55
# T:528
# t:771
# fee:509
# position:-1
# profit:10.849999999999454
# mem:1322.85
# (H_k+L_k)/2:1322.85
# T:529
# t:772
# fee:511
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1323.45
# T:530
# t:773
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1324.25
# T:531
# t:774
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1325.15
# T:532
# t:775
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1324.65
# T:533
# t:776
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1324.25
# T:534
# t:777
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1323.85
# T:535
# t:778
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1324.15
# T:536
# t:779
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1324.9
# T:537
# t:780
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1324.9
# T:538
# t:781
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1324.6999999999998
# T:539
# t:782
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1324.85
# T:540
# t:783
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1324.75
# T:541
# t:784
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1326.75
# T:542
# t:785
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1326.55
# T:543
# t:786
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1327.0
# T:544
# t:787
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1326.3
# T:545
# t:788
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1326.8
# T:546
# t:789
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1326.0
# T:547
# t:790
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1325.95
# T:548
# t:791
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1326.85
# T:549
# t:792
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1325.6
# T:550
# t:793
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1327.3
# T:551
# t:794
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1328.55
# T:552
# t:795
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1328.0500000000002
# T:553
# t:796
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1329.1999999999998
# T:554
# t:797
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1329.25
# T:555
# t:798
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1328.2
# T:556
# t:799
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1328.35
# T:557
# t:800
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1329.85
# T:558
# t:801
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1329.45
# T:559
# t:802
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1329.4
# T:560
# t:803
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1329.4
# T:561
# t:804
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1328.7
# T:562
# t:805
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1328.9499999999998
# T:563
# t:806
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1328.9
# T:564
# t:807
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1329.3
# T:565
# t:808
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1329.65
# T:566
# t:809
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1329.0500000000002
# T:567
# t:810
# fee:512
# profit:10.249999999999318
# mem:1323.45
# (H_k+L_k)/2:1329.15
# T:568
# ...
# mem:1303.75
# (H_k+L_k)/2:1303.75
# T:2782
# t:3025
# fee:2418
# profit:123.39999999999668
# mem:1303.65
# (H_k+L_k)/2:1303.65
# T:2783
# t:3026
# fee:2419
# profit:123.39999999999668
# mem:1303.65
# (H_k+L_k)/2:1303.1999999999998
# T:2784
# t:3027
# fee:2419
# profit:123.39999999999668
# mem:1303.65
# (H_k+L_k)/2:1302.9
# T:2785
# t:3028
# fee:2419
# position:-1
# profit:123.39999999999668
# mem:1302.5
# (H_k+L_k)/2:1302.5
# T:2786
# t:3029
# fee:2420
# position:-1
# profit:122.79999999999677
# mem:1303.1
# (H_k+L_k)/2:1303.1
# T:2787
# t:3030
# fee:2422
# profit:121.69999999999686
# mem:1304.1999999999998
# (H_k+L_k)/2:1304.1999999999998
# T:2788
# t:3031
# fee:2423
# profit:121.69999999999686
# mem:1304.1999999999998
# (H_k+L_k)/2:1302.9
# T:2789
# t:3032
# fee:2423
# position:-1
# profit:121.69999999999686
# mem:1303.25
# (H_k+L_k)/2:1303.25
# T:2790
# t:3033
# fee:2424
# profit:121.44999999999686
# mem:1303.5
# (H_k+L_k)/2:1303.5
# T:2791
# t:3034
# fee:2425
# profit:121.44999999999686
# mem:1303.5
# (H_k+L_k)/2:1302.85
# T:2792
# t:3035
# fee:2425
# profit:121.44999999999686
# mem:1303.5
# (H_k+L_k)/2:1303.0
# T:2793
# t:3036
# fee:2425
# profit:121.44999999999686
# mem:1303.5
# (H_k+L_k)/2:1302.9
# T:2794
# t:3037
# fee:2425
# position:-1
# profit:121.44999999999686
# mem:1302.6
# (H_k+L_k)/2:1302.6
# T:2795
# t:3038
# fee:2426
# position:-1
# profit:121.79999999999677
# mem:1302.25
# (H_k+L_k)/2:1302.25
# T:2796
# t:3039
# fee:2428
# position:-1
# profit:121.69999999999686
# mem:1302.35
# (H_k+L_k)/2:1302.35
# T:2797
# t:3040
# fee:2430
# position:-1
# profit:121.44999999999686
# mem:1302.6
# (H_k+L_k)/2:1302.6
# T:2798
# t:3041
# fee:2432
# position:-1
# profit:121.49999999999682
# mem:1302.55
# (H_k+L_k)/2:1302.55
# T:2799
# t:3042
# fee:2434
# profit:121.24999999999682
# mem:1302.8
# (H_k+L_k)/2:1302.8
# T:2800
# t:3043
# fee:2435
# profit:121.24999999999682
# mem:1302.8
# (H_k+L_k)/2:1302.5
# T:2801
# t:3044
# fee:2435
# profit:121.24999999999682
# mem:1302.8
# (H_k+L_k)/2:1302.45
# T:2802
# t:3045
# fee:2435
# profit:121.24999999999682
# mem:1302.8
# (H_k+L_k)/2:1302.6
# T:2803
# t:3046
# fee:2435
# profit:121.24999999999682
# mem:1302.8
# (H_k+L_k)/2:1302.4
# T:2804
# t:3047
# fee:2435
# profit:121.24999999999682
# mem:1302.8
# (H_k+L_k)/2:1302.4
# T:2805
# t:3048
# fee:2435
# profit:121.24999999999682
# mem:1302.8
# (H_k+L_k)/2:1303.1
# T:2806
# t:3049
# fee:2435
# profit:121.24999999999682
# mem:1302.8
# (H_k+L_k)/2:1303.35
# T:2807
# t:3050
# fee:2435
# position:1
# profit:121.24999999999682
# mem:1302.75
# (H_k+L_k)/2:1302.75
# T:2808
# t:3051
# fee:2436
# position:1
# profit:121.19999999999663
# mem:1302.6999999999998
# (H_k+L_k)/2:1302.6999999999998
# T:2809
# t:3052
# fee:2438
# position:-1
# profit:121.19999999999686
# mem:1302.7
# (H_k+L_k)/2:1302.7
# T:2810
# t:3053
# fee:2440
# position:1
# profit:121.299999999997
# mem:1302.6
# (H_k+L_k)/2:1302.6
# T:2811
# t:3054
# fee:2442
# position:1
# profit:122.09999999999718
# mem:1303.4
# (H_k+L_k)/2:1303.4
# T:2812
# t:3055
# fee:2444
# profit:121.94999999999709
# mem:1303.25
# (H_k+L_k)/2:1303.25
# T:2813
# t:3056
# fee:2445
# profit:121.94999999999709
# mem:1303.25
# (H_k+L_k)/2:1303.5
# T:2814
# t:3057
# fee:2445
# profit:121.94999999999709
# mem:1303.25
# (H_k+L_k)/2:1303.35
# T:2815
# t:3058
# fee:2445
# position:-1
# profit:121.94999999999709
# mem:1303.7
# (H_k+L_k)/2:1303.7
# T:2816
# t:3059
# fee:2446
# profit:121.99999999999704
# mem:1303.65
# (H_k+L_k)/2:1303.65
# T:2817
# t:3060
# fee:2447
# position:1
# profit:121.99999999999704
# mem:1303.5500000000002
# (H_k+L_k)/2:1303.5500000000002
# T:2818
# t:3061
# fee:2448
# position:1
# profit:121.99999999999682
# mem:1303.55
# (H_k+L_k)/2:1303.55
# T:2819
# t:3062
# fee:2450
# position:1
# profit:121.74999999999682
# mem:1303.3
# (H_k+L_k)/2:1303.3
# T:2820
# t:3063
# fee:2452
# position:1
# profit:121.89999999999691
# mem:1303.45
# (H_k+L_k)/2:1303.45
# T:2821
# t:3064
# fee:2454
# profit:122.09999999999695
# mem:1303.65
# (H_k+L_k)/2:1303.65
# T:2822
# t:3065
# fee:2455
# profit:122.09999999999695
# mem:1303.65
# (H_k+L_k)/2:1303.6
# T:2823
# t:3066
# fee:2455
# profit:122.09999999999695
# mem:1303.65
# (H_k+L_k)/2:1303.8
# T:2824
# t:3067
# fee:2455
# profit:122.09999999999695
# mem:1303.65
# (H_k+L_k)/2:1303.3000000000002
# T:2825
# t:3068
# fee:2455
# position:-1
# profit:122.09999999999695
# mem:1302.75
# (H_k+L_k)/2:1302.75
# T:2826
# t:3069
# fee:2456
# position:-1
# profit:123.49999999999704
# mem:1301.35
# (H_k+L_k)/2:1301.35
# T:2827
# t:3070
# fee:2457
# position:-1
# profit:122.69999999999686
# mem:1302.15
# (H_k+L_k)/2:1302.15
# T:2828
# t:3071
# fee:2459
# position:-1
# profit:122.69999999999686
# mem:1302.15
# (H_k+L_k)/2:1300.9
# T:2829
# t:3072
# fee:2459
# position:-1
# profit:122.69999999999686
# mem:1302.15
# (H_k+L_k)/2:1299.2
# T:2830
# t:3073
# fee:2459
# position:-1
# profit:122.69999999999686
# mem:1302.15
# (H_k+L_k)/2:1298.85
# T:2831
# t:3074
# fee:2459
# position:-1
# profit:122.69999999999686
# mem:1302.15
# (H_k+L_k)/2:1299.05
# T:2832
# t:3075
# fee:2459
# position:-1
# profit:122.69999999999686
# mem:1302.15
# (H_k+L_k)/2:1298.2
# T:2833
# t:3076
# fee:2459
# position:-1
# profit:122.69999999999686
# mem:1302.15
# (H_k+L_k)/2:1296.1999999999998
# T:2834
# t:3077
# fee:2459
# position:-1
# profit:122.69999999999686
# mem:1302.15
# (H_k+L_k)/2:1297.15
# T:2835
# t:3078
# fee:2459
# position:-1
# profit:127.79999999999677
# mem:1297.0500000000002
# (H_k+L_k)/2:1297.0500000000002
# T:2836
# t:3079
# fee:2461
# position:-1
# profit:126.99999999999704
# mem:1297.85
# (H_k+L_k)/2:1297.85
# T:2837
# t:3080
# fee:2463
# position:-1
# profit:127.59999999999695
# mem:1297.25
# (H_k+L_k)/2:1297.25
# T:2838
# t:3081
# fee:2465
# position:-1
# profit:127.34999999999695
# mem:1297.5
# (H_k+L_k)/2:1297.5
# T:2839
# t:3082
# fee:2467
# position:-1
# profit:126.549999999997
# mem:1298.3
# (H_k+L_k)/2:1298.3
# T:2840
# t:3083
# fee:2469
# position:-1
# profit:126.64999999999691
# mem:1298.2
# (H_k+L_k)/2:1298.2
# T:2841
# t:3084
# fee:2471
# position:-1
# profit:126.99999999999704
# mem:1297.85
# (H_k+L_k)/2:1297.85
# T:2842
# t:3085
# fee:2473
# position:1
# profit:126.39999999999691
# mem:1298.45
# (H_k+L_k)/2:1298.45
# T:2843
# t:3086
# fee:2475
# position:1
# profit:128.64999999999668
# mem:1300.6999999999998
# (H_k+L_k)/2:1300.6999999999998
# T:2844
# t:3087
# fee:2477
# position:1
# profit:128.64999999999668
# mem:1300.6999999999998
# (H_k+L_k)/2:1302.05
# T:2845
# t:3088
# fee:2477
# position:1
# profit:128.64999999999668
# mem:1300.6999999999998
# (H_k+L_k)/2:1301.2
# T:2846
# t:3089
# fee:2477
# position:1
# profit:128.64999999999668
# mem:1300.6999999999998
# (H_k+L_k)/2:1301.15
# T:2847
# t:3090
# fee:2477
# position:1
# profit:128.84999999999695
# mem:1300.9
# (H_k+L_k)/2:1300.9
# T:2848
# t:3091
# fee:2479
# position:1
# profit:128.44999999999686
# mem:1300.5
# (H_k+L_k)/2:1300.5
# T:2849
# t:3092
# fee:2481
# position:1
# profit:128.8999999999969
# mem:1300.95
# (H_k+L_k)/2:1300.95
# T:2850
# t:3093
# fee:2483
# position:1
# profit:127.79999999999677
# mem:1299.85
# (H_k+L_k)/2:1299.85
# T:2851
# t:3094
# fee:2485
# position:1
# profit:127.39999999999691
# mem:1299.45
# (H_k+L_k)/2:1299.45
# T:2852
# t:3095
# fee:2487
# position:1
# profit:126.99999999999682
# mem:1299.05
# (H_k+L_k)/2:1299.05
# T:2853
# t:3096
# fee:2489
# position:-1
# profit:127.34999999999695
# mem:1299.4
# (H_k+L_k)/2:1299.4
# T:2854
# t:3097
# fee:2491
# position:-1
# profit:127.799999999997
# mem:1298.95
# (H_k+L_k)/2:1298.95
# T:2855
# t:3098
# fee:2493
# position:-1
# profit:127.549999999997
# mem:1299.2
# (H_k+L_k)/2:1299.2
# T:2856
# t:3099
# fee:2495
# position:-1
# profit:127.59999999999695
# mem:1299.15
# (H_k+L_k)/2:1299.15
# T:2857
# t:3100
# fee:2497
# position:-1
# profit:127.94999999999709
# mem:1298.8
# (H_k+L_k)/2:1298.8
# T:2858
# t:3101
# fee:2499
# position:-1
# profit:128.89999999999714
# mem:1297.85
# (H_k+L_k)/2:1297.85
# T:2859
# t:3102
# fee:2501
# position:-1
# profit:129.39999999999714
# mem:1297.35
# (H_k+L_k)/2:1297.35
# T:2860
# t:3103
# fee:2503
# position:-1
# profit:129.799999999997
# mem:1296.95
# (H_k+L_k)/2:1296.95
# T:2861
# t:3104
# fee:2505
# position:-1
# profit:129.84999999999695
# mem:1296.9
# (H_k+L_k)/2:1296.9
# T:2862
# t:3105
# fee:2507
# position:-1
# profit:129.24999999999704
# mem:1297.5
# (H_k+L_k)/2:1297.5
# T:2863
# t:3106
# fee:2509
# position:-1
# profit:129.24999999999704
# mem:1297.5
# (H_k+L_k)/2:1297.5
# T:2864
# t:3107
# fee:2511
# position:-1
# profit:129.1999999999971
# mem:1297.55
# (H_k+L_k)/2:1297.55
# T:2865
# t:3108
# fee:2513
# position:-1
# profit:128.89999999999714
# mem:1297.85
# (H_k+L_k)/2:1297.85
# T:2866
# t:3109
# fee:2515
# position:-1
# profit:129.299999999997
# mem:1297.45
# (H_k+L_k)/2:1297.45
# T:2867
# t:3110
# fee:2517
# position:-1
# profit:129.64999999999714
# mem:1297.1
# (H_k+L_k)/2:1297.1
# T:2868
# t:3111
# fee:2519
# position:-1
# profit:129.49999999999704
# mem:1297.25
# (H_k+L_k)/2:1297.25
# T:2869
# t:3112
# fee:2521
# position:1
# profit:129.049999999997
# mem:1297.7
# (H_k+L_k)/2:1297.7
# T:2870
# t:3113
# fee:2523
# position:1
# profit:128.84999999999695
# mem:1297.5
# (H_k+L_k)/2:1297.5
# T:2871
# t:3114
# fee:2525
# position:1
# profit:129.24999999999704
# mem:1297.9
# (H_k+L_k)/2:1297.9
# T:2872
# t:3115
# fee:2527
# position:1
# profit:129.49999999999704
# mem:1298.15
# (H_k+L_k)/2:1298.15
# T:2873
# t:3116
# fee:2529
# position:1
# profit:129.09999999999695
# mem:1297.75
# (H_k+L_k)/2:1297.75
# T:2874
# t:3117
# fee:2531
# position:-1
# profit:128.34999999999695
# mem:1297.0
# (H_k+L_k)/2:1297.0
# T:2875
# t:3118
# fee:2533
# position:-1
# profit:128.74999999999704
# mem:1296.6
# (H_k+L_k)/2:1296.6
# T:2876
# t:3119
# fee:2535
# position:-1
# profit:127.99999999999704
# mem:1297.35
# (H_k+L_k)/2:1297.35
# T:2877
# t:3120
# fee:2537
# position:-1
# profit:128.34999999999695
# mem:1297.0
# (H_k+L_k)/2:1297.0
# T:2878
# t:3121
# fee:2539
# position:-1
# profit:128.6499999999969
# mem:1296.7
# (H_k+L_k)/2:1296.7
# T:2879
# t:3122
# fee:2541
# position:-1
# profit:128.29999999999677
# mem:1297.0500000000002
# (H_k+L_k)/2:1297.0500000000002
# T:2880
# t:3123
# fee:2543
# position:-1
# profit:128.3999999999969
# mem:1296.95
# (H_k+L_k)/2:1296.95
# T:2881
# t:3124
# fee:2545
# position:-1
# profit:127.94999999999686
# mem:1297.4
# (H_k+L_k)/2:1297.4
# T:2882
# t:3125
# fee:2547
# position:-1
# profit:127.79999999999677
# mem:1297.5500000000002
# (H_k+L_k)/2:1297.5500000000002
# T:2883
# t:3126
# fee:2549
# position:-1
# profit:128.29999999999677
# mem:1297.0500000000002
# (H_k+L_k)/2:1297.0500000000002
# T:2884
# t:3127
# fee:2551
# position:1
# profit:128.44999999999686
# mem:1296.9
# (H_k+L_k)/2:1296.9
# T:2885
# t:3128
# fee:2553
# position:-1
# profit:128.54999999999677
# mem:1297.0
# (H_k+L_k)/2:1297.0
# T:2886
# t:3129
# fee:2555
# position:-1
# profit:128.49999999999682
# mem:1297.05
# (H_k+L_k)/2:1297.05
# T:2887
# t:3130
# fee:2557
# position:-1
# profit:128.59999999999695
# mem:1296.9499999999998
# (H_k+L_k)/2:1296.9499999999998
# T:2888
# t:3131
# fee:2559
# position:1
# profit:128.34999999999673
# mem:1297.2
# (H_k+L_k)/2:1297.2
# T:2889
# t:3132
# fee:2561
# position:1
# profit:128.34999999999673
# mem:1297.2
# (H_k+L_k)/2:1297.2
# T:2890
# t:3133
# fee:2563
# position:1
# profit:128.4999999999966
# mem:1297.35
# (H_k+L_k)/2:1297.35
# T:2891
# t:3134
# fee:2565
# position:-1
# profit:128.54999999999677
# mem:1297.4
# (H_k+L_k)/2:1297.4
# T:2892
# t:3135
# fee:2567
# position:1
# profit:128.44999999999686
# mem:1297.5
# (H_k+L_k)/2:1297.5
# T:2893
# t:3136
# fee:2569
# position:-1
# profit:127.99999999999704
# mem:1297.0500000000002
# (H_k+L_k)/2:1297.0500000000002
# T:2894
# t:3137
# fee:2571
# position:-1
# profit:127.99999999999704
# mem:1297.0500000000002
# (H_k+L_k)/2:1295.7
# T:2895
# t:3138
# fee:2571
# position:-1
# profit:127.99999999999704
# mem:1297.0500000000002
# (H_k+L_k)/2:1295.1
# T:2896
# t:3139
# fee:2571
# position:-1
# profit:127.99999999999704
# mem:1297.0500000000002
# (H_k+L_k)/2:1294.85
# T:2897
# t:3140
# fee:2571
# position:-1
# profit:127.99999999999704
# mem:1297.0500000000002
# (H_k+L_k)/2:1295.05
# T:2898
# t:3141
# fee:2571
# position:-1
# profit:127.99999999999704
# mem:1297.0500000000002
# (H_k+L_k)/2:1295.3
# T:2899
# t:3142
# fee:2571
# position:-1
# profit:129.99999999999727
# mem:1295.05
# (H_k+L_k)/2:1295.05
# T:2900
# t:3143
# fee:2573
# position:-1
# profit:129.69999999999732
# mem:1295.35
# (H_k+L_k)/2:1295.35
# T:2901
# t:3144
# fee:2575
# position:-1
# profit:129.94999999999732
# mem:1295.1
# (H_k+L_k)/2:1295.1
# T:2902
# t:3145
# fee:2577
# position:-1
# profit:129.89999999999714
# mem:1295.15
# (H_k+L_k)/2:1295.15
# T:2903
# t:3146
# fee:2579
# position:1
# profit:129.19999999999732
# mem:1295.85
# (H_k+L_k)/2:1295.85
# T:2904
# t:3147
# fee:2581
# position:1
# profit:129.19999999999732
# mem:1295.85
# (H_k+L_k)/2:1297.6
# T:2905
# t:3148
# fee:2581
# position:1
# profit:129.19999999999732
# mem:1295.85
# (H_k+L_k)/2:1297.6999999999998
# T:2906
# t:3149
# fee:2581
# position:1
# profit:130.44999999999732
# mem:1297.1
# (H_k+L_k)/2:1297.1
# T:2907
# t:3150
# fee:2583
# position:1
# profit:130.4999999999975
# mem:1297.15
# (H_k+L_k)/2:1297.15
# T:2908
# t:3151
# fee:2585
# position:1
# profit:130.5999999999974
# mem:1297.25
# (H_k+L_k)/2:1297.25
# T:2909
# t:3152
# fee:2587
# position:1
# profit:130.94999999999732
# mem:1297.6
# (H_k+L_k)/2:1297.6
# T:2910
# t:3153
# fee:2589
# position:1
# profit:130.7499999999975
# mem:1297.4
# (H_k+L_k)/2:1297.4
# T:2911
# t:3154
# fee:2591
# position:1
# profit:131.14999999999736
# mem:1297.8
# (H_k+L_k)/2:1297.8
# T:2912
# t:3155
# fee:2593
# position:1
# profit:131.04999999999745
# mem:1297.7
# (H_k+L_k)/2:1297.7
# T:2913
# t:3156
# fee:2595
# position:1
# profit:131.89999999999736
# mem:1298.55
# (H_k+L_k)/2:1298.55
# T:2914
# t:3157
# fee:2597
# position:1
# profit:131.4999999999975
# mem:1298.15
# (H_k+L_k)/2:1298.15
# T:2915
# t:3158
# fee:2599
# position:1
# profit:131.29999999999723
# mem:1297.9499999999998
# (H_k+L_k)/2:1297.9499999999998
# T:2916
# t:3159
# fee:2601
# position:1
# profit:131.0999999999974
# mem:1297.75
# (H_k+L_k)/2:1297.75
# T:2917
# t:3160
# fee:2603
# position:1
# profit:131.69999999999732
# mem:1298.35
# (H_k+L_k)/2:1298.35
# T:2918
# t:3161
# fee:2605
# position:1
# profit:132.2499999999975
# mem:1298.9
# (H_k+L_k)/2:1298.9
# T:2919
# t:3162
# fee:2607
# profit:132.29999999999745
# mem:1298.95
# (H_k+L_k)/2:1298.95
# T:2920
# t:3163
# fee:2608
# profit:132.29999999999745
# mem:1298.95
# (H_k+L_k)/2:1298.85
# T:2921
# t:3164
# fee:2608
# position:1
# profit:132.29999999999745
# mem:1299.2
# (H_k+L_k)/2:1299.2
# T:2922
# t:3165
# fee:2609
# profit:132.89999999999736
# mem:1299.8
# (H_k+L_k)/2:1299.8
# T:2923
# t:3166
# fee:2610
# profit:132.89999999999736
# mem:1299.8
# (H_k+L_k)/2:1300.35
# T:2924
# t:3167
# fee:2610
# profit:132.89999999999736
# mem:1299.8
# (H_k+L_k)/2:1300.65
# T:2925
# t:3168
# fee:2610
# profit:132.89999999999736
# mem:1299.8
# (H_k+L_k)/2:1300.9
# T:2926
# t:3169
# fee:2610
# profit:132.89999999999736
# mem:1299.8
# (H_k+L_k)/2:1301.05
# T:2927
# t:3170
# fee:2610
# profit:132.89999999999736
# mem:1299.8
# (H_k+L_k)/2:1301.3000000000002
# T:2928
# t:3171
# fee:2610
# profit:132.89999999999736
# mem:1299.8
# (H_k+L_k)/2:1301.35
# T:2929
# t:3172
# fee:2610
# profit:132.89999999999736
# mem:1299.8
# (H_k+L_k)/2:1300.6
# T:2930
# t:3173
# fee:2610
# profit:132.89999999999736
# mem:1299.8
# (H_k+L_k)/2:1299.75
# T:2931
# t:3174
# fee:2610
# profit:132.89999999999736
# mem:1299.8
# (H_k+L_k)/2:1299.1
# T:2932
# t:3175
# fee:2610
# profit:132.89999999999736
# mem:1299.8
# (H_k+L_k)/2:1299.1
# T:2933
# t:3176
# fee:2610
# profit:132.89999999999736
# mem:1299.8
# (H_k+L_k)/2:1299.8
# T:2934
# t:3177
# fee:2610
# profit:132.89999999999736
# mem:1299.8
# (H_k+L_k)/2:1299.35
# T:2935
# t:3178
# fee:2610
# profit:132.89999999999736
# mem:1299.8
# (H_k+L_k)/2:1298.1
# T:2936
# t:3179
# fee:2610
# profit:132.89999999999736
# mem:1299.8
# (H_k+L_k)/2:1297.55
# T:2937
# t:3180
# fee:2610
# profit:132.89999999999736
# mem:1299.8
# (H_k+L_k)/2:1297.65
# T:2938
# t:3181
# fee:2610
# profit:132.89999999999736
# mem:1299.8
# (H_k+L_k)/2:1297.85
# T:2939
# t:3182
# fee:2610
# position:-1
# profit:132.89999999999736
# mem:1297.7
# (H_k+L_k)/2:1297.7
# T:2940
# t:3183
# fee:2611
# position:-1
# profit:132.89999999999736
# mem:1297.7
# (H_k+L_k)/2:1297.7
# T:2941
# t:3184
# fee:2613
# position:-1
# profit:132.9999999999975
# mem:1297.6
# (H_k+L_k)/2:1297.6
# T:2942
# t:3185
# fee:2615
# position:-1
# profit:132.9999999999975
# mem:1297.6
# (H_k+L_k)/2:1297.6
# T:2943
# t:3186
# fee:2617
# profit:133.1499999999976
# mem:1297.4499999999998
# (H_k+L_k)/2:1297.4499999999998
# T:2944
# t:3187
# fee:2618
# profit:133.1499999999976
# mem:1297.4499999999998
# (H_k+L_k)/2:1297.35
# T:2945
# t:3188
# fee:2618
# profit:133.1499999999976
# mem:1297.4499999999998
# (H_k+L_k)/2:1297.15
# T:2946
# t:3189
# fee:2618
# profit:133.1499999999976
# mem:1297.4499999999998
# (H_k+L_k)/2:1297.15
# T:2947
# t:3190
# fee:2618
# profit:133.1499999999976
# mem:1297.4499999999998
# (H_k+L_k)/2:1296.9
# T:2948
# t:3191
# fee:2618
# profit:133.1499999999976
# mem:1297.4499999999998
# (H_k+L_k)/2:1296.95
# T:2949
# t:3192
# fee:2618
# profit:133.1499999999976
# mem:1297.4499999999998
# (H_k+L_k)/2:1296.8
# T:2950
# t:3193
# fee:2618
# profit:133.1499999999976
# mem:1297.4499999999998
# (H_k+L_k)/2:1296.65
# T:2951
# t:3194
# fee:2618
# profit:133.1499999999976
# mem:1297.4499999999998
# (H_k+L_k)/2:1296.55
# T:2952
# t:3195
# fee:2618
# profit:133.1499999999976
# mem:1297.4499999999998
# (H_k+L_k)/2:1296.55
# T:2953
# t:3196
# fee:2618
# profit:133.1499999999976
# mem:1297.4499999999998
# (H_k+L_k)/2:1296.25
# T:2954
# t:3197
# fee:2618
# profit:133.1499999999976
# mem:1297.4499999999998
# (H_k+L_k)/2:1296.0
# T:2955
# t:3198
# fee:2618
# profit:133.1499999999976
# mem:1297.4499999999998
# (H_k+L_k)/2:1295.85
# T:2956
# t:3199
# fee:2618
# profit:133.1499999999976
# mem:1297.4499999999998
# (H_k+L_k)/2:1295.7
# T:2957
# t:3200
# fee:2618
# profit:133.1499999999976
# 2618
